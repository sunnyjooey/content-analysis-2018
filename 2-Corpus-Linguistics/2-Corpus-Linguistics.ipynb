# %% [markdown]
# # Week 2 - Corpus Linguistics
#
# This week, we take text corpora that we have developed, spidered, scraped, and encoded, and we find and count words and simple phrases and properties of those counts (e.g., word frequency distributions). Initially, we model how to search corpora for keywords or phrases. Next, we examine the distributions of terms and phrases across a corpus, and the corelation between different words and phrase counts. In order to do this effectively, we coarsely disambiguate words based of part-of-speech (POS) tagging, and normalize them through stemming and lemmatization. Next we distinguish *important* words and phrase within the corpus, and image them with Wordls! Then we calculate word frequenceis, conditional frequences (the frequency of word *shock* conditional on the presence of word *awe*), and statistically significant collocations of lengths 2 through $n$. Finally, we calculate and visualize Differences (Divergences and Distances) between the word frequency distributions from two corpora.
#
# For this notebook we will be using the following packages

# %%
#Special module written for this class
#This provides access to data and to helper functions from previous weeks
import lucem_illud #pip install git+git://github.com/Computational-Content-Analysis-2018/lucem_illud.git

#All these packages need to be installed from pip
import requests #for http requests
import nltk #the Natural Language Toolkit
import pandas #gives us DataFrames
import matplotlib.pyplot as plt #For graphics
import wordcloud #Makes word clouds
import numpy as np #For divergences/distances
import scipy #For divergences/distances
import seaborn as sns #makes our plots look nicer
import sklearn.manifold #For a manifold plot
from nltk.corpus import stopwords #For stopwords
import json #For API responses
import urllib.parse #For joining urls

#This 'magic' command makes the plots work better
#in the notebook, don't use it outside of a notebook
# %matplotlib inline

# %%
from IPython.display import display
from nltk.util import skipgrams

# %% [markdown]
# # Retrieving exemplary corpora
#
# To get started we will need some examples. Let's start by downloading one of the corpuses from `nltk`, a Natural Language Toolkit developed by computational linguists at the University of Pennsylvania. Let's take a look at how that works.
#
# First we can get a list of works available from the Gutenburg corpus, with the [corpus module](http://www.nltk.org/api/nltk.corpus.html). To do this we will need to tell nltk where the data are, and download them if need be.

# %%
#You should have them already downloaded in the data directory
try:
    #adding path for both local and server, only one of these will actually be used at a time
    nltk.data.path.append('/project2/macs60000/shared_data/nltk')
    nltk.data.path.append('../data')
    #Check that everything is in place
    nltk.corpus.gutenberg.fileids()
except LookupError:
    print("You have to download all the documents")
    print("Downloading to ../data this should only take a couple minutes")
    nltk.download('all', download_dir = '../data')
    nltk.data.path.append('../data')
#If you haven't downloaded the copura then you will have to run `nltk.download()`
print(nltk.corpus.gutenberg.fileids())
print(len(nltk.corpus.gutenberg.fileids()))
# Out:
# ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']
# 18

# %% [markdown]
# We can also look at the individual works

# %%
nltk.corpus.gutenberg.raw('shakespeare-macbeth.txt')[2000:4000]
# Out:
# "es,\nBut the Norweyan Lord, surueying vantage,\nWith furbusht Armes, and new supplyes of men,\nBegan a fresh assault\n\n   King. Dismay'd not this our Captaines, Macbeth and\nBanquoh?\n  Cap. Yes, as Sparrowes, Eagles;\nOr the Hare, the Lyon:\nIf I say sooth, I must report they were\nAs Cannons ouer-charg'd with double Cracks,\nSo they doubly redoubled stroakes vpon the Foe:\nExcept they meant to bathe in reeking Wounds,\nOr memorize another Golgotha,\nI cannot tell: but I am faint,\nMy Gashes cry for helpe\n\n   King. So well thy words become thee, as thy wounds,\nThey smack of Honor both: Goe get him Surgeons.\nEnter Rosse and Angus.\n\nWho comes here?\n  Mal. The worthy Thane of Rosse\n\n   Lenox. What a haste lookes through his eyes?\nSo should he looke, that seemes to speake things strange\n\n   Rosse. God saue the King\n\n   King. Whence cam'st thou, worthy Thane?\n  Rosse. From Fiffe, great King,\nWhere the Norweyan Banners flowt the Skie,\nAnd fanne our people cold.\nNorway himselfe, with terrible numbers,\nAssisted by that most disloyall Traytor,\nThe Thane of Cawdor, began a dismall Conflict,\nTill that Bellona's Bridegroome, lapt in proofe,\nConfronted him with selfe-comparisons,\nPoint against Point, rebellious Arme 'gainst Arme,\nCurbing his lauish spirit: and to conclude,\nThe Victorie fell on vs\n\n   King. Great happinesse\n\n   Rosse. That now Sweno, the Norwayes King,\nCraues composition:\nNor would we deigne him buriall of his men,\nTill he disbursed, at Saint Colmes ynch,\nTen thousand Dollars, to our generall vse\n\n   King. No more that Thane of Cawdor shall deceiue\nOur Bosome interest: Goe pronounce his present death,\nAnd with his former Title greet Macbeth\n\n   Rosse. Ile see it done\n\n   King. What he hath lost, Noble Macbeth hath wonne.\n\nExeunt.\n\n\nScena Tertia.\n\nThunder. Enter the three Witches.\n\n  1. Where hast thou beene, Sister?\n  2. Killing Swine\n\n   3. Sister, where thou?\n  1. A Saylors Wife had Chestnuts in her Lappe,\nAnd mouncht, & mouncht, and mouncht:\nGiue me, quoth I.\nAroynt thee, "

# %% [markdown]
# All the listed works have been nicely marked up and classified for us so we can do much better than just looking at raw text.

# %%
print(nltk.corpus.gutenberg.words('shakespeare-macbeth.txt'))
print(nltk.corpus.gutenberg.sents('shakespeare-macbeth.txt'))
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Macbeth', 'by', ...]
# [['[', 'The', 'Tragedie', 'of', 'Macbeth', 'by', 'William', 'Shakespeare', '1603', ']'], ['Actus', 'Primus', '.'], ...]

# %% [markdown]
# # Counting words
#
# If we want to do some analysis we can start by simply counting the number of times each word occurs within the corpus.

# %%
def wordCounter(wordLst):
    wordCounts = {}
    for word in wordLst:
        #We usually need to normalize the case
        wLower = word.lower()
        if wLower in wordCounts:
            wordCounts[wLower] += 1
        else:
            wordCounts[wLower] = 1
    #convert to DataFrame
    countsForFrame = {'word' : [], 'count' : []}
    for w, c in wordCounts.items():
        countsForFrame['word'].append(w)
        countsForFrame['count'].append(c)
    return pandas.DataFrame(countsForFrame)

countedWords = wordCounter(nltk.corpus.gutenberg.words('shakespeare-macbeth.txt'))
countedWords[:10]
# Out:
#    count         word
# 0      4            [
# 1    650          the
# 2      2     tragedie
# 3    338           of
# 4     62      macbeth
# 5     49           by
# 6      1      william
# 7      1  shakespeare
# 8      1         1603
# 9      4            ]

# %% [markdown]
# Notice how `wordCounter()` is not a very complicated function. That is because the hard parts have already been done by `nltk`. If we were using unprocessed text we would have to tokenize and determine what to do with the non-word characters.
#
# nltk also offers a built-in way for getting a frequency distribution from a list of words:

# %%
words = [word.lower() for word in nltk.corpus.gutenberg.words('shakespeare-macbeth.txt')]
freq = nltk.FreqDist(words)
print (freq['macbeth'])
# Out:
# 62

# %% [markdown]
# Lets sort and plot our counts to investigate the shape of our word frequency distribution.
#
# First we need to sort the words by count.

# %%
#Doing this in place (changing the original DataFrame) as we don't need the unsorted DataFrame
countedWords.sort_values('count', ascending=False, inplace=True)
countedWords[:10]
# Out:
#     count word
# 29   1962    ,
# 12   1235    .
# 1     650  the
# 36    637    '
# 16    546  and
# 64    477    :
# 54    384   to
# 56    348    i
# 3     338   of
# 27    241    ?

# %% [markdown]
# Punctuation and very common words (articles 'a' and 'the'; prepositions 'of' and 'to') make up the most common values, but this isn't very interesting and can actually get in the way of our analysis. We may remove these 'function words' by removing according to a stopword list, setting some frequency threshold, or using a weighting scheme (like tf.idf) to decrease their influence (all modeled later in this tutorial).

# %%
#Creating a figure and axis lets us do things like change the scaling or add a title
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(range(len(countedWords)), countedWords['count'])
plt.show()

# %% [markdown]
# This shows that likelihood of a word occurring is inversely proportional to its rank. This effect is called [Zipf's Law](https://en.wikipedia.org/wiki/Zipf%27s_law), and suggests that the most frequent word will occur approximately twice as often as the second most frequent word, three times as often as the third most frequent word, etc. Zipf's law is most easily observed by plotting the data on a log-log graph, with the axes being log (rank order) and log (frequency) resulting in a linear relationship.

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(range(len(countedWords)), countedWords['count'])
ax.set_yscale('log')
ax.set_xscale('log')
plt.show()

# %% [markdown]
# (The same relationship occurs in many other rankings, such as population ranks of cities, corporation sizes, income rankings, etc.)
#
# The distribution was imagined by Zipf to be driven by a principle of 'least effort' where speakers did not work any harder than necessary to communicate a given idea, but the basis for this relationship is still not well understood and conforms at least as well to a process of [preferential attachment](https://en.wikipedia.org/wiki/Preferential_attachment) whereby people disproportionately attend to popular words.
#
# There are many other properties of words we can examine. First lets look surrounding words with the concordance. To do this we need to load the text into a `ConcordanceIndex`

# %%
macbethIndex = nltk.text.ConcordanceIndex(nltk.corpus.gutenberg.words('shakespeare-macbeth.txt'))

# %% [markdown]
# Then we can retrieve all the words that cooccur with a word in a given word window. Let's first look at `'macbeth'`.

# %%
macbethIndex.print_concordance('macbeth')
# Out:
# No matches

# %% [markdown]
# Weird?! `'macbeth'` doesn't occur anywhere in the the text. What happened?
#
# `ConcordanceIndex` is case sensitive, lets try looking for `'Macbeth'`

# %%
macbethIndex.print_concordance('Macbeth')
# Out:
# Displaying 25 of 61 matches:
#                                   Macbeth by William Shakespeare 1603 ] Act
#  the Heath 3 . There to meet with Macbeth 1 . I come , Gray - Malkin All .
# but all ' s too weake : For braue Macbeth ( well hee deserues that Name ) D
# smay ' d not this our Captaines , Macbeth and Banquoh ? Cap . Yes , as Spar
# , And with his former Title greet Macbeth Rosse . Ile see it done King . Wh
#  King . What he hath lost , Noble Macbeth hath wonne . Exeunt . Scena Terti
# ithin . 3 . A Drumme , a Drumme : Macbeth doth come All . The weyward Siste
# , the Charme ' s wound vp . Enter Macbeth and Banquo . Macb . So foule and
# an : what are you ? 1 . All haile Macbeth , haile to thee Thane of Glamis 2
# hee Thane of Glamis 2 . All haile Macbeth , haile to thee Thane of Cawdor 3
# hee Thane of Cawdor 3 . All haile Macbeth , that shalt be King hereafter Ba
# . Hayle 3 . Hayle 1 . Lesser than Macbeth , and greater 2 . Not so happy ,
# hough thou be none : So all haile Macbeth , and Banquo 1 . Banquo , and Mac
# eth , and Banquo 1 . Banquo , and Macbeth , all haile Macb . Stay you imper
# he King hath happily receiu ' d , Macbeth , The newes of thy successe : and
# gh the roughest Day Banq . Worthy Macbeth , wee stay vpon your leysure Macb
# I built An absolute Trust . Enter Macbeth , Banquo , Rosse , and Angus . O
# ke , To cry , hold , hold . Enter Macbeth . Great Glamys , worthy Cawdor ,
# ruice ouer the Stage . Then enter Macbeth Macb . If it were done , when ' t
# re giues way to in repose . Enter Macbeth , and a Seruant with a Torch . Gi
# hether they liue , or dye . Enter Macbeth . Macb . Who ' s there ? what hoa
# ard a voyce cry , Sleep no more : Macbeth does murther Sleepe , the innocen
# ore Cawdor Shall sleepe no more : Macbeth shall sleepe no more Lady . Who w
#  made a Shift to cast him . Enter Macbeth . Macd . Is thy Master stirring ?
# selues : awake , awake , Exeunt . Macbeth and Lenox . Ring the Alarum Bell

# %% [markdown]
# That's better. What about something a lot less frequent?

# %%
print(countedWords[countedWords['word'] == 'donalbaine'])
macbethIndex.print_concordance('Donalbaine')
# Out:
#     count        word
# 80      7  donalbaine
# Displaying 7 of 7 matches:
# m within . Enter King Malcome , Donalbaine , Lenox , with attendants , mee
# Enter King , Lenox , Malcolme , Donalbaine , and Attendants . King . Is ex
# rches . Enter King , Malcolme , Donalbaine , Banquo , Lenox , Macduff , Ro
#  ' th ' second Chamber ? Lady . Donalbaine Mac . This is a sorry sight Lad
# er , and Treason , Banquo , and Donalbaine : Malcolme awake , Shake off th
# to brag of . Enter Malcolme and Donalbaine . Donal . What is amisse ? Macb
# were subborned , Malcolme , and Donalbaine the Kings two Sonnes Are stolne

# %% [markdown]
# # Getting and working with raw text
#
# First, we will retrieve a collection of press releases from a *GitHub API* that archived them, based on a number of analyses by Justin Grimmer, a political scientist whose work we will read next week, and who will be joining the University of Chicago next July!
#
# GitHub API requests are made to `'https://api.github.com/'` and responses are in JSON, similar to Tumblr's API.
#
# We will get the information on [github.com/lintool/GrimmerSenatePressReleases](https://github.com/lintool/GrimmerSenatePressReleases) as it contains a nice set documents.

# %%
r = requests.get('https://api.github.com/repos/lintool/GrimmerSenatePressReleases')
senateReleasesData = json.loads(r.text)
print(senateReleasesData.keys())
print(senateReleasesData['description'])
# Out:
# dict_keys(['id', 'name', 'full_name', 'owner', 'private', 'html_url', 'description', 'fork', 'url', 'forks_url', 'keys_url', 'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url', 'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url', 'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url', 'languages_url', 'stargazers_url', 'contributors_url', 'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url', 'comments_url', 'issue_comment_url', 'contents_url', 'compare_url', 'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url', 'milestones_url', 'notifications_url', 'labels_url', 'releases_url', 'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url', 'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size', 'stargazers_count', 'watchers_count', 'language', 'has_issues', 'has_projects', 'has_downloads', 'has_wiki', 'has_pages', 'forks_count', 'mirror_url', 'archived', 'open_issues_count', 'license', 'forks', 'open_issues', 'watchers', 'default_branch', 'network_count', 'subscribers_count'])
# Grimmer's Senate Press Releases

# %% [markdown]
# What we are interested in here is the `'contents_url'`

# %%
print(senateReleasesData['contents_url'])
# Out:
# https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/{+path}

# %% [markdown]
# We can use this to get any or all of the files from the repo.

# %%
r = requests.get('https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Whitehouse')
whitehouseLinks = json.loads(r.text)
whitehouseLinks[0]
# Out:
# {'_links': {'git': 'https://api.github.com/repos/lintool/GrimmerSenatePressReleases/git/blobs/f524289ee563dca58690c8d36c23dce5dbd9962a',
#   'html': 'https://github.com/lintool/GrimmerSenatePressReleases/blob/master/raw/Whitehouse/10Apr2007Whitehouse123.txt',
#   'self': 'https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Whitehouse/10Apr2007Whitehouse123.txt?ref=master'},
#  'download_url': 'https://raw.githubusercontent.com/lintool/GrimmerSenatePressReleases/master/raw/Whitehouse/10Apr2007Whitehouse123.txt',
#  'git_url': 'https://api.github.com/repos/lintool/GrimmerSenatePressReleases/git/blobs/f524289ee563dca58690c8d36c23dce5dbd9962a',
#  'html_url': 'https://github.com/lintool/GrimmerSenatePressReleases/blob/master/raw/Whitehouse/10Apr2007Whitehouse123.txt',
#  'name': '10Apr2007Whitehouse123.txt',
#  'path': 'raw/Whitehouse/10Apr2007Whitehouse123.txt',
#  'sha': 'f524289ee563dca58690c8d36c23dce5dbd9962a',
#  'size': 2206,
#  'type': 'file',
#  'url': 'https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Whitehouse/10Apr2007Whitehouse123.txt?ref=master'}

# %% [markdown]
# Now we have a list of information about Whitehouse press releases. Let's look at one of them.

# %%
r = requests.get(whitehouseLinks[0]['download_url'])
whitehouseRelease = r.text
print(whitehouseRelease[:1000])
len(whitehouseRelease)
# Out:
# SEN. WHITEHOUSE SHARES WESTERLY GIRL'S STORY IN PUSH FOR STEM CELL RESEARCH
#   Sharing the story of Lila Barber, a 12 year old girl from Westerly, Sen. Sheldon Whitehouse (D-R.I.) on Tuesday, April 10, 2007, illustrated the hope stem cell research can offer in a speech on the Senate floor in favor of legislation to expand federal funding for stem cell research.
#    Whitehouse met Lila two weeks ago. She was diagnosed two years ago with osteosarcoma, a cancerous bone condition, and last year underwent cadaver bone transplant surgery. The procedure saved her leg and is helping her remain cancer-free, but the transplanted tissue will not grow with her and likely will break down over time. Stem cell research, Whitehouse explained, could vastly improve the care of patients like Lila by allowing surgeons to enhance transplants with a patient's own stem cells, which could replace the lost bone and cartilage, or grow entirely new replacement bones and joints.
#    "Stem cell research gives hope
# 2206

# %% [markdown]
# Now we have a string of correctly encoded text, similar to those we constructed from last week's assignment. For analysis of its words, next we need to tokenize it, or to split it into a sequence of tokens or word instances.

# %%
whTokens = nltk.word_tokenize(whitehouseRelease)
whTokens[10:30]
# Out:
# ['STEM',
#  'CELL',
#  'RESEARCH',
#  'Sharing',
#  'the',
#  'story',
#  'of',
#  'Lila',
#  'Barber',
#  ',',
#  'a',
#  '12',
#  'year',
#  'old',
#  'girl',
#  'from',
#  'Westerly',
#  ',',
#  'Sen.',
#  'Sheldon']

# %% [markdown]
# `whTokens` is a list of 'words' constructed from nltk's `word_tokenize` method built on the [Penn Treebank tokenizer](http://www.nltk.org/api/nltk.tokenize.html#module-nltk.tokenize.treebank). While it's better than `.split(' ')`, a general python string method that splits on whitespace, it is not perfect. There are many different ways to tokenize a string. `word_tokenize` is unfortunately unaware of sentences and is essentially a complicated regular expression (regex) run across the string.
#
# If we want to find sentences we can use something like `nltk.sent_tokenize()`, which implements the [Punkt Sentence tokenizer](http://www.nltk.org/api/nltk.tokenize.html#nltk.tokenize.punkt.PunktSentenceTokenizer), a machine learning based algorithm that works well for many European languages.
#
# We could also use the [Stanford tokenizer](http://www.nltk.org/api/nltk.tokenize.html#module-nltk.tokenize.stanford) or construct our own regex with [`RegexpTokenizer()`](http://www.nltk.org/api/nltk.tokenize.html#module-nltk.tokenize.regexp). Picking the correct tokenizer is important as the tokens form the base of our analysis.
#
# For our purposes in this example, the Penn Treebank tokenizer is fine.
#
# To use the list of tokens in `nltk`, and take advantage of functions like `concordance`, shown above, we can convert it into a `Text`.

# %%
whText = nltk.Text(whTokens)

whitehouseIndex = nltk.text.ConcordanceIndex(whText) 
whitehouseIndex.print_concordance('Whitehouse')
# Out:
# Displaying 5 of 5 matches:
# rl from Westerly , Sen. Sheldon Whitehouse ( D-R.I. ) on Tuesday , April 1
# unding for stem cell research . Whitehouse met Lila two weeks ago . She wa
# ver time . Stem cell research , Whitehouse explained , could vastly improv
# ch might help or even cure , '' Whitehouse said . Whitehouse also praised
# ven cure , '' Whitehouse said . Whitehouse also praised the efforts of Rho

# %% [markdown]
# *Note* that the `Text` class is for doing rapid, exploratory analysis. It provides an easy interface to many of the operations we want to do, but it does not allow us much control over the particular operations it glosses. When you are doing a more complete analysis, you should be using the module specifically designed for that task instead of the shortcut method `Text` provides, e.g. use  [`collocations` Module](http://www.nltk.org/api/nltk.html#module-nltk.collocations) instead of `.collocations()`.
#
# Now that we have gotten this loaded, let's glance at few features we will delve into more deeply later.
#
# For example, we can find words that statistically tend to occur together and typically have a composite, idiomatic meaning irreducible to the semantics of its component words. We will do this later with more control over exactly how these are identified.

# %%
whText.collocations()
# Out:
# Rhode Island; stem cells; cell research; Cell Enhancement; Enhancement
# Act; President Bush; Stem Cell; stem cell; Stem cell

# %% [markdown]
# Or we can pick a word (or words) and find what words tend to occur around it.

# %%
whText.common_contexts(['stem'])
# Out:
# for_cell hope_cell ._cell own_cells ``_cell of_cell on_cells the_cell
# embryonic_cells

# %% [markdown]
# We can also just count the number of times the word occurs.

# %%
whText.count('cell')
# Out:
# 5

# %% [markdown]
# We can also plot each time a set of words occurs.

# %%
sns.reset_orig() #Seaborn messes with this plot, disabling it
whText.dispersion_plot(['Sen.','stem', 'cell', 'federal' ,'Lila', 'Barber', 'Whitehouse'])
sns.set() #Re-enabling seaborn

# %% [markdown]
# If we want to do an analysis of all the Whitehouse press releases we will first need to obtain them. By looking at the API we can see the the URL we want is [https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Whitehouse](https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Whitehouse), so we can create a function to scrape the individual files.
#
# If you want to know more about downloading from APIs, refer back to the 1st notebook.

# %%
def getGithubFiles(target, maxFiles = 100):
    #We are setting a max so our examples don't take too long to run
    #For converting to a DataFrame
    releasesDict = {
        'name' : [], #The name of the file
        'text' : [], #The text of the file, watch out for binary files
        'path' : [], #The path in the git repo to the file
        'html_url' : [], #The url to see the file on Github
        'download_url' : [], #The url to download the file
    }

    #Get the directory information from Github
    r = requests.get(target)
    filesLst = json.loads(r.text)

    for fileDict in filesLst[:maxFiles]:
        #These are provided by the directory
        releasesDict['name'].append(fileDict['name'])
        releasesDict['path'].append(fileDict['path'])
        releasesDict['html_url'].append(fileDict['html_url'])
        releasesDict['download_url'].append(fileDict['download_url'])

        #We need to download the text though
        text = requests.get(fileDict['download_url']).text
        releasesDict['text'].append(text)

    return pandas.DataFrame(releasesDict)

whReleases = getGithubFiles('https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Whitehouse', maxFiles = 10)
whReleases[:2]
# Out:
#                                         download_url  \
# 0  https://raw.githubusercontent.com/lintool/Grim...
# 1  https://raw.githubusercontent.com/lintool/Grim...
#
#                                             html_url  \
# 0  https://github.com/lintool/GrimmerSenatePressR...
# 1  https://github.com/lintool/GrimmerSenatePressR...
#
#                          name                                       path  \
# 0  10Apr2007Whitehouse123.txt  raw/Whitehouse/10Apr2007Whitehouse123.txt
# 1    10Apr2008Whitehouse2.txt    raw/Whitehouse/10Apr2008Whitehouse2.txt
#
#                                                 text
# 0  SEN. WHITEHOUSE SHARES WESTERLY GIRL'S STORY I...
# 1  SEN. WHITEHOUSE SAYS PRESIDENT BUSH MUST BEGIN...

# %% [markdown]
# If you are having trouble downloading the data uncomment this next cell

# %%
#whReleases = pandas.read_csv('../data/whReleases.csv')

# %% [markdown]
# Now we have all the texts in a DataFrame we can look at a few things.
#
# First let's tokenize the texts with the same tokenizer as we used before. We will just save the tokens as a list for now; no need to convert to `Text`s.

# %%
whReleases['tokenized_text'] = whReleases['text'].apply(lambda x: nltk.word_tokenize(x))

# %% [markdown]
# Now lets see how long each of the press releases is:

# %%
whReleases['word_counts'] = whReleases['tokenized_text'].apply(lambda x: len(x))
whReleases['word_counts']
# Out:
# 0    397
# 1    344
# 2    553
# 3    216
# 4    257
# 5    380
# 6    270
# 7    521
# 8    484
# 9    482
# Name: word_counts, dtype: int64

# %%
whReleases.head(2)
# Out:
#                                         download_url  \
# 0  https://raw.githubusercontent.com/lintool/Grim...
# 1  https://raw.githubusercontent.com/lintool/Grim...
#
#                                             html_url  \
# 0  https://github.com/lintool/GrimmerSenatePressR...
# 1  https://github.com/lintool/GrimmerSenatePressR...
#
#                          name                                       path  \
# 0  10Apr2007Whitehouse123.txt  raw/Whitehouse/10Apr2007Whitehouse123.txt
# 1    10Apr2008Whitehouse2.txt    raw/Whitehouse/10Apr2008Whitehouse2.txt
#
#                                                 text  \
# 0  SEN. WHITEHOUSE SHARES WESTERLY GIRL'S STORY I...
# 1  SEN. WHITEHOUSE SAYS PRESIDENT BUSH MUST BEGIN...
#
#                                       tokenized_text  word_counts
# 0  [SEN., WHITEHOUSE, SHARES, WESTERLY, GIRL, 'S,...          397
# 1  [SEN., WHITEHOUSE, SAYS, PRESIDENT, BUSH, MUST...          344

# %% [markdown]
# ## <span style="color:red">*Exercise 1*</span>
#
# <span style="color:red">Construct cells immediately below this that input and interrogate a corpus relating to your anticipated final project. Turn your text into an nltk `Text` object, and explore all of the features examined above, and others that relate to better understanding your corpus in relation to your research question. </span>

# %% [markdown]
# ## <span style="color:blue">Notes 1.1</span>
# <span style="color:blue">We will be working with newspaper articles from around the world, and analyze how they portray climate change, a common global issue, in a similar or different manner. We manually downloaded about 100 articles (14 - 15 from each of 7 countries) and parsed the .html files to filter out the texts that we need into the 'news' dataframe.</span>

# %%
news = pandas.read_csv('news.csv', encoding='latin1')
news = news[['region','source','author','date','section','title','text']]

# %%
news.head()
# Out:
#          region                            source               author  \
# 0  Saudi Arabia  Arab News (Jedda, Saudi Arabia)                  NEWS
# 1  Saudi Arabia  Arab News (Jedda, Saudi Arabia)          Aaron Cosbey
# 2  Saudi Arabia  Arab News (Jedda, Saudi Arabia)         Bjorn Lomborg
# 3  Saudi Arabia  Arab News (Jedda, Saudi Arabia)        Cornelia Meyer
# 4  Saudi Arabia  Arab News (Jedda, Saudi Arabia)   Kerry Boyd Anderson
#
#                      date section  \
# 0  ['September 21, 2017']   World
# 1    ['November 4, 2017']    NEWS
# 2                      []    NEWS
# 3                      []    NEWS
# 4   ['November 14, 2017']    NEWS
#
#                                                title  \
# 0  Climate change tops the agenda at Bloomberg Bu...
# 1                        Warm fronts know no borders
# 2              A climate cure worse than the disease
# 3           Climate change battle goes on without US
# 4  Drought¡¯s contribution to growing risks of co...
#
#                                                 text
# 0  Frank Kane     NEW YORK: Climate change domina...
# 1  Climate change may be the most difficult and u...
# 2  Two years after the Paris climate agreement wa...
# 3  On Tuesday, French President Emmanuel Macron c...
# 4  A report released earlier this month by the En...

# %%
news['tokenized_text'] = news['text'].apply(lambda x: nltk.word_tokenize(x.lower()))
news['word_counts'] = news['tokenized_text'].apply(lambda x: len(x))

# %%
news.head()
# Out:
#          region                            source               author  \
# 0  Saudi Arabia  Arab News (Jedda, Saudi Arabia)                  NEWS
# 1  Saudi Arabia  Arab News (Jedda, Saudi Arabia)          Aaron Cosbey
# 2  Saudi Arabia  Arab News (Jedda, Saudi Arabia)         Bjorn Lomborg
# 3  Saudi Arabia  Arab News (Jedda, Saudi Arabia)        Cornelia Meyer
# 4  Saudi Arabia  Arab News (Jedda, Saudi Arabia)   Kerry Boyd Anderson
#
#                      date section  \
# 0  ['September 21, 2017']   World
# 1    ['November 4, 2017']    NEWS
# 2                      []    NEWS
# 3                      []    NEWS
# 4   ['November 14, 2017']    NEWS
#
#                                                title  \
# 0  Climate change tops the agenda at Bloomberg Bu...
# 1                        Warm fronts know no borders
# 2              A climate cure worse than the disease
# 3           Climate change battle goes on without US
# 4  Drought¡¯s contribution to growing risks of co...
#
#                                                 text  \
# 0  Frank Kane     NEW YORK: Climate change domina...
# 1  Climate change may be the most difficult and u...
# 2  Two years after the Paris climate agreement wa...
# 3  On Tuesday, French President Emmanuel Macron c...
# 4  A report released earlier this month by the En...
#
#                                       tokenized_text  word_counts
# 0  [frank, kane, new, york, :, climate, change, d...          714
# 1  [climate, change, may, be, the, most, difficul...          904
# 2  [two, years, after, the, paris, climate, agree...         1127
# 3  [on, tuesday, ,, french, president, emmanuel, ...          957
# 4  [a, report, released, earlier, this, month, by...         1046

# %% [markdown]
# ## <span style="color:blue">Notes 1.2</span>
# <span style="color:blue"> Basic analyses were done the ‘most relevant’ articles on climate change from Saudi Arabia and China (15 from the most reputable English language newspaper from each country). Regarding the number of words used in the articles, the pattern looked very similar to the patterns found in the text of Macbeth (or any text). The most frequent word was ‘the’ in both datasets, followed by stop words and punctuations. ‘climate’ and ‘change’ appeared very frequently (were emphasized more?) in the Chinese newspaper, but not in the Saudi one. Zipf’s law was replicated in both datasets, including a more-or-less linear log-log graph.</span>
#
# <span style="color:blue">Regarding the most frequent bi-grams appearing in each dataset, we see similar groups of climate change related words appearing in both sets, though interestingly Saudi Arabia mentioned 'trade agreement' while China mentioned 'national security' frequently. Regarding the dispersion of specific words in an article (the top ‘most relevant’ one from each country), we can see that climate and change are both mentioned throughout both the articles. Interestingly, the word ‘trump’ was mentioned sporadically in the Saudi article, though the word ‘saudi’ itself was not. Conversely, the word ‘trump’ was not mentioned at all in the Chinese article, while the word ‘china’ was mentioned consistently and as much as ‘climate’ in the Chinese article. There is much more self-referencing in the Chinese article, something that might be interesting to analyze further (self-referencing vs referencing other countries).
# </span>

# %%
saudWords = []
chinaWords = []
for i in range(15):
    saudWords.extend(news.loc[i,'tokenized_text'])
    chinaWords.extend(news.loc[i+15,'tokenized_text'])
    
topWords = wordCounter(saudWords) #15 articles from Saudi Arabia
topWords.sort_values('count', ascending=False, inplace=True)
topWords1 = wordCounter(chinaWords) #15 articles from China
topWords1.sort_values('count', ascending=False, inplace=True)

print('Saudi')
display(topWords[:10])
print('China')
display(topWords1[:10])
# Out:
# Saudi
#      count  word
# 8      779   the
# 19     647     ,
# 34     466     .
# 11     372    of
# 49     358    to
# 23     343   and
# 16     249    in
# 43     229     a
# 105    179  that
# 102    163    is
# China
#     count     word
# 4     647      the
# 17    512        ,
# 9     326        .
# 11    305       to
# 6     249       of
# 62    238      and
# 7     182  climate
# 95    178       in
# 69    167        a
# 8     130   change

# %%
saudWords
# Out:
# ['frank',
#  'kane',
#  'new',
#  'york',
#  ':',
#  'climate',
#  'change',
#  'dominated',
#  'the',
#  'opening',
#  'stages',
#  'of',
#  'the',
#  'bloomberg',
#  'global',
#  'business',
#  'forum',
#  'in',
#  'new',
#  'york',
#  'on',
#  'wednesday',
#  ',',
#  'as',
#  'many',
#  'of',
#  'the',
#  '250',
#  'business',
#  'and',
#  'political',
#  'leaders',
#  'assembled',
#  'for',
#  'the',
#  'event',
#  'criticized',
#  'the',
#  'trump',
#  'administration¡¯s',
#  'stance',
#  'on',
#  'the',
#  'issue',
#  '.',
#  'michael',
#  'bloomberg',
#  ',',
#  'the',
#  'media',
#  'entrepreneur',
#  'and',
#  'former',
#  'three-time',
#  'mayor',
#  'of',
#  'the',
#  'city',
#  ',',
#  'announced',
#  'a',
#  'partnership',
#  'with',
#  'the',
#  'world',
#  'bank',
#  'and',
#  'the',
#  'un',
#  'to',
#  'fund',
#  'urban',
#  'infrastructure',
#  'development',
#  'to',
#  'take',
#  'account',
#  'of',
#  'accelerating',
#  'climate',
#  'change',
#  ',',
#  'especially',
#  'in',
#  'emerging',
#  'markets',
#  'where',
#  'cities',
#  'often',
#  'struggle',
#  'to',
#  'get',
#  'access',
#  'to',
#  'funding',
#  '.',
#  'he',
#  'said',
#  ':',
#  '¡°cities',
#  'account',
#  'for',
#  '70',
#  'percent',
#  'of',
#  'carbon',
#  'emissions',
#  'in',
#  'the',
#  'world',
#  ',',
#  'so',
#  'they',
#  'are',
#  'part',
#  'of',
#  'the',
#  'problem',
#  ',',
#  'but',
#  'they',
#  'are',
#  'also',
#  'big',
#  'financial',
#  'centers',
#  ',',
#  'so',
#  'they',
#  'are',
#  'part',
#  'of',
#  'the',
#  'solution',
#  'too',
#  '.',
#  'new',
#  'york',
#  'has',
#  'reduced',
#  'carbon',
#  'emissions',
#  'by',
#  '20',
#  'percent',
#  'in',
#  'seven',
#  'years',
#  ',',
#  'and',
#  'it',
#  'would',
#  'have',
#  'been',
#  'faster',
#  'if',
#  'the',
#  'city',
#  'had',
#  'more',
#  'access',
#  'to',
#  'funding',
#  '.',
#  '¡°in',
#  'the',
#  'developing',
#  'world',
#  ',',
#  'it',
#  'is',
#  'even',
#  'more',
#  'the',
#  'case',
#  'that',
#  'cities',
#  'need',
#  'access',
#  'to',
#  'greater',
#  'funding',
#  'to',
#  'fight',
#  'climate',
#  'change',
#  ',',
#  'but',
#  'they',
#  'do',
#  'not',
#  'have',
#  'the',
#  'credit',
#  'profile',
#  'to',
#  'get',
#  'that.¡±',
#  'on',
#  'the',
#  'main',
#  'issue',
#  'of',
#  'climate',
#  'change',
#  ',',
#  'bloomberg',
#  'said',
#  'that',
#  'there',
#  'had',
#  'been',
#  '¡°pushback¡±',
#  'from',
#  'the',
#  'current',
#  'white',
#  'house',
#  '.',
#  '¡°i',
#  'can',
#  'not',
#  'speak',
#  'for',
#  'the',
#  'current',
#  'administration',
#  ',',
#  'but',
#  'it¡¯s',
#  'new',
#  'and',
#  'is',
#  'realizing',
#  'that',
#  'these',
#  'problems',
#  'are',
#  'complex',
#  ',',
#  'so',
#  'it',
#  'gets',
#  'laughed',
#  'at',
#  '.',
#  'but',
#  'trump',
#  'has',
#  'done',
#  'climate',
#  'change',
#  'people',
#  'a',
#  'great',
#  'favor',
#  'because',
#  'he',
#  'has',
#  'galvanized',
#  'them.¡±',
#  'the',
#  'city',
#  'climate',
#  'finance',
#  'plan',
#  'is',
#  'a',
#  'partnership',
#  'between',
#  'bloomberg',
#  'philanthropies',
#  ',',
#  'his',
#  'charitable',
#  'operation',
#  ',',
#  'the',
#  'world',
#  'bank',
#  'and',
#  'the',
#  'un',
#  '.',
#  'it',
#  'hopes',
#  'to',
#  'have',
#  'definitive',
#  'plans',
#  'for',
#  'climate',
#  'change',
#  'investment',
#  'later',
#  'this',
#  'year',
#  ',',
#  'the',
#  'president',
#  'jim',
#  'kim',
#  'said',
#  '.',
#  'other',
#  'leaders',
#  'addressed',
#  'themes',
#  'including',
#  'globalization',
#  ',',
#  'immigration',
#  'and',
#  'inclusion',
#  ',',
#  'all',
#  'of',
#  'which',
#  'have',
#  'been',
#  'hot',
#  'topics',
#  'under',
#  'the',
#  'trump',
#  'administration',
#  '.',
#  'former',
#  'president',
#  'bill',
#  'clinton',
#  'said',
#  ':',
#  '¡°we',
#  'are',
#  'all',
#  'well',
#  'aware',
#  'that',
#  'a',
#  'lot',
#  'of',
#  'people',
#  'feel',
#  'left',
#  'out',
#  ',',
#  'left',
#  'behind',
#  ',',
#  'alienated',
#  'politically',
#  ',',
#  'socially',
#  'and',
#  'economically.¡±',
#  'tim',
#  'cook',
#  ',',
#  'chief',
#  'executive',
#  'of',
#  'apple',
#  ',',
#  'said',
#  'that',
#  'recent',
#  'moves',
#  'to',
#  'change',
#  'immigration',
#  'status',
#  'for',
#  'the',
#  'children',
#  'of',
#  'illegal',
#  'immigrants',
#  '?',
#  'the',
#  'so-called',
#  '¡°dreamers¡±',
#  '?',
#  'were',
#  'wrong',
#  '.',
#  '¡°i',
#  'am',
#  'personally',
#  'shocked',
#  'there',
#  'was',
#  'even',
#  'a',
#  'discussion',
#  ',',
#  '¡±',
#  'he',
#  'said',
#  '.',
#  '¡°this',
#  'debate',
#  'goes',
#  'to',
#  'the',
#  'basis',
#  'of',
#  'american',
#  'values',
#  '.',
#  'i',
#  'wish',
#  'everyone',
#  'loved',
#  'america',
#  'as',
#  'much',
#  'as',
#  'the',
#  '¡®dreamers.¡¯¡±',
#  'bloomberg',
#  'agreed',
#  ':',
#  '¡°they',
#  'may',
#  'be',
#  'here',
#  'illegally',
#  'but',
#  'they',
#  'have',
#  'committed',
#  'no',
#  'crime',
#  '.',
#  'we',
#  'need',
#  'this',
#  'new',
#  'blood',
#  'coming',
#  'into',
#  'our',
#  'country.¡±',
#  'other',
#  'business',
#  'leaders',
#  'spoke',
#  'of',
#  'the',
#  'need',
#  'to',
#  'address',
#  'the',
#  'problems',
#  'of',
#  '¡°big',
#  'data¡±',
#  'and',
#  'digital',
#  'change',
#  'in',
#  'the',
#  'global',
#  'economy',
#  '.',
#  'jack',
#  'ma',
#  ',',
#  'founder',
#  'and',
#  'chief',
#  'executive',
#  'of',
#  'chinese',
#  'online',
#  'retailer',
#  'ali',
#  'baba',
#  ',',
#  'said',
#  'that',
#  'the',
#  'digital',
#  'age',
#  'should',
#  'be',
#  'regarded',
#  'as',
#  'an',
#  'opportunity',
#  ',',
#  'not',
#  'a',
#  'threat',
#  '.',
#  '¡°people',
#  'are',
#  'worried',
#  'about',
#  'big',
#  'data',
#  ',',
#  'but',
#  'people',
#  'in',
#  'history',
#  'were',
#  'worried',
#  'about',
#  'steam',
#  'and',
#  'electricity',
#  '.',
#  'but',
#  'all',
#  'three',
#  'have',
#  'led',
#  'to',
#  'an',
#  'increase',
#  'in',
#  'employment.¡±',
#  'christine',
#  'lagarde',
#  ',',
#  'managing',
#  'director',
#  'of',
#  'the',
#  'international',
#  'monetary',
#  'fund',
#  ',',
#  'also',
#  'defended',
#  'globalization',
#  'in',
#  'trade',
#  'and',
#  'business',
#  '.',
#  'justin',
#  'trudeau',
#  ',',
#  'prime',
#  'minister',
#  'of',
#  'canada',
#  ',',
#  'who',
#  'is',
#  'due',
#  'to',
#  'sign',
#  'a',
#  'trade',
#  'agreement',
#  'with',
#  'the',
#  'eu',
#  ',',
#  'agreed',
#  'with',
#  'her',
#  'that',
#  'the',
#  'world',
#  'needed',
#  'more',
#  'such',
#  'free',
#  'trade',
#  'agreements',
#  '.',
#  '¡°we',
#  'have',
#  'to',
#  '¡¦',
#  'eliminate',
#  'barriers',
#  ',',
#  'but',
#  'also',
#  'ensure',
#  'jobs',
#  ',',
#  'gender',
#  'equality',
#  'and',
#  'growth',
#  ',',
#  '¡±',
#  'he',
#  'said',
#  '.',
#  'other',
#  'speakers',
#  'pointed',
#  'to',
#  'the',
#  'imbalances',
#  'in',
#  'the',
#  'global',
#  'financial',
#  'system',
#  '.',
#  'arif',
#  'naqvi',
#  ',',
#  'founder',
#  'and',
#  'chief',
#  'executive',
#  'officer',
#  'of',
#  'dubai-based',
#  'private',
#  'equity',
#  'group',
#  'abraaj',
#  ',',
#  'said',
#  ':',
#  '¡°the',
#  'plumbing',
#  'of',
#  'the',
#  'world',
#  'financial',
#  'system',
#  'is',
#  'broken',
#  '.',
#  'there',
#  'is',
#  '$',
#  '9',
#  'trillion',
#  'of',
#  'investment',
#  'value',
#  'sitting',
#  'in',
#  'non-interest',
#  'bearing',
#  'assets',
#  '.',
#  'there',
#  'are',
#  'lots',
#  'of',
#  'other',
#  'investment',
#  'opportunities',
#  'being',
#  'missed',
#  'in',
#  'the',
#  'fast',
#  'growth',
#  'markets.¡±',
#  'larry',
#  'fink',
#  ',',
#  'chief',
#  'executive',
#  'officer',
#  'of',
#  'investment',
#  'group',
#  'blackrock',
#  ',',
#  'warned',
#  'against',
#  'the',
#  'rise',
#  'of',
#  'protectionism',
#  'and',
#  'exclusion',
#  'in',
#  'the',
#  'world',
#  '.',
#  '¡°more',
#  'than',
#  '50',
#  'per',
#  'cent',
#  'of',
#  'family',
#  'assets',
#  'round',
#  'the',
#  'world',
#  'are',
#  'managed',
#  'by',
#  'women',
#  '.',
#  'we',
#  'need',
#  'more',
#  'women',
#  'on',
#  'our',
#  'boards.¡±',
#  'copyright',
#  ':',
#  'arab',
#  'news',
#  'climate',
#  'change',
#  'may',
#  'be',
#  'the',
#  'most',
#  'difficult',
#  'and',
#  'urgent',
#  'challenge',
#  'facing',
#  'mankind',
#  'today',
#  '.',
#  'the',
#  'current',
#  'global',
#  'plan',
#  'for',
#  'action',
#  '?',
#  'the',
#  '2015',
#  'paris',
#  'agreement',
#  '?',
#  'calls',
#  'for',
#  'an',
#  'economic',
#  'and',
#  'social',
#  'transformation',
#  'on',
#  'the',
#  'scale',
#  'of',
#  'the',
#  'industrial',
#  'revolution',
#  ',',
#  'but',
#  'squeezed',
#  'into',
#  'a',
#  'much',
#  'more',
#  'disruptive',
#  '?',
#  'and',
#  'tighter',
#  '?',
#  'timeframe',
#  '.',
#  'for',
#  'that',
#  'to',
#  'happen',
#  ',',
#  'all',
#  'silos',
#  'of',
#  'government',
#  'policy',
#  'will',
#  'have',
#  'to',
#  'open',
#  'up',
#  ',',
#  'and',
#  'those',
#  'outside',
#  'of',
#  'environment',
#  'ministries',
#  'will',
#  'need',
#  'to',
#  'ask',
#  'themselves',
#  'what',
#  'they',
#  'might',
#  'do',
#  'to',
#  'ease',
#  'the',
#  'transition',
#  '.',
#  'that',
#  'message',
#  'seems',
#  'to',
#  'be',
#  'lost',
#  'on',
#  'trade',
#  'ministries',
#  '?',
#  'those',
#  'in',
#  'charge',
#  'of',
#  'negotiating',
#  'international',
#  'trade',
#  'agreements',
#  ',',
#  'such',
#  'as',
#  'world',
#  'trade',
#  'organization',
#  '(',
#  'wto',
#  ')',
#  'treaties',
#  ',',
#  'and',
#  'the',
#  'crop',
#  'of',
#  'new',
#  'regional',
#  'agreements',
#  'under',
#  'negotiation',
#  'or',
#  'just',
#  'completed',
#  '.',
#  'all',
#  'these',
#  'negotiations',
#  'seem',
#  'to',
#  'be',
#  'taking',
#  'place',
#  'in',
#  'some',
#  'pleasant',
#  'parallel',
#  'universe',
#  'where',
#  'climate',
#  'change',
#  'is',
#  'not',
#  'an',
#  'issue',
#  '.',
#  'the',
#  'problem',
#  'is',
#  'not',
#  'a',
#  'lack',
#  'of',
#  'potential',
#  'or',
#  'a',
#  'dearth',
#  'of',
#  'possibilities',
#  '.',
#  'one',
#  'obvious',
#  'possibility',
#  'is',
#  'an',
#  'agreement',
#  'on',
#  'environmental',
#  'goods',
#  '.',
#  'the',
#  'wto',
#  'has',
#  'been',
#  'trying',
#  'since',
#  '2001',
#  'to',
#  'lower',
#  'tariffs',
#  'on',
#  'environmental',
#  'goods',
#  'such',
#  'as',
#  'solar',
#  'panels',
#  'and',
#  'geothermal',
#  'pumps',
#  ',',
#  'and',
#  'a',
#  'smaller',
#  'group',
#  'of',
#  'wto',
#  'members',
#  'has',
#  'been',
#  'actively',
#  'trying',
#  'anew',
#  'since',
#  '2014.',
#  'the',
#  'payoff',
#  '?',
#  'faster',
#  'dissemination',
#  'of',
#  'critically',
#  'needed',
#  'green',
#  'technologies',
#  '.',
#  'but',
#  'progress',
#  'is',
#  'stalled',
#  ';',
#  'when',
#  'the',
#  'negotiators',
#  'get',
#  'to',
#  'the',
#  'table',
#  ',',
#  'they',
#  'forget',
#  'that',
#  'the',
#  'environment',
#  'is',
#  'the',
#  'goal',
#  'and',
#  'revert',
#  'to',
#  'promoting',
#  'their',
#  'narrow',
#  'economic',
#  'interests',
#  '.',
#  'this',
#  'is',
#  'a',
#  'question',
#  'of',
#  'political',
#  'will',
#  '.',
#  'in',
#  'the',
#  'wto',
#  'and',
#  'in',
#  'other',
#  'agreements',
#  ',',
#  'parties',
#  'should',
#  'agree',
#  'on',
#  'what',
#  'goods',
#  'are',
#  '``',
#  'green',
#  "''",
#  'and',
#  'reduce',
#  'tariffs',
#  'to',
#  'zero',
#  '.',
#  'they',
#  ...]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(range(len(topWords)), topWords['count'])
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(range(len(topWords1)), topWords1['count'])
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(range(len(topWords)), topWords['count'])
ax.set_yscale('log')
ax.set_xscale('log')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(range(len(topWords1)), topWords1['count'])
ax.set_yscale('log')
ax.set_xscale('log')
plt.show()

# %%
saudText = nltk.Text(news.loc[0,'tokenized_text']) # just the first article
climateIndex = nltk.text.ConcordanceIndex(saudText)
climateIndex.print_concordance('climate')
# Out:
# Displaying 7 of 7 matches:
#                                   climate change dominated the opening stag
# t to take account of accelerating climate change , especially in emerging m
# ccess to greater funding to fight climate change , but they do not have the
#  get that.¡± on the main issue of climate change , bloomberg said that ther
# s laughed at . but trump has done climate change people a great favor becau
# e has galvanized them.¡± the city climate finance plan is a partnership bet
# opes to have definitive plans for climate change investment later this year

# %%
chinaText = nltk.Text(news.loc[15,'tokenized_text']) # just the first article
climateIndex1 = nltk.text.ConcordanceIndex(chinaText)
climateIndex1.print_concordance('climate')
# Out:
# Displaying 25 of 25 matches:
#                                   climate change . according to the third n
# ird national assessment report on climate change , the average temperature
# tury . besides temperature rise , climate change has had other observable e
#  increasing risks of hurricanes . climate change therefore has a significan
# nomic growth . due to its complex climate conditions and fragile ecosystems
# cosystems , china is sensitive to climate change , with its agriculture bei
# articularly vulnerable . although climate change will improve thermal condi
# more frequent and intense extreme climate events . it is widely believed th
# widely believed the net effect of climate change on agriculture is negative
# ange on agriculture is negative . climate change therefore poses a huge cha
# ssment of the economic impacts of climate change on china 's agriculture an
# dress the challenge . the cost of climate change on china 's agriculture ha
# ences . the report 's authors say climate change is likely to decrease the
# th the challenge . the impacts of climate change on the three staple crops
# us across chinese regions . while climate change is harmful for rice produc
# heastern china could benefit from climate change . and while central china
# r moderate losses , the impact of climate change on southern china will be
# ions show the negative impacts of climate change , except for some counties
# everely affected . the impacts of climate change on rice , wheat , and corn
# nificance . and evidence suggests climate change can endanger china 's food
# not fill the supply gap caused by climate change . and if china has to rely
# government . given the impacts of climate change and potential risks , chin
#  mitigate the negative impacts of climate change and benefit from the posit
# l technology needs assessment for climate change adaptation , funded by the
# chnologies , china can reduce the climate risks on food security . the auth

# %%
saudWords2 = nltk.Text(saudWords)
saudWords2.collocations()
# Out:
# climate change; arab news; global warming; saudi arabia; carbon
# dioxide; new york; greenhouse gas; renewable energy; fossil fuels; gas
# emissions; philips lighting; trade agreements; last year; paris
# agreement; sea levels; rising sea; chief executive; sustainable
# development; michael bloomberg; donald trump

# %%
chinaWords2 = nltk.Text(chinaWords)
chinaWords2.collocations()
# Out:
# climate change; paris agreement; clean energy; united states; donald
# trump; president donald; greenhouse gas; global warming; gas
# emissions; temperature rise; united nations; last year; national
# security; china daily; fossil fuel; human activities; paris pact;
# european union; obama administration; carbon trading

# %%
saudWords2.common_contexts(['climate'])
# Out:
# :_change accelerating_change fight_change of_change done_change
# city_finance for_change news_change where_change mitigating_change
# new_laws address_change the_and paris_agreement stop_change
# than_change on_change 's_body ,_change the_policies

# %%
chinaWords2.common_contexts(['climate'])
# Out:
# of_change on_change ,_change ._change complex_conditions to_change
# although_change extreme_events say_change while_change from_change
# suggests_change by_change for_change the_risks global_change
# veteran_change paris_change us-china_change us-china_smart/low

# %%
# This is only for the first Saudi article
sns.reset_orig() 
saudText.dispersion_plot(['climate','change','energy','sustainable','oil','risk','trump','saudi'])
sns.set()

# %%
# This is only for the first Chinese article
chinaText.dispersion_plot(['climate','change','energy','sustainable','oil','risk','trump','china'])
sns.set()

# %% [markdown]
# # Filtering and normalizing text
#
# As we want to start comparing the different releases we may choose to do a bit of filtering and normalizing that will allow us to focus on what we most care about. We can first make all of the words lower case, then drop the non-word tokens. Next, we can remove some 'stop words', stem the remaining words to remove suffixes, prefixes and (in some languages) infixes, or lemmatize tokens by intelligently grouping inflected or variant forms of the same word (e.g., with a stemmer and a dictionary).
#
# To begin this process, we will first define a function to work over the tokenized lists, then another to add normalized tokens to a new column.

# %% [markdown]
# Nltk has a built-in list of stopwords. They are already imported in the import section. Let's first take a look at what they are.

# %%
print(', '.join(stopwords.words('english')))
# Out:
# i, me, my, myself, we, our, ours, ourselves, you, you're, you've, you'll, you'd, your, yours, yourself, yourselves, he, him, his, himself, she, she's, her, hers, herself, it, it's, its, itself, they, them, their, theirs, themselves, what, which, who, whom, this, that, that'll, these, those, am, is, are, was, were, be, been, being, have, has, had, having, do, does, did, doing, a, an, the, and, but, if, or, because, as, until, while, of, at, by, for, with, about, against, between, into, through, during, before, after, above, below, to, from, up, down, in, out, on, off, over, under, again, further, then, once, here, there, when, where, why, how, all, any, both, each, few, more, most, other, some, such, no, nor, not, only, own, same, so, than, too, very, s, t, can, will, just, don, don't, should, should've, now, d, ll, m, o, re, ve, y, ain, aren, aren't, couldn, couldn't, didn, didn't, doesn, doesn't, hadn, hadn't, hasn, hasn't, haven, haven't, isn, isn't, ma, mightn, mightn't, mustn, mustn't, needn, needn't, shan, shan't, shouldn, shouldn't, wasn, wasn't, weren, weren't, won, won't, wouldn, wouldn't

# %% [markdown]
# We can remove these stopwords from the analysis by fiat, but we could also take a more principled approach by looking at the frequency distribution of words and selecting a specific cut-off associated with the preservation of 'meaningful words' identified upon inspection. Alternatively, we could automatically set a cut-off by rule, such as removal of all words more frequent then the most frequent verb, or the most frequent noun (not pronoun), or some term of central interest.

# %% [markdown]
# Lets generate our own stop list now.

# %%
countsDict = {}
for word in whReleases['tokenized_text'].sum():
    if word in countsDict:
        countsDict[word] += 1
    else:
        countsDict[word] = 1
word_counts = sorted(countsDict.items(), key = lambda x : x[1], reverse = True)
word_counts[:20]
# Out:
# [('the', 179),
#  (',', 173),
#  ('.', 136),
#  ('of', 112),
#  ('to', 112),
#  ('and', 108),
#  ('in', 64),
#  ('a', 61),
#  ("'s", 50),
#  ('that', 41),
#  ('our', 39),
#  ('for', 35),
#  ('on', 33),
#  ('is', 33),
#  ('Whitehouse', 31),
#  ('``', 30),
#  ('Iraq', 28),
#  ('Bush', 27),
#  ('President', 25),
#  ('(', 24)]

# %% [markdown]
# We can look at this and pick the cutoff, usually it is at the first noun. So we will cut all words before `'Whitehouse'`.

# %%
#The stop list is then all words that occur before the first noun
stop_words_freq = []
for word, count in word_counts:
    if word == 'Whitehouse':
        break
    else:
        stop_words_freq.append(word)
stop_words_freq
wordnet = nltk.stem.WordNetLemmatizer()
wordnet.lemmatize('are')
# Out:
# 'are'

# %% [markdown]
# Now we can create our function to normalize the tokens

# %%
stop_words_nltk = stopwords.words('english')
#stop_words = ["the","it","she","he", "a"] #Uncomment this line if you want to use your own list of stopwords.

#The stemmers and lemmers need to be initialized before bing run
porter = nltk.stem.porter.PorterStemmer()
snowball = nltk.stem.snowball.SnowballStemmer('english')
wordnet = nltk.stem.WordNetLemmatizer()

def normlizeTokens(tokenLst, stopwordLst = None, stemmer = None, lemmer = None):
    #We can use a generator here as we just need to iterate over it

    #Lowering the case and removing non-words
    workingIter = (w.lower() for w in tokenLst if w.isalpha())

    #Now we can use the semmer, if provided
    if stemmer is not None:
        workingIter = (stemmer.stem(w) for w in workingIter)
        
    #And the lemmer
    if lemmer is not None:
        workingIter = (lemmer.lemmatize(w) for w in workingIter)
    
    #And remove the stopwords
    if stopwordLst is not None:
        workingIter = (w for w in workingIter if w not in stopwordLst)
    #We will return a list with the stopwords removed
    return list(workingIter)

# %%
whReleases['normalized_tokens'] = whReleases['tokenized_text'].apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, stemmer = porter))

whReleases['normalized_tokens_count'] = whReleases['normalized_tokens'].apply(lambda x: len(x))

whReleases.head(2)
# Out:
#                                         download_url  \
# 0  https://raw.githubusercontent.com/lintool/Grim...
# 1  https://raw.githubusercontent.com/lintool/Grim...
#
#                                             html_url  \
# 0  https://github.com/lintool/GrimmerSenatePressR...
# 1  https://github.com/lintool/GrimmerSenatePressR...
#
#                          name                                       path  \
# 0  10Apr2007Whitehouse123.txt  raw/Whitehouse/10Apr2007Whitehouse123.txt
# 1    10Apr2008Whitehouse2.txt    raw/Whitehouse/10Apr2008Whitehouse2.txt
#
#                                                 text  \
# 0  SEN. WHITEHOUSE SHARES WESTERLY GIRL'S STORY I...
# 1  SEN. WHITEHOUSE SAYS PRESIDENT BUSH MUST BEGIN...
#
#                                       tokenized_text  word_counts  \
# 0  [SEN., WHITEHOUSE, SHARES, WESTERLY, GIRL, 'S,...          397
# 1  [SEN., WHITEHOUSE, SAYS, PRESIDENT, BUSH, MUST...          344
#
#                                    normalized_tokens  normalized_tokens_count
# 0  [whitehous, share, westerli, girl, stori, push...                      231
# 1  [whitehous, say, presid, bush, must, begin, br...                      171

# %% [markdown]
# The stemmer we use here is called the [Porter Stemmer](http://www.nltk.org/api/nltk.stem.html#module-nltk.stem.porter), there are many others, including another good one by the same person (Martin Porter) called the [Snowball Stemmer](http://www.nltk.org/api/nltk.stem.html#module-nltk.stem.snowball) or 'another stemmer' called the [Lancaster Stemmer](http://www.nltk.org/_modules/nltk/stem/lancaster.html). We can also normalize our words by lemmatizing them, or matching word variants or inflected forms to a common morpheme in a dictionary like [WordNet](https://wordnet.princeton.edu) through intelligent stemming rules. (The WordNet function `morphy` returns the given word if it cannot be matched to a word in the dictionary).
#
# Now that it is cleaned we start analyzing the dataset. We can start by finding frequency distributions for the dataset. Lets start looking at all the press releases together. The [`ConditionalFreqDist`](http://www.nltk.org/api/nltk.html#nltk.probability.ConditionalProbDist) class reads in an iterable of tuples, the first element is the condition and the second the focal word. For starters, we will use word lengths as the conditions, but tags or clusters will provide more useful results.

# %%
#.sum() adds together the lists from each row into a single list
whcfdist = nltk.ConditionalFreqDist(((len(w), w) for w in whReleases['normalized_tokens'].sum()))

#print the number of words
print(whcfdist.N())
# Out:
# 2038

# %% [markdown]
# From this we can lookup the distributions of different word lengths

# %%
whcfdist[3].plot()

# %% [markdown]
# See that the most frequent 3-character word is "thi". But what is "thi"? It is actually "this" stemmed by the Porter Stemmer.

# %%
porter = nltk.stem.porter.PorterStemmer()
print (porter.stem('this'))
# Out:
# thi

# %% [markdown]
# Let's try with the Snowball Stemer. See that "this" is corretly stemmed as a 4-character word.

# %%
print (snowball.stem('this'))

whReleases['normalized_tokens'] = whReleases['tokenized_text'].apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, stemmer = snowball))
whReleases['normalized_tokens_count'] = whReleases['normalized_tokens'].apply(lambda x: len(x))
whcfdist = nltk.ConditionalFreqDist(((len(w), w) for w in whReleases['normalized_tokens'].sum()))
whcfdist[3].plot()
# Out:
# this

# %% [markdown]
# We can also create a Conditional Probability Distribution or [`ConditionalProbDist`](http://www.nltk.org/api/nltk.html#nltk.probability.ConditionalProbDist) from the `ConditionalFreqDist`. To do this, however, we need a model for the probability distribution. A simple model is [`ELEProbDist`](http://www.nltk.org/api/nltk.html#nltk.probability.ELEProbDist) which gives the expected likelihood estimate for the probability distribution of the experiment used to generate the observed frequency distribution.

# %%
whcpdist = nltk.ConditionalProbDist(whcfdist, nltk.ELEProbDist)

#print the most common 2 letter word
print(whcpdist[2].max())

#And its probability
print(whcpdist[2].prob(whcpdist[2].max()))
# Out:
# us
# 0.6470588235294118

# %% [markdown]
# Length is one feature of a word, but there are many more important features we care about. Another critical feature is a word's role in the sentence, or its part of speech (POS). Here, we will be classifying words according to their part of speech (POS), using the [`nltk.pos_tag()`](http://www.nltk.org/api/nltk.tag.html#nltk.tag.pos_tag). The tags used here are those from the [Brown Corpus tagset](http://www.scs.leeds.ac.uk/amalgam/tagsets/brown.html).

# %%
whReleases['normalized_tokens_POS'] = [nltk.pos_tag(t) for t in whReleases['normalized_tokens']]

# %%
whReleases.head(2)
# Out:
#                                         download_url  \
# 0  https://raw.githubusercontent.com/lintool/Grim...
# 1  https://raw.githubusercontent.com/lintool/Grim...
#
#                                             html_url  \
# 0  https://github.com/lintool/GrimmerSenatePressR...
# 1  https://github.com/lintool/GrimmerSenatePressR...
#
#                          name                                       path  \
# 0  10Apr2007Whitehouse123.txt  raw/Whitehouse/10Apr2007Whitehouse123.txt
# 1    10Apr2008Whitehouse2.txt    raw/Whitehouse/10Apr2008Whitehouse2.txt
#
#                                                 text  \
# 0  SEN. WHITEHOUSE SHARES WESTERLY GIRL'S STORY I...
# 1  SEN. WHITEHOUSE SAYS PRESIDENT BUSH MUST BEGIN...
#
#                                       tokenized_text  word_counts  \
# 0  [SEN., WHITEHOUSE, SHARES, WESTERLY, GIRL, 'S,...          397
# 1  [SEN., WHITEHOUSE, SAYS, PRESIDENT, BUSH, MUST...          344
#
#                                    normalized_tokens  normalized_tokens_count  \
# 0  [whitehous, share, wester, girl, stori, push, ...                      228
# 1  [whitehous, say, presid, bush, must, begin, br...                      166
#
#                                normalized_tokens_POS
# 0  [(whitehous, JJ), (share, NN), (wester, RBR), ...
# 1  [(whitehous, JJ), (say, VBP), (presid, JJ), (b...

# %% [markdown]
# This gives us a new column with the part of speech as a short initialism and the word in a tuple, exactly how the `nltk.ConditionalFreqDist()` function wants them. We can now construct another conditional frequency distribution.

# %%
whcfdist_WordtoPOS = nltk.ConditionalFreqDist(whReleases['normalized_tokens_POS'].sum())
list(whcfdist_WordtoPOS.items())[:10]
# Out:
# [('whitehous', FreqDist({'JJ': 39, 'NN': 1})),
#  ('share', FreqDist({'NN': 4})),
#  ('wester', FreqDist({'NN': 1, 'RBR': 1})),
#  ('girl', FreqDist({'NN': 2})),
#  ('stori', FreqDist({'FW': 2})),
#  ('push', FreqDist({'NN': 2})),
#  ('stem', FreqDist({'NN': 12})),
#  ('cell', FreqDist({'NN': 9, 'VBP': 3})),
#  ('research', FreqDist({'NN': 9})),
#  ('lila', FreqDist({'CD': 1, 'JJ': 1, 'NN': 2}))]

# %% [markdown]
# This gives the frequency of each word as each part of speech...which can be uninformative and boring.

# %%
whcfdist_WordtoPOS['administr'].plot()

# %% [markdown]
# What we want is the converse; the frequency of each part of speech for each word.

# %%
whcfdist_POStoWord = nltk.ConditionalFreqDist((p, w) for w, p in whReleases['normalized_tokens_POS'].sum())

# %% [markdown]
# We can now identify and collect all of the superlative adjectives

# %%
whcfdist_POStoWord['JJS']
# Out:
# FreqDist({'best': 1, 'strongest': 2})

# %% [markdown]
# Or look at the most common nouns

# %%
whcfdist_POStoWord['NN'].most_common(5)
# Out:
# [('bush', 24), ('presid', 23), ('iraq', 22), ('rhode', 18), ('island', 18)]

# %% [markdown]
# Or plot the base form verbs against their number of occurrences

# %%
whcfdist_POStoWord['VB'].plot()

# %% [markdown]
# We can then do a similar analysis of the word probabilities

# %%
whcpdist_POStoWord = nltk.ConditionalProbDist(whcfdist_POStoWord, nltk.ELEProbDist)

#print the most common nouns
print(whcpdist_POStoWord['NN'].max())

#And its probability
print(whcpdist_POStoWord['NN'].prob(whcpdist_POStoWord['NN'].max()))
# Out:
# bush
# 0.017844136926438457

# %% [markdown]
# We can even create a...wait for it...*WORD CLOUD* or Wordl to gaze at and draw mystical, approximate inferences about important nouns and verbs in our corpus:

# %%
wc = wordcloud.WordCloud(background_color="white", max_words=500, width= 1000, height = 1000, mode ='RGBA', scale=.5).generate(' '.join(whReleases['normalized_tokens'].sum()))
plt.imshow(wc)
plt.axis("off")
plt.savefig("whitehouse_word_cloud.pdf", format = 'pdf')

# %% [markdown]
# ## <span style="color:red">*Exercise 2*</span>
#
# <span style="color:red">Construct cells immediately below this that filter, stem and lemmatize the tokens in your corpus, and then creates plots (with titles and labels) that map the word frequency distribution, word probability distribution, and at least two conditional probability distributions that help us better understand the social and cultural game underlying the production of your corpus. Create a wordl of words (or normalized words) and add a few vague comments about what mysteries are revealed through it.</span>

# %%
# news['normalized_tokens'] = news['tokenized_text'].apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, stemmer = snowball))
# news['normalized_tokens_count'] = news['normalized_tokens'].apply(lambda x: len(x)) 
# news['normalized_tokens_POS'] = [nltk.pos_tag(t) for t in news['normalized_tokens']]

# %% [markdown]
# # Collocations

# %% [markdown]
# As illustrated above, we might want to find significant bigrams (two-word phrases), trigrams (three-word phrases), n-grams (*n*-word phrases) or skip-grams (noncontinguous 'phrases' with skip-length *n*). We will begin with the [`nltk.collocations.BigramCollocationFinder`](http://www.nltk.org/api/nltk.html?highlight=bigramcollocationfinder#nltk.collocations.BigramCollocationFinder) class, which can be given raw lists of strings with the `from_words()` method. By default it only looks at continuous bigrams but there is an option (`window_size`) to allow skip-grams.

# %%
whBigrams = nltk.collocations.BigramCollocationFinder.from_words(whReleases['normalized_tokens'].sum())
print("There are {} bigrams in the finder".format(whBigrams.N))
# Out:
# There are 2038 bigrams in the finder

# %% [markdown]
# To compare the bigrams we need to tell nltk what our score function is. Initially, we will look at the raw counts.

# %%
def bigramScoring(count, wordsTuple, total):
    return count

# %%
print(whBigrams.nbest(bigramScoring, 10))
# Out:
# [('rhode', 'island'), ('presid', 'bush'), ('sheldon', 'whitehous'), ('stem', 'cell'), ('whitehous', 'said'), ('bush', 'administr'), ('american', 'peopl'), ('bring', 'troop'), ('senat', 'sheldon'), ('troop', 'home')]

# %%
birgramScores = []

def bigramPrinting(count, wordsTuple, total):
    global birgramScores
    birgramScores.append("The first word is:  {}, The second word is: {}".format(*wordsTuple))
    #Returns None so all the tuples are considered to have the same rank

# %% [markdown]
# One note about how `BigramCollocationFinder` works. It doesn't use the strings internally.

# %%
nBigrams.nbest(bigramPrinting, 10)
print('\n'.join(birgramScores[:10]))
# Out:
# The first word is:  8, The second word is: 2
# The first word is:  2, The second word is: 145
# The first word is:  145, The second word is: 23
# The first word is:  23, The second word is: 1194
# The first word is:  1194, The second word is: 973
# The first word is:  973, The second word is: 5
# The first word is:  5, The second word is: 15
# The first word is:  15, The second word is: 9
# The first word is:  9, The second word is: 23
# The first word is:  23, The second word is: 271

# %% [markdown]
# The words are each given numeric IDs and there is a dictionary that maps the IDs to the words they represent. This is a common performance optimization.
#
# Two words can appear together by chance. Recall from  Manning and Schütze's textbook that a $t-value can be computed for each bigram to see how significant the association is. You may also want to try computing the $\chi^2$, likelihood ratio, and pointwise mutual information statistics.

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
whBigrams.score_ngrams(bigram_measures.likelihood_ratio)[:40]
# other options include student_t, chi_sq, likelihood_ratio, pmi
# Out:
# [(('rhode', 'island'), 223.98603169548517),
#  (('stem', 'cell'), 146.69971583676724),
#  (('presid', 'bush'), 124.78339903371592),
#  (('sheldon', 'whitehous'), 97.83057167237577),
#  (('unit', 'state'), 63.7408597571739),
#  (('whitehous', 'said'), 50.85365409523493),
#  (('jack', 'reed'), 46.61449955206517),
#  (('honor', 'societi'), 45.00623576992483),
#  (('american', 'peopl'), 44.4949166648486),
#  (('bring', 'troop'), 43.29082241816299),
#  (('bush', 'administr'), 42.73672706610401),
#  (('cell', 'research'), 41.25934273451902),
#  (('youth', 'program'), 38.276119099832265),
#  (('troop', 'home'), 36.87601441962918),
#  (('come', 'home'), 36.661589434392276),
#  (('senat', 'sheldon'), 36.08708619238288),
#  (('epw', 'committe'), 34.42122395939712),
#  (('potenti', 'close'), 33.7794434582587),
#  (('budget', 'resolut'), 32.192797473966614),
#  (('district', 'columbia'), 31.62701894759353),
#  (('humpti', 'dumpti'), 31.62701894759353),
#  (('jose', 'socrat'), 31.62701894759353),
#  (('prime', 'minist'), 31.62701894759353),
#  (('weaver', 'cove'), 31.62701894759353),
#  (('chang', 'cours'), 31.55001446652071),
#  (('confirm', 'hear'), 27.80793393782465),
#  (('harm', 'way'), 27.80793393782465),
#  (('interest', 'payment'), 27.80793393782465),
#  (('trillion', 'foregon'), 27.80793393782465),
#  (('foregon', 'surplus'), 26.081841503113964),
#  (('senat', 'youth'), 25.938248175532106),
#  (('consul', 'provid'), 25.75753014835219),
#  (('year', 'ago'), 25.07814446954526),
#  (('high', 'school'), 24.896902277500963),
#  (('reconsid', 'potenti'), 24.896902277500963),
#  (('one', 'thing'), 23.98985093210625),
#  (('circuit', 'court'), 23.988848928055774),
#  (('cost', 'america'), 23.988848928055774),
#  (('general', 'counsel'), 23.988848928055774),
#  (('misguid', 'polici'), 23.988848928055774)]

# %% [markdown]
# There are a few other available measures

# %%
[s for s in dir(bigram_measures) if s[0] != '_']
# Out:
# ['chi_sq',
#  'dice',
#  'fisher',
#  'jaccard',
#  'likelihood_ratio',
#  'mi_like',
#  'phi_sq',
#  'pmi',
#  'poisson_stirling',
#  'raw_freq',
#  'student_t']

# %% [markdown]
# We can also look at trigrams

# %%
trigram_measures = nltk.collocations.TrigramAssocMeasures()
whTrigrams = nltk.collocations.TrigramCollocationFinder.from_words(whReleases['normalized_tokens'].sum())
whTrigrams.score_ngrams(trigram_measures.student_t)[:20]
# Out:
# [(('bring', 'troop', 'home'), 2.449202865677887),
#  (('senat', 'sheldon', 'whitehous'), 2.4481166557834917),
#  (('stem', 'cell', 'research'), 2.2359229352888974),
#  (('whitehous', 'said', 'today'), 1.9987987990993996),
#  (('jack', 'reed', 'sheldon'), 1.7319953264758123),
#  (('senat', 'youth', 'program'), 1.7319901251233376),
#  (('unit', 'state', 'senat'), 1.73173525885207),
#  (('new', 'direct', 'iraq'), 1.7316624399174225),
#  (('reed', 'sheldon', 'whitehous'), 1.7314959966382275),
#  (('sheldon', 'whitehous', 'said'), 1.7309411857075774),
#  (('trillion', 'foregon', 'surplus'), 1.414209315486583),
#  (('reconsid', 'potenti', 'close'), 1.4142064842289084),
#  (('sent', 'clear', 'messag'), 1.414205599460885),
#  (('today', 'confirm', 'hear'), 1.4141976365486753),
#  (('select', 'committe', 'intellig'), 1.4141965748270473),
#  (('general', 'david', 'petraeus'), 1.4141923279405353),
#  (('take', 'respons', 'secur'), 1.4141923279405353),
#  (('cell', 'enhanc', 'act'), 1.4141880810540235),
#  (('respons', 'secur', 'govern'), 1.4141880810540235),
#  (('new', 'sourc', 'review'), 1.41416897006472)]

# %% [markdown]
# Or n-grams (for any number n)

# %%
Ngrams = nltk.ngrams(whReleases['normalized_tokens'].sum(), 4)
Counts = {}
for ngram in list(Ngrams):
    if ngram in Counts.keys():
        Counts[ngram] += 1
    else:
        Counts[ngram] = 1
Filtered = {}
for key in Counts.keys():
    if Counts[key] < 2:
        pass
    else:
        Filtered[key] = Counts[key]
print(Filtered)
# Out:
# {('stem', 'cell', 'research', 'whitehous'): 2, ('stem', 'cell', 'enhanc', 'act'): 2, ('begin', 'bring', 'troop', 'home'): 2, ('bring', 'troop', 'home', 'iraq'): 2, ('senat', 'sheldon', 'whitehous', 'said'): 3, ('sheldon', 'whitehous', 'said', 'today'): 3, ('member', 'senat', 'select', 'committe'): 2, ('senat', 'select', 'committe', 'intellig'): 2, ('take', 'respons', 'secur', 'govern'): 2, ('senat', 'jack', 'reed', 'sheldon'): 2, ('jack', 'reed', 'sheldon', 'whitehous'): 3, ('whitehous', 'welcom', 'rhode', 'island'): 2, ('portugues', 'american', 'citizen', 'rhode'): 2, ('american', 'citizen', 'rhode', 'island'): 2}

# %% [markdown]
# ## <span style="color:red">*Exercise 3*</span>
#
# <span style="color:red">Construct cells immediately below this that identify statistically significant bigrams, trigrams, quadgrams, higher-order *n*grams and skipgrams. Explore whether these collocations are idiomatic and so irreducible to the semantic sum of their component words. You can do this by examination of conditional frequencies (e.g., what else is 'united' besides the 'United States'). If these phrases are idiomatic, what do they suggest about the culture of the world producing them?
#
# <span style="color:red">**Stretch**: In Manning and Schütze's textbook, there Section 5.3.2 explores how to use the *t*-test to find words whose co-occurance patterns best distinguish two words. Implement that and use it to explore phrases in your corpus. For instance, you could tell what words come after "America" much more often than after "Iraq"?</span>

# %% [markdown]
# ## <span style="color:blue">*Notes*</span>
# <span style="color:blue"> Here, we explore bigrams, trigrams, quadgrams and some skipgrams. There are nearly 40 thousand bigrams in the 100 articles we scraped. The top ten bigrams that are the most related to each other according to the likelihood ratio and the student’s t test are quite similar. The two words most likely to appear together are ‘climat’ and ‘change’, not surprising since they were the search terms. Other words include typical climate change related words, such as, ‘global warming’, ‘fossil fuel’, ‘greenhouse gas’, and ‘gas emission’. A few strongly related proper noun bigrams include ‘paris agreement’, ‘donald trump’, and ‘united states’.
#
# <span style="color:blue"> As for trigrams, we most often find the bigram ‘climate change’ grouped with an additional word, such as ‘impact [of] climate change’, ‘effect [of] climate change’, ‘risk [of] climate change’, ‘tackle climate change’. In addition, proper nouns are also very common, such as ‘paris climate change’, ‘convention on climate change’, and ‘president donald trump’. We see many more proper nouns in the top quadgrams, unsurprisingly (in terms of frequency instead of a statistical test). Skipgrams are also dominated by the words ‘climate change’ (many of them normal bi/trigrams instead of skipgrams) grouped with an additional word. We can see that the articles are dominated by the words 'climate change'. So, it may be interesting to analyze the corpus without the words ‘climate change’ or enlarge the corpus to include articles found with other search terms (such as ‘sustainable energy’).

# %%
# news analysis
nBigrams = nltk.collocations.BigramCollocationFinder.from_words(news['normalized_tokens'].sum())
print("There are {} bigrams in the finder".format(nBigrams.N))
# Out:
# There are 39588 bigrams in the finder

# %%
# news analysis
print(nBigrams.nbest(bigramScoring, 10))
# Out:
# [('climat', 'chang'), ('global', 'warm'), ('pari', 'agreement'), ('per', 'cent'), ('fossil', 'fuel'), ('unit', 'state'), ('donald', 'trump'), ('renew', 'energi'), ('impact', 'climat'), ('greenhous', 'gas')]

# %%
# news analysis
bigram_measures = nltk.collocations.BigramAssocMeasures()
nBigrams.score_ngrams(bigram_measures.likelihood_ratio)[:10]
# Out:
# [(('climat', 'chang'), 6216.084410825541),
#  (('per', 'cent'), 832.9628595172843),
#  (('global', 'warm'), 785.9628047936018),
#  (('pari', 'agreement'), 699.6505849775403),
#  (('fossil', 'fuel'), 687.0238884333314),
#  (('donald', 'trump'), 512.6230785055077),
#  (('greenhous', 'gas'), 483.0462352237136),
#  (('associ', 'press'), 429.7025809541749),
#  (('unit', 'state'), 419.9350629032579),
#  (('gas', 'emiss'), 361.38632018274575)]

# %%
nBigrams.score_ngrams(bigram_measures.student_t)[:10]
# Out:
# [(('climat', 'chang'), 28.377901392642013),
#  (('global', 'warm'), 9.34763205750794),
#  (('pari', 'agreement'), 8.76267103093127),
#  (('per', 'cent'), 7.92014490177939),
#  (('fossil', 'fuel'), 6.989174208634651),
#  (('unit', 'state'), 6.941291733425714),
#  (('donald', 'trump'), 6.893187114373613),
#  (('renew', 'energi'), 6.491566907835204),
#  (('greenhous', 'gas'), 6.387502127271212),
#  (('gas', 'emiss'), 6.130878080201113)]

# %%
# news analysis
trigram_measures = nltk.collocations.TrigramAssocMeasures()
nTrigrams = nltk.collocations.TrigramCollocationFinder.from_words(news['normalized_tokens'].sum())
nTrigrams.score_ngrams(trigram_measures.student_t)[:10]
# Out:
# [(('impact', 'climat', 'chang'), 6.38923177082558),
#  (('greenhous', 'gas', 'emiss'), 6.164363175562539),
#  (('presid', 'donald', 'trump'), 5.56764769528843),
#  (('effect', 'climat', 'chang'), 4.886420269980804),
#  (('climat', 'chang', 'confer'), 4.678404396723941),
#  (('un', 'climat', 'chang'), 4.349205276485897),
#  (('risk', 'climat', 'chang'), 4.211365002701355),
#  (('climat', 'chang', 'said'), 4.052627937378583),
#  (('copyright', 'arab', 'news'), 3.872981793596896),
#  (('tackl', 'climat', 'chang'), 3.867049912312774)]

# %%
nTrigrams.score_ngrams(trigram_measures.likelihood_ratio)[:10]
# Out:
# [(('impact', 'climat', 'chang'), 9572.306584596761),
#  (('convent', 'climat', 'chang'), 9456.94168575144),
#  (('un', 'climat', 'chang'), 9456.449978868044),
#  (('effect', 'climat', 'chang'), 9455.700873921305),
#  (('climat', 'chang', 'confer'), 9445.62065896636),
#  (('tackl', 'climat', 'chang'), 9436.884335369197),
#  (('fight', 'climat', 'chang'), 9436.436414551603),
#  (('pari', 'climat', 'chang'), 9430.90642945515),
#  (('climat', 'chang', 'real'), 9428.971802325388),
#  (('climat', 'climat', 'chang'), 9426.234654674223)]

# %%
def countDict(ngramList):
    Counts = {}
    for ngram in ngramList:
        if ngram in Counts.keys():
            Counts[ngram] += 1
        else:
            Counts[ngram] = 1
    Filtered = {}
    for key in Counts.keys():
        if Counts[key] < 2:
            pass
        else:
            Filtered[key] = Counts[key]
    return Filtered

def printDesc(dictionary):
    sorted_keys = sorted(dictionary, key=dictionary.get, reverse=True)
    for r in sorted_keys:
        print (r, dictionary[r])

# %%
# news analysis
Ngrams = nltk.ngrams(news['normalized_tokens'].sum(), 4)
Filtered = countDict(list(Ngrams))

printDesc(Filtered)
# Out:
# ('un', 'climat', 'chang', 'confer') 19
# ('framework', 'convent', 'climat', 'chang') 14
# ('cop', 'fiji', 'un', 'climat') 14
# ('fiji', 'un', 'climat', 'chang') 14
# ('us', 'presid', 'donald', 'trump') 13
# ('climat', 'chang', 'confer', 'bonn') 12
# ('chang', 'confer', 'bonn', 'germani') 12
# ('confer', 'bonn', 'germani', 'saturday') 11
# ('ap', 'meissner', 'associ', 'press') 11
# ('action', 'plan', 'climat', 'chang') 10
# ('intergovernment', 'panel', 'climat', 'chang') 8
# ('unit', 'nation', 'framework', 'convent') 8
# ('nation', 'framework', 'convent', 'climat') 8
# ('climat', 'chang', 'climat', 'chang') 7
# ('climat', 'action', 'center', 'cop') 7
# ('action', 'center', 'cop', 'fiji') 7
# ('center', 'cop', 'fiji', 'un') 7
# ('pari', 'agreement', 'climat', 'chang') 6
# ('un', 'framework', 'convent', 'climat') 6
# ('reduc', 'greenhous', 'gas', 'emiss') 6
# ('america', 'pledg', 'campaign', 'work') 6
# ('pledg', 'campaign', 'work', 'compil') 6
# ('campaign', 'work', 'compil', 'talli') 6
# ('work', 'compil', 'talli', 'climat') 6
# ('compil', 'talli', 'climat', 'action') 6
# ('talli', 'climat', 'action', 'state') 6
# ('climat', 'action', 'state', 'citi') 6
# ('action', 'state', 'citi', 'colleg') 6
# ('state', 'citi', 'colleg', 'busi') 6
# ('citi', 'colleg', 'busi', 'local') 6
# ('colleg', 'busi', 'local', 'actor') 6
# ('busi', 'local', 'actor', 'across') 6
# ('local', 'actor', 'across', 'entir') 6
# ('actor', 'across', 'entir', 'economi') 6
# ('across', 'entir', 'economi', 'ap') 6
# ('entir', 'economi', 'ap', 'meissner') 6
# ('economi', 'ap', 'meissner', 'associ') 6
# ('meissner', 'associ', 'press', 'former') 6
# ('state', 'action', 'plan', 'climat') 6
# ('former', 'new', 'york', 'mayor') 5
# ('pari', 'climat', 'chang', 'agreement') 5
# ('bloomberg', 'america', 'pledg', 'campaign') 5
# ('bonn', 'germani', 'saturday', 'ap') 5
# ('germani', 'saturday', 'ap', 'meissner') 5
# ('saturday', 'ap', 'meissner', 'associ') 5
# ('new', 'nation', 'secur', 'strategi') 5
# ('tuesday', 'brooklin', 'maggi', 'hassan') 5
# ('brooklin', 'maggi', 'hassan', 'led') 5
# ('maggi', 'hassan', 'led', 'discuss') 5
# ('hassan', 'led', 'discuss', 'mapl') 5
# ('led', 'discuss', 'mapl', 'syrup') 5
# ('discuss', 'mapl', 'syrup', 'produc') 5
# ('mapl', 'syrup', 'produc', 'new') 5
# ('syrup', 'produc', 'new', 'hampshir') 5
# ('produc', 'new', 'hampshir', 'climat') 5
# ('new', 'hampshir', 'climat', 'chang') 5
# ('hampshir', 'climat', 'chang', 'impact') 5
# ('climat', 'chang', 'impact', 'industri') 5
# ('chang', 'impact', 'industri', 'ap') 5
# ('impact', 'industri', 'ap', 'amendola') 5
# ('industri', 'ap', 'amendola', 'associ') 5
# ('ap', 'amendola', 'associ', 'press') 5
# ('california', 'governor', 'jerri', 'brown') 4
# ('bank', 'england', 'governor', 'mark') 4
# ('england', 'governor', 'mark', 'carney') 4
# ('german', 'chancellor', 'angela', 'merkel') 4
# ('keep', 'global', 'temperatur', 'rise') 4
# ('presid', 'donald', 'trump', 'expect') 4
# ('climat', 'chang', 'nation', 'secur') 4
# ('greenhous', 'gas', 'emiss', 'power') 4
# ('gas', 'emiss', 'power', 'plant') 4
# ('demonstr', 'costum', 'presid', 'donald') 4
# ('costum', 'presid', 'donald', 'trump') 4
# ('presid', 'donald', 'trump', 'polar') 4
# ('donald', 'trump', 'polar', 'bear') 4
# ('trump', 'polar', 'bear', 'protest') 4
# ('polar', 'bear', 'protest', 'climat') 4
# ('bear', 'protest', 'climat', 'chang') 4
# ('protest', 'climat', 'chang', 'dure') 4
# ('climat', 'chang', 'dure', 'climat') 4
# ('chang', 'dure', 'climat', 'confer') 4
# ('dure', 'climat', 'confer', 'cop') 4
# ('climat', 'confer', 'cop', 'bonn') 4
# ('confer', 'cop', 'bonn', 'western') 4
# ('cop', 'bonn', 'western', 'germani') 4
# ('bonn', 'western', 'germani', 'saturday') 4
# ('western', 'germani', 'saturday', 'bernd') 4
# ('germani', 'saturday', 'bernd', 'via') 4
# ('saturday', 'bernd', 'via', 'ap') 4
# ('bernd', 'via', 'ap', 'associ') 4
# ('via', 'ap', 'associ', 'press') 4
# ('speak', 'climat', 'action', 'center') 4
# ('associ', 'press', 'former', 'new') 4
# ('press', 'former', 'new', 'york') 4
# ('new', 'york', 'mayor', 'billionair') 4
# ('york', 'mayor', 'billionair', 'michael') 4
# ('mayor', 'billionair', 'michael', 'bloomberg') 4
# ('fiji', 'prime', 'minist', 'cop') 4
# ('prime', 'minist', 'cop', 'presid') 4
# ('minist', 'cop', 'presid', 'frank') 4
# ('cop', 'presid', 'frank', 'bainimarama') 4
# ('presid', 'donald', 'trump', 'speak') 4
# ('effort', 'curb', 'climat', 'chang') 4
# ('parker', 'mapl', 'barn', 'employe') 4
# ('adapt', 'impact', 'climat', 'chang') 4
# ('climat', 'chang', 'action', 'plan') 4
# ('money', 'doe', 'grow', 'tree') 4
# ('work', 'plan', 'forest', 'divis') 4
# ('princip', 'chief', 'conserv', 'forest') 4
# ('global', 'greenhous', 'gas', 'emiss') 3
# ('panel', 'climat', 'chang', 'ipcc') 3
# ('bjorn', 'lomborg', 'director', 'copenhagen') 3
# ('lomborg', 'director', 'copenhagen', 'consensus') 3
# ('director', 'copenhagen', 'consensus', 'center') 3
# ('secretari', 'general', 'antonio', 'guterr') 3
# ('head', 'environment', 'protect', 'agenc') 3
# ('task', 'forc', 'financi', 'disclosur') 3
# ('gross', 'domest', 'product', 'gdp') 3
# ('former', 'us', 'vice', 'presid') 3
# ('us', 'vice', 'presid', 'al') 3
# ('vice', 'presid', 'al', 'gore') 3
# ('achiev', 'sustain', 'develop', 'goal') 3
# ('sustain', 'develop', 'goal', 'sdgs') 3
# ('nation', 'determin', 'contribut', 'ndc') 3
# ('nation', 'ocean', 'atmospher', 'administr') 3
# ('mitig', 'climat', 'chang', 'must') 3
# ('temperatur', 'rise', 'climat', 'chang') 3
# ('negat', 'impact', 'climat', 'chang') 3
# ('climat', 'chang', 'work', 'group') 3
# ('renew', 'energi', 'energi', 'effici') 3
# ('risk', 'associ', 'climat', 'chang') 3
# ('mitig', 'adapt', 'climat', 'chang') 3
# ('global', 'temperatur', 'rise', 'c') 3
# ('reduct', 'greenhous', 'gas', 'emiss') 3
# ('greenhous', 'gas', 'emiss', 'per') 3
# ('associ', 'press', 'demonstr', 'costum') 3
# ('press', 'demonstr', 'costum', 'presid') 3
# ('associ', 'press', 'smoke', 'steam') 3
# ('press', 'smoke', 'steam', 'billow') 3
# ('smoke', 'steam', 'billow', 'chimney') 3
# ('steam', 'billow', 'chimney', 'kosovo') 3
# ('billow', 'chimney', 'kosovo', 'power') 3
# ('chimney', 'kosovo', 'power', 'plant') 3
# ('kosovo', 'power', 'plant', 'near') 3
# ('power', 'plant', 'near', 'obil') 3
# ('plant', 'near', 'obil', 'kosovo') 3
# ('near', 'obil', 'kosovo', 'friday') 3
# ('obil', 'kosovo', 'friday', 'cop') 3
# ('kosovo', 'friday', 'cop', 'fiji') 3
# ('friday', 'cop', 'fiji', 'un') 3
# ('climat', 'chang', 'confer', 'take') 3
# ('chang', 'confer', 'take', 'place') 3
# ('confer', 'take', 'place', 'bonn') 3
# ('take', 'place', 'bonn', 'germani') 3
# ('place', 'bonn', 'germani', 'meet') 3
# ('bonn', 'germani', 'meet', 'start') 3
# ('germani', 'meet', 'start', 'monday') 3
# ('meet', 'start', 'monday', 'first') 3
# ('start', 'monday', 'first', 'major') 3
# ('monday', 'first', 'major', 'confer') 3
# ('first', 'major', 'confer', 'climat') 3
# ('major', 'confer', 'climat', 'chang') 3
# ('confer', 'climat', 'chang', 'sinc') 3
# ('climat', 'chang', 'sinc', 'presid') 3
# ('chang', 'sinc', 'presid', 'donald') 3
# ('sinc', 'presid', 'donald', 'trump') 3
# ('presid', 'donald', 'trump', 'said') 3
# ('donald', 'trump', 'said', 'pull') 3
# ('trump', 'said', 'pull', 'pari') 3
# ('said', 'pull', 'pari', 'accord') 3
# ('pull', 'pari', 'accord', 'unless') 3
# ('pari', 'accord', 'unless', 'administr') 3
# ('accord', 'unless', 'administr', 'secur') 3
# ('unless', 'administr', 'secur', 'better') 3
# ('administr', 'secur', 'better', 'deal') 3
# ('secur', 'better', 'deal', 'ap') 3
# ('better', 'deal', 'ap', 'kryeziu') 3
# ('deal', 'ap', 'kryeziu', 'associ') 3
# ('ap', 'kryeziu', 'associ', 'press') 3
# ('billionair', 'michael', 'bloomberg', 'left') 3
# ('michael', 'bloomberg', 'left', 'speak') 3
# ('bloomberg', 'left', 'speak', 'fiji') 3
# ('left', 'speak', 'fiji', 'prime') 3
# ('speak', 'fiji', 'prime', 'minist') 3
# ('presid', 'frank', 'bainimarama', 'climat') 3
# ('frank', 'bainimarama', 'climat', 'action') 3
# ('bainimarama', 'climat', 'action', 'center') 3
# ('bonn', 'germani', 'saturday', 'bloomberg') 3
# ('germani', 'saturday', 'bloomberg', 'america') 3
# ('saturday', 'bloomberg', 'america', 'pledg') 3
# ('donald', 'trump', 'speak', 'nation') 3
# ('trump', 'speak', 'nation', 'secur') 3
# ('speak', 'nation', 'secur', 'monday') 3
# ('nation', 'secur', 'monday', 'washington') 3
# ('secur', 'monday', 'washington', 'trump') 3
# ('monday', 'washington', 'trump', 'say') 3
# ('washington', 'trump', 'say', 'new') 3
# ('trump', 'say', 'new', 'nation') 3
# ('say', 'new', 'nation', 'secur') 3
# ('nation', 'secur', 'strategi', 'put') 3
# ('secur', 'strategi', 'put', 'america') 3
# ('strategi', 'put', 'america', 'first') 3
# ('put', 'america', 'first', 'ap') 3
# ('america', 'first', 'ap', 'vucci') 3
# ('first', 'ap', 'vucci', 'associ') 3
# ('ap', 'vucci', 'associ', 'press') 3
# ('damag', 'interest', 'roll', 'back') 3
# ('interest', 'roll', 'back', 'previous') 3
# ('roll', 'back', 'previous', 'administr') 3
# ('back', 'previous', 'administr', 'effort') 3
# ('previous', 'administr', 'effort', 'curb') 3
# ('administr', 'effort', 'curb', 'climat') 3
# ('curb', 'climat', 'chang', 'presid') 3
# ('climat', 'chang', 'presid', 'donald') 3
# ('chang', 'presid', 'donald', 'trump') 3
# ('donald', 'trump', 'expect', 'sign') 3
# ('trump', 'expect', 'sign', 'execut') 3
# ('expect', 'sign', 'execut', 'order') 3
# ('sign', 'execut', 'order', 'tuesday') 3
# ('rescind', 'suspend', 'review', 'regul') 3
# ('suspend', 'review', 'regul', 'includ') 3
# ('review', 'regul', 'includ', 'restrict') 3
# ('regul', 'includ', 'restrict', 'greenhous') 3
# ('includ', 'restrict', 'greenhous', 'gas') 3
# ('restrict', 'greenhous', 'gas', 'emiss') 3
# ('climat', 'chang', 'summit', 'pari') 3
# ('bucket', 'tuesday', 'brooklin', 'maggi') 3
# ('amendola', 'associ', 'press', 'parker') 3
# ('associ', 'press', 'parker', 'mapl') 3
# ('press', 'parker', 'mapl', 'barn') 3
# ('mapl', 'barn', 'employe', 'jon') 3
# ('barn', 'employe', 'jon', 'joni') 3
# ('depart', 'energi', 'climat', 'chang') 3
# ('effort', 'address', 'climat', 'chang') 3
# ('australian', 'prudenti', 'regul', 'author') 3
# ('financi', 'risk', 'climat', 'chang') 3
# ('move', 'away', 'fossil', 'fuel') 3
# ('climat', 'chang', 'extrem', 'weather') 3
# ('deal', 'threat', 'climat', 'chang') 3
# ('convent', 'climat', 'chang', 'unfccc') 3
# ('implement', 'climat', 'chang', 'action') 3
# ('green', 'climat', 'fund', 'gcf') 3
# ('pull', 'pari', 'climat', 'accord') 3
# ('set', 'climat', 'chang', 'cell') 3
# ('plan', 'climat', 'chang', 'sapcc') 3
# ('tourism', 'transport', 'agricultur', 'horticultur') 3
# ('rn', 'jha', 'nodal', 'offic') 3
# ('nodal', 'offic', 'climat', 'chang') 3
# ('environ', 'climat', 'chang', 'depart') 3
# ('unit', 'nation', 'develop', 'program') 3
# ('climat', 'chang', 'adapt', 'polici') 3
# ('environ', 'wing', 'state', 'forest') 3
# ('wing', 'state', 'forest', 'depart') 3
# ('critic', 'need', 'green', 'technolog') 2
# ('pari', 'climat', 'agreement', 'sign') 2
# ('polici', 'laud', 'pari', 'essenti') 2
# ('laud', 'pari', 'essenti', 'gestur') 2
# ('throughout', 'centuri', 'would', 'prevent') 2
# ('centuri', 'would', 'prevent', 'global') 2
# ('would', 'prevent', 'global', 'warm') 2
# ('need', 'keep', 'temperatur', 'rise') 2
# ('green', 'energi', 'fossil', 'fuel') 2
# ('project', 'syndic', 'copyright', 'arab') 2
# ('syndic', 'copyright', 'arab', 'news') 2
# ('agreement', 'climat', 'chang', 'accord') 2
# ('elect', 'repres', 'citizen', 'pittsburgh') 2
# ('pari', 'agreement', 'dead', 'countri') 2
# ('agreement', 'dead', 'countri', 'compani') 2
# ('dead', 'countri', 'compani', 'even') 2
# ('countri', 'compani', 'even', 'oil') 2
# ('see', 'import', 'account', 'greenhous') 2
# ('import', 'account', 'greenhous', 'gas') 2
# ('account', 'greenhous', 'gas', 'emiss') 2
# ('forc', 'financi', 'disclosur', 'tcfd') 2
# ('financi', 'disclosur', 'tcfd', 'tcfd') 2
# ('disclosur', 'tcfd', 'tcfd', 'initi') 2
# ('climat', 'chang', 'due', 'greenhous') 2
# ('chang', 'due', 'greenhous', 'gas') 2
# ('due', 'greenhous', 'gas', 'emiss') 2
# ('greenhous', 'gas', 'emiss', 'increas') 2
# ('evid', 'suggest', 'climat', 'chang') 2
# ('factor', 'spread', 'extrem', 'countri') 2
# ('way', 'mitig', 'drought', 'social') 2
# ('mitig', 'drought', 'social', 'polit') 2
# ('drought', 'social', 'polit', 'effect') 2
# ('social', 'polit', 'effect', 'kerri') 2
# ('polit', 'effect', 'kerri', 'boyd') 2
# ('effect', 'kerri', 'boyd', 'anderson') 2
# ('empow', 'concern', 'citizen', 'citi') 2
# ('concern', 'citizen', 'citi', 'energi') 2
# ('citizen', 'citi', 'energi', 'resolv') 2
# ('citi', 'energi', 'resolv', 'achiev') 2
# ('issu', 'like', 'climat', 'chang') 2
# ('mayor', 'new', 'york', 'said') 2
# ('lead', 'fight', 'climat', 'chang') 2
# ('nasser', 'general', 'manag', 'trade') 2
# ('general', 'manag', 'trade', 'busi') 2
# ('manag', 'trade', 'busi', 'develop') 2
# ('trade', 'busi', 'develop', 'itfc') 2
# ('islam', 'develop', 'bank', 'group') 2
# ('report', 'nation', 'ocean', 'atmospher') 2
# ('annual', 'sea', 'ice', 'extent') 2
# ('reduc', 'depend', 'fossil', 'fuel') 2
# ('worst', 'effect', 'climat', 'chang') 2
# ('mani', 'regul', 'may', 'need') 2
# ('strangl', 'sourc', 'make', 'life') 2
# ('sourc', 'make', 'life', 'worth') 2
# ('make', 'life', 'worth', 'live') 2
# ('life', 'worth', 'live', 'edmund') 2
# ('worth', 'live', 'edmund', 'phelp') 2
# ('greenhous', 'gas', 'emiss', 'peak') 2
# ('skeptic', 'seem', 'advoc', 'would') 2
# ('seem', 'advoc', 'would', 'grow') 2
# ('advoc', 'would', 'grow', 'likelihood') 2
# ('would', 'grow', 'likelihood', 'devast') 2
# ('grow', 'likelihood', 'devast', 'environment') 2
# ('likelihood', 'devast', 'environment', 'damag') 2
# ('devast', 'environment', 'damag', 'planet') 2
# ('limit', 'global', 'temperatur', 'rise') 2
# ('moham', 'bin', 'rashid', 'solar') 2
# ('bin', 'rashid', 'solar', 'park') 2
# ('rashid', 'solar', 'park', 'dubai') 2
# ('ford', 'conserv', 'environment', 'grant') 2
# ('climat', 'chang', 'china', 'agricultur') 2
# ('special', 'envoy', 'climat', 'chang') 2
# ('emiss', 'per', 'unit', 'gdp') 2
# ('said', 'skeptic', 'climat', 'chang') 2
# ('whether', 'climat', 'chang', 'real') 2
# ('former', 'exxon', 'mobil', 'ceo') 2
# ('exxon', 'mobil', 'ceo', 'rex') 2
# ('mobil', 'ceo', 'rex', 'tillerson') 2
# ('last', 'week', 'climat', 'chang') 2
# ('billion', 'dollar', 'mayb', 'even') 2
# ('dollar', 'mayb', 'even', 'trillion') 2
# ('mayb', 'even', 'trillion', 'potenti') 2
# ('even', 'trillion', 'potenti', 'profit') 2
# ('trillion', 'potenti', 'profit', 'loss') 2
# ('accord', 'intern', 'energi', 'agenc') 2
# ('acknowledg', 'climat', 'chang', 'real') 2
# ('trump', 'pull', 'pari', 'agreement') 2
# ('un', 'secretari', 'general', 'antonio') 2
# ('intend', 'nation', 'determin', 'contribut') 2
# ('energi', 'energi', 'effici', 'technolog') 2
# ('countri', 'sign', 'pari', 'agreement') 2
# ('presid', 'donald', 'trump', 'pull') 2
# ('donald', 'trump', 'pull', 'pari') 2
# ('ratifi', 'doha', 'amend', 'kyoto') 2
# ('doha', 'amend', 'kyoto', 'protocol') 2
# ('climat', 'chang', 'real', 'dream') 2
# ('author', 'senior', 'editor', 'china') 2
# ('senior', 'editor', 'china', 'daili') 2
# ('editor', 'china', 'daili', 'oprana') 2
# ('nation', 'congress', 'communist', 'parti') 2
# ('congress', 'communist', 'parti', 'china') 2
# ('author', 'deputi', 'china', 'daili') 2
# ('deputi', 'china', 'daili', 'usa') 2
# ('china', 'daili', 'usa', 'huanxinzhao') 2
# ('effort', 'fight', 'climat', 'chang') 2
# ('shift', 'toward', 'cleaner', 'energi') 2
# ('tackl', 'climat', 'chang', 'said') 2
# ('unit', 'state', 'pari', 'climat') 2
# ('devast', 'effect', 'climat', 'chang') 2
# ('ceo', 'european', 'climat', 'foundat') 2
# ('prevent', 'futur', 'climat', 'catastroph') 2
# ('whether', 'pull', 'us', 'pari') 2
# ('pull', 'us', 'pari', 'agreement') 2
# ('unit', 'state', 'climat', 'chang') 2
# ('commit', 'combat', 'climat', 'chang') 2
# ('nation', 'develop', 'reform', 'commiss') 2
# ('climat', 'chang', 'bonn', 'confer') 2
# ('greenhous', 'gas', 'emiss', 'drastic') 2
# ('remov', 'climat', 'chang', 'list') 2
# ('climat', 'chang', 'list', 'worldwid') 2
# ('chang', 'list', 'worldwid', 'threat') 2
# ('list', 'worldwid', 'threat', 'menac') 2
# ('worldwid', 'threat', 'menac', 'unit') 2
# ('threat', 'menac', 'unit', 'state') 2
# ('obama', 'administr', 'describ', 'climat') 2
# ('administr', 'describ', 'climat', 'chang') 2
# ('describ', 'climat', 'chang', 'urgent') 2
# ('climat', 'chang', 'urgent', 'grow') 2
# ('chang', 'urgent', 'grow', 'threat') 2
# ('chang', 'nation', 'secur', 'threat') 2
# ('human', 'activ', 'primari', 'caus') 2
# ('activ', 'primari', 'caus', 'climat') 2
# ('primari', 'caus', 'climat', 'chang') 2
# ('burn', 'oil', 'gas', 'coal') 2
# ('pruitt', 'said', 'believ', 'epa') 2
# ('take', 'climat', 'chang', 'serious') 2
# ('unit', 'nation', 'climat', 'chang') 2
# ('climat', 'chang', 'past', 'year') 2
# ('curb', 'greenhous', 'gas', 'emiss') 2
# ('ap', 'associ', 'press', 'demonstr') 2
# ('associ', 'press', 'file', 'file') 2
# ('press', 'file', 'file', 'photo') 2
# ('associ', 'press', 'california', 'governor') 2
# ('press', 'california', 'governor', 'jerri') 2
# ('governor', 'jerri', 'brown', 'speak') 2
# ('jerri', 'brown', 'speak', 'climat') 2
# ('brown', 'speak', 'climat', 'action') 2
# ('bonn', 'germani', 'saturday', 'brown') 2
# ('germani', 'saturday', 'brown', 'michael') 2
# ('saturday', 'brown', 'michael', 'bloomberg') 2
# ('brown', 'michael', 'bloomberg', 'america') 2
# ('michael', 'bloomberg', 'america', 'pledg') 2
# ('associ', 'press', 'former', 'us') 2
# ('press', 'former', 'us', 'vice') 2
# ('presid', 'al', 'gore', 'arriv') 2
# ('al', 'gore', 'arriv', 'climat') 2
# ('gore', 'arriv', 'climat', 'action') 2
# ('arriv', 'climat', 'action', 'center') 2
# ('climat', 'action', 'center', 'america') 2
# ('action', 'center', 'america', 'pledg') 2
# ('center', 'america', 'pledg', 'still') 2
# ('america', 'pledg', 'still', 'campaign') 2
# ('pledg', 'still', 'campaign', 'cop') 2
# ('still', 'campaign', 'cop', 'fiji') 2
# ('campaign', 'cop', 'fiji', 'un') 2
# ('demonstr', 'outsid', 'cop', 'fiji') 2
# ('outsid', 'cop', 'fiji', 'un') 2
# ('associ', 'press', 'washington', 'ap') 2
# ('defens', 'secretari', 'jame', 'matti') 2
# ('vucci', 'associ', 'press', 'presid') 2
# ('associ', 'press', 'presid', 'donald') 2
# ('press', 'presid', 'donald', 'trump') 2
# ('scientif', 'consensus', 'climat', 'chang') 2
# ('germani', 'scientist', 'offici', 'europ') 2
# ('scientist', 'offici', 'europ', 'say') 2
# ('offici', 'europ', 'say', 'unit') 2
# ('europ', 'say', 'unit', 'state') 2
# ('say', 'unit', 'state', 'damag') 2
# ('unit', 'state', 'damag', 'interest') 2
# ('state', 'damag', 'interest', 'roll') 2
# ('execut', 'order', 'tuesday', 'march') 2
# ('order', 'tuesday', 'march', 'rescind') 2
# ('tuesday', 'march', 'rescind', 'suspend') 2
# ('march', 'rescind', 'suspend', 'review') 2
# ('emiss', 'power', 'plant', 'ap') 2
# ('climat', 'chang', 'good', 'news') 2
# ('employe', 'jon', 'joni', 'tap') 2
# ('jon', 'joni', 'tap', 'mapl') 2
# ('joni', 'tap', 'mapl', 'tree') 2
# ('tap', 'mapl', 'tree', 'tuesday') 2
# ('mapl', 'tree', 'tuesday', 'brooklin') 2
# ('tree', 'tuesday', 'brooklin', 'maggi') 2
# ('carbon', 'dioxid', 'primari', 'contributor') 2
# ('dioxid', 'primari', 'contributor', 'global') 2
# ('primari', 'contributor', 'global', 'warm') 2
# ('meet', 'challeng', 'climat', 'chang') 2
# ('public', 'deserv', 'know', 'impact') 2
# ('deserv', 'know', 'impact', 'might') 2
# ('know', 'impact', 'might', 'expect') 2
# ('impact', 'might', 'expect', 'nation') 2
# ('might', 'expect', 'nation', 'purs') 2
# ('expect', 'nation', 'purs', 'degrad') 2
# ('director', 'priestley', 'intern', 'centr') 2
# ('priestley', 'intern', 'centr', 'climat') 2
# ('intern', 'centr', 'climat', 'leed') 2
# ('centr', 'climat', 'leed', 'univers') 2
# ('climat', 'research', 'unit', 'univers') 2
# ('research', 'unit', 'univers', 'east') 2
# ('unit', 'univers', 'east', 'anglia') 2
# ('temperatur', 'sea', 'level', 'rise') 2
# ('nation', 'secur', 'strategi', 'presid') 2
# ('senior', 'administr', 'offici', 'said') 2
# ('us', 'pari', 'climat', 'accord') 2
# ('joanna', 'haigh', 'grantham', 'institut') 2
# ('haigh', 'grantham', 'institut', 'imperi') 2
# ('grantham', 'institut', 'imperi', 'colleg') 2
# ('institut', 'imperi', 'colleg', 'london') 2
# ('satellit', 'data', 'studi', 'sun') 2
# ('data', 'studi', 'sun', 'influenc') 2
# ('studi', 'sun', 'influenc', 'climat') 2
# ('climat', 'chang', 'one', 'biggest') 2
# ('devast', 'hurrican', 'maria', 'septemb') 2
# ('meadow', 'pipit', 'willow', 'tit') 2
# ('pipit', 'willow', 'tit', 'willow') 2
# ('willow', 'tit', 'willow', 'warbler') 2
# ('tit', 'willow', 'warbler', 'disappear') 2
# ('willow', 'warbler', 'disappear', 'site') 2
# ('avail', 'good', 'habitat', 'mean') 2
# ('climat', 'chang', 'pari', 'agreement') 2
# ('must', 'urgent', 'scale', 'scale') 2
# ('urgent', 'scale', 'scale', 'princ') 2
# ('global', 'movement', 'strength', 'bigger') 2
# ('movement', 'strength', 'bigger', 'ani') 2
# ('strength', 'bigger', 'ani', 'one') 2
# ('bigger', 'ani', 'one', 'nation') 2
# ('ani', 'one', 'nation', 'state') 2
# ('one', 'nation', 'state', 'ani') 2
# ('nation', 'state', 'ani', 'one') 2
# ('come', 'climat', 'chang', 'polici') 2
# ('subsidi', 'fossil', 'fuel', 'would') 2
# ('fossil', 'fuel', 'would', 'produc') 2
# ('depart', 'intern', 'develop', 'dfid') 2
# ('money', 'would', 'better', 'spent') 2
# ('would', 'better', 'spent', 'humanitarian') 2
# ('effect', 'climat', 'chang', 'climat') 2
# ('us', 'environment', 'protect', 'agenc') 2
# ('studi', 'impact', 'climat', 'chang') 2
# ('climat', 'chang', 'could', 'increas') 2
# ('defenc', 'say', 'climat', 'chang') 2
# ('climat', 'chang', 'could', 'exacerb') 2
# ('determin', 'potenti', 'climat', 'chang') 2
# ('regulatori', 'investig', 'sharehold', 'class') 2
# ('investig', 'sharehold', 'class', 'action') 2
# ('move', 'lower', 'carbon', 'economi') 2
# ('frequenc', 'extrem', 'weather', 'event') 2
# ('balanc', 'sheet', 'valu', 'proven') 2
# ('busi', 'risk', 'climat', 'chang') 2
# ('australian', 'council', 'superannu', 'investor') 2
# ('great', 'barrier', 'reef', 'caus') 2
# ('per', 'cent', 'believ', 'climat') 2
# ('cent', 'believ', 'climat', 'chang') 2
# ('believ', 'climat', 'chang', 'caus') 2
# ('onli', 'per', 'cent', 'respond') 2
# ('per', 'cent', 'agre', 'climat') 2
# ('cent', 'agre', 'climat', 'chang') 2
# ('agre', 'climat', 'chang', 'alreadi') 2
# ('climat', 'chang', 'alreadi', 'caus') 2
# ('chang', 'alreadi', 'caus', 'frequent') 2
# ('alreadi', 'caus', 'frequent', 'extrem') 2
# ('caus', 'frequent', 'extrem', 'flood') 2
# ('agre', 'climat', 'chang', 'pose') 2
# ('climat', 'chang', 'pose', 'serious') 2
# ('chang', 'pose', 'serious', 'threat') 2
# ('pose', 'serious', 'threat', 'way') 2
# ('serious', 'threat', 'way', 'life') 2
# ('threat', 'way', 'life', 'next') 2
# ('way', 'life', 'next', 'year') 2
# ('call', 'sweep', 'chang', 'much') 2
# ('investor', 'climat', 'chang', 'exposur') 2
# ('shift', 'away', 'fossil', 'fuel') 2
# ('shift', 'toward', 'renew', 'energi') 2
# ('manag', 'climat', 'chang', 'risk') 2
# ('prime', 'minist', 'malcolm', 'turnbul') 2
# ('risk', 'creat', 'climat', 'chang') 2
# ('per', 'cent', 'increas', 'number') 2
# ('sabin', 'centr', 'climat', 'chang') 2
# ('centr', 'climat', 'chang', 'law') 2
# ('climat', 'chang', 'focal', 'point') 2
# ('climat', 'chang', 'mitig', 'adapt') 2
# ('kenya', 'climat', 'chang', 'work') 2
# ('impact', 'climat', 'chang', 'could') 2
# ('per', 'cent', 'gross', 'domest') 2
# ('cent', 'gross', 'domest', 'product') 2
# ('various', 'articl', 'pari', 'agreement') 2
# ('gas', 'emiss', 'per', 'cent') 2
# ('accord', 'report', 'climat', 'chang') 2
# ('sustain', 'environment', 'develop', 'watch') 2
# ('environment', 'develop', 'watch', 'suswatch') 2
# ('climat', 'chang', 'get', 'serious') 2
# ('implement', 'mitig', 'adapt', 'measur') 2
# ('mitig', 'adapt', 'measur', 'climat') 2
# ('adapt', 'measur', 'climat', 'chang') 2
# ('climat', 'chang', 'global', 'issu') 2
# ('initi', 'clean', 'air', 'un') 2
# ('clean', 'air', 'un', 'framework') 2
# ('air', 'un', 'framework', 'convent') 2
# ('kyoto', 'protocol', 'pari', 'agreement') 2
# ('protocol', 'pari', 'agreement', 'recent') 2
# ('pari', 'agreement', 'recent', 'bonn') 2
# ('agreement', 'recent', 'bonn', 'confer') 2
# ('recent', 'bonn', 'confer', 'impress') 2
# ('bonn', 'confer', 'impress', 'lot') 2
# ('confer', 'impress', 'lot', 'need') 2
# ('impress', 'lot', 'need', 'done') 2
# ('lot', 'need', 'done', 'rate') 2
# ('need', 'done', 'rate', 'harm') 2
# ('done', 'rate', 'harm', 'greenhous') 2
# ('rate', 'harm', 'greenhous', 'gase') 2
# ('emit', 'atmospher', 'worri', 'increas') 2
# ('atmospher', 'worri', 'increas', 'popul') 2
# ('worri', 'increas', 'popul', 'industrialis') 2
# ('increas', 'popul', 'industrialis', 'globalis') 2
# ('popul', 'industrialis', 'globalis', 'infrastructur') 2
# ('industrialis', 'globalis', 'infrastructur', 'develop') 2
# ('globalis', 'infrastructur', 'develop', 'among') 2
# ('infrastructur', 'develop', 'among', 'factor') 2
# ('develop', 'among', 'factor', 'blame') 2
# ('among', 'factor', 'blame', 'must') 2
# ('climat', 'chang', 'gase', 'complet') 2
# ('chang', 'gase', 'complet', 'alter') 2
# ('gase', 'complet', 'alter', 'normal') 2
# ('complet', 'alter', 'normal', 'function') 2
# ('alter', 'normal', 'function', 'atmospher') 2
# ('normal', 'function', 'atmospher', 'disturb') 2
# ('exposur', 'air', 'pollut', 'damag') 2
# ('air', 'pollut', 'damag', 'ecosystem') 2
# ('lead', 'prematur', 'death', 'harm') 2
# ('prematur', 'death', 'harm', 'effect') 2
# ('death', 'harm', 'effect', 'bodi') 2
# ('harm', 'effect', 'bodi', 'system') 2
# ('respiratori', 'health', 'complic', 'therefor') 2
# ('health', 'complic', 'therefor', 'import') 2
# ('complic', 'therefor', 'import', 'serious') 2
# ('therefor', 'import', 'serious', 'govern') 2
# ('import', 'serious', 'govern', 'put') 2
# ('serious', 'govern', 'put', 'measur') 2
# ('govern', 'put', 'measur', 'mitig') 2
# ('put', 'measur', 'mitig', 'adapt') 2
# ('measur', 'mitig', 'adapt', 'climat') 2
# ('adapt', 'climat', 'chang', 'factor') 2
# ('entiti', 'must', 'help', 'state') 2
# ('polici', 'regul', 'emiss', 'individu') 2
# ('regul', 'emiss', 'individu', 'industri') 2
# ('emiss', 'individu', 'industri', 'equip') 2
# ('power', 'plant', 'cement', 'manufactur') 2
# ('plant', 'cement', 'manufactur', 'farmer') 2
# ('cement', 'manufactur', 'farmer', 'among') 2
# ('manufactur', 'farmer', 'among', 'stakehold') 2
# ('farmer', 'among', 'stakehold', 'must') 2
# ('among', 'stakehold', 'must', 'regul') 2
# ('air', 'pollut', 'research', 'must') 2
# ('pollut', 'research', 'must', 'given') 2
# ('research', 'must', 'given', 'prioriti') 2
# ('must', 'given', 'prioriti', 'becaus') 2
# ('scientif', 'find', 'matter', 'pollut') 2
# ('find', 'matter', 'pollut', 'key') 2
# ('matter', 'pollut', 'key', 'minimis') 2
# ('pollut', 'key', 'minimis', 'effect') 2
# ('key', 'minimis', 'effect', 'greenhous') 2
# ('minimis', 'effect', 'greenhous', 'gas') 2
# ('effect', 'greenhous', 'gas', 'emiss') 2
# ('greenhous', 'gas', 'emiss', 'qualiti') 2
# ('gas', 'emiss', 'qualiti', 'air') 2
# ('emiss', 'qualiti', 'air', 'standard') 2
# ('qualiti', 'air', 'standard', 'must') 2
# ('air', 'standard', 'must', 'develop') 2
# ('standard', 'must', 'develop', 'implement') 2
# ('must', 'develop', 'implement', 'legisl') 2
# ('africa', 'continu', 'experi', 'sharper') 2
# ('continu', 'experi', 'sharper', 'edg') 2
# ('experi', 'sharper', 'edg', 'climat') 2
# ('sharper', 'edg', 'climat', 'chang') 2
# ('edg', 'climat', 'chang', 'due') 2
# ('climat', 'chang', 'due', 'inabl') 2
# ('chang', 'due', 'inabl', 'reduc') 2
# ('due', 'inabl', 'reduc', 'emiss') 2
# ('inabl', 'reduc', 'emiss', 'harm') 2
# ('reduc', 'emiss', 'harm', 'gase') 2
# ('emiss', 'harm', 'gase', 'atmospher') 2
# ('harm', 'gase', 'atmospher', 'onli') 2
# ('gase', 'atmospher', 'onli', 'meet') 2
# ('atmospher', 'onli', 'meet', 'intern') 2
# ('onli', 'meet', 'intern', 'confer') 2
# ('meet', 'intern', 'confer', 'actualis') 2
# ('intern', 'confer', 'actualis', 'implement') 2
# ('confer', 'actualis', 'implement', 'plan') 2
# ('actualis', 'implement', 'plan', 'mitig') 2
# ('implement', 'plan', 'mitig', 'climat') 2
# ('plan', 'mitig', 'climat', 'chang') 2
# ('climat', 'chang', 'must', 'stop') 2
# ('chang', 'must', 'stop', 'play') 2
# ('must', 'stop', 'play', 'hide') 2
# ('stop', 'play', 'hide', 'seek') 2
# ('unit', 'nation', 'environ', 'assembl') 2
# ('advers', 'effect', 'climat', 'chang') 2
# ('kaddu', 'sebunya', 'presid', 'african') 2
# ('sebunya', 'presid', 'african', 'wildlif') 2
# ('presid', 'african', 'wildlif', 'foundat') 2
# ('african', 'wildlif', 'foundat', 'ksebunya') 2
# ('kenya', 'climat', 'chang', 'act') 2
# ('counti', 'climat', 'chang', 'fund') 2
# ('uk', 'depart', 'intern', 'develop') 2
# ('climat', 'chang', 'global', 'warm') 2
# ('global', 'climat', 'chang', 'agenda') 2
# ('climat', 'chang', 'agenda', 'crossroad') 2
# ('chang', 'agenda', 'crossroad', 'follow') 2
# ('agenda', 'crossroad', 'follow', 'recent') 2
# ('crossroad', 'follow', 'recent', 'announc') 2
# ('follow', 'recent', 'announc', 'unit') 2
# ('recent', 'announc', 'unit', 'state') 2
# ('announc', 'unit', 'state', 'pull') 2
# ('unit', 'state', 'pull', 'pari') 2
# ('state', 'pull', 'pari', 'climat') 2
# ('pari', 'climat', 'accord', 'brought') 2
# ('climat', 'accord', 'brought', 'scrutini') 2
# ('accord', 'brought', 'scrutini', 'futur') 2
# ('brought', 'scrutini', 'futur', 'commit') 2
# ('scrutini', 'futur', 'commit', 'made') 2
# ('futur', 'commit', 'made', 'govern') 2
# ('commit', 'made', 'govern', 'pari') 2
# ('made', 'govern', 'pari', 'agreement') 2
# ('govern', 'pari', 'agreement', 'near') 2
# ('pari', 'agreement', 'near', 'nation') 2
# ('agreement', 'near', 'nation', 'pledg') 2
# ('near', 'nation', 'pledg', 'limit') 2
# ('nation', 'pledg', 'limit', 'world') 2
# ('pledg', 'limit', 'world', 'temperatur') 2
# ('limit', 'world', 'temperatur', 'rise') 2
# ('world', 'temperatur', 'rise', 'era') 2
# ('beyond', 'murmur', 'futur', 'pari') 2
# ('murmur', 'futur', 'pari', 'agreement') 2
# ('futur', 'pari', 'agreement', 'us') 2
# ('pari', 'agreement', 'us', 'individu') 2
# ('agreement', 'us', 'individu', 'corpor') 2
# ('us', 'individu', 'corpor', 'across') 2
# ('individu', 'corpor', 'across', 'east') 2
# ('corpor', 'across', 'east', 'africa') 2
# ('across', 'east', 'africa', 'must') 2
# ('east', 'africa', 'must', 'guard') 2
# ('africa', 'must', 'guard', 'environ') 2
# ('must', 'guard', 'environ', 'lost') 2
# ('guard', 'environ', 'lost', 'climat') 2
# ('environ', 'lost', 'climat', 'chang') 2
# ('lost', 'climat', 'chang', 'agenda') 2
# ('mani', 'us', 'grew', 'common') 2
# ('us', 'grew', 'common', 'admonish') 2
# ('grew', 'common', 'admonish', 'money') 2
# ('common', 'admonish', 'money', 'doe') 2
# ('admonish', 'money', 'doe', 'grow') 2
# ('doe', 'grow', 'tree', 'parent') 2
# ('grow', 'tree', 'parent', 'use') 2
# ('tree', 'parent', 'use', 'line') 2
# ('parent', 'use', 'line', 'especi') 2
# ('use', 'line', 'especi', 'explain') 2
# ('line', 'especi', 'explain', 'children') 2
# ('especi', 'explain', 'children', 'money') 2
# ('explain', 'children', 'money', 'doe') 2
# ('children', 'money', 'doe', 'come') 2
# ('money', 'doe', 'come', 'easi') 2
# ('doe', 'come', 'easi', 'truth') 2
# ('come', 'easi', 'truth', 'told') 2
# ('easi', 'truth', 'told', 'money') 2
# ('truth', 'told', 'money', 'doe') 2
# ('told', 'money', 'doe', 'grow') 2
# ('doe', 'grow', 'tree', 'gift') 2
# ('grow', 'tree', 'gift', 'natur') 2
# ('tree', 'gift', 'natur', 'provid') 2
# ('gift', 'natur', 'provid', 'freeli') 2
# ('let', 'explain', 'busi', 'exist') 2
# ('explain', 'busi', 'exist', 'earn') 2
# ('busi', 'exist', 'earn', 'return') 2
# ('exist', 'earn', 'return', 'onli') 2
# ('earn', 'return', 'onli', 'happen') 2
# ('return', 'onli', 'happen', 'invest') 2
# ('onli', 'happen', 'invest', 'farmer') 2
# ('happen', 'invest', 'farmer', 'plant') 2
# ('invest', 'farmer', 'plant', 'reap') 2
# ('farmer', 'plant', 'reap', 'bank') 2
# ('plant', 'reap', 'bank', 'custom') 2
# ('reap', 'bank', 'custom', 'deposit') 2
# ('bank', 'custom', 'deposit', 'order') 2
# ('custom', 'deposit', 'order', 'withdraw') 2
# ('deposit', 'order', 'withdraw', 'environ') 2
# ('unfortun', 'mankind', 'use', 'resourc') 2
# ('mankind', 'use', 'resourc', 'earth') 2
# ('use', 'resourc', 'earth', 'unsustain') 2
# ('resourc', 'earth', 'unsustain', 'rate') 2
# ('earth', 'unsustain', 'rate', 'soon') 2
# ('unsustain', 'rate', 'soon', 'reach') 2
# ('rate', 'soon', 'reach', 'tip') 2
# ('soon', 'reach', 'tip', 'point') 2
# ('reach', 'tip', 'point', 'popul') 2
# ('tip', 'point', 'popul', 'pressur') 2
# ('point', 'popul', 'pressur', 'urbanis') 2
# ('popul', 'pressur', 'urbanis', 'industrialis') 2
# ('pressur', 'urbanis', 'industrialis', 'carefre') 2
# ('urbanis', 'industrialis', 'carefre', 'attitud') 2
# ('industrialis', 'carefre', 'attitud', 'contribut') 2
# ('carefre', 'attitud', 'contribut', 'environment') 2
# ('attitud', 'contribut', 'environment', 'degrad') 2
# ('contribut', 'environment', 'degrad', 'push') 2
# ('environment', 'degrad', 'push', 'ecosystem') 2
# ('degrad', 'push', 'ecosystem', 'brink') 2
# ('push', 'ecosystem', 'brink', 'natur') 2
# ('ecosystem', 'brink', 'natur', 'stop') 2
# ('brink', 'natur', 'stop', 'provid') 2
# ('natur', 'stop', 'provid', 'raw') 2
# ('stop', 'provid', 'raw', 'materi') 2
# ('provid', 'raw', 'materi', 'support') 2
# ('raw', 'materi', 'support', 'run') 2
# ('materi', 'support', 'run', 'busi') 2
# ('support', 'run', 'busi', 'natur') 2
# ('run', 'busi', 'natur', 'generous') 2
# ('busi', 'natur', 'generous', 'unforgiv') 2
# ('wit', 'ugli', 'side', 'climat') 2
# ('ugli', 'side', 'climat', 'chang') 2
# ('side', 'climat', 'chang', 'extrem') 2
# ('chang', 'extrem', 'weather', 'pattern') 2
# ('extrem', 'weather', 'pattern', 'becom') 2
# ('weather', 'pattern', 'becom', 'regular') 2
# ('pattern', 'becom', 'regular', 'expos') 2
# ('becom', 'regular', 'expos', 'collect') 2
# ('regular', 'expos', 'collect', 'failur') 2
# ('expos', 'collect', 'failur', 'protect') 2
# ('collect', 'failur', 'protect', 'environ') 2
# ('kenya', 'feel', 'effect', 'last') 2
# ('feel', 'effect', 'last', 'two') 2
# ('effect', 'last', 'two', 'year') 2
# ('last', 'two', 'year', 'experienc') 2
# ('two', 'year', 'experienc', 'depress') 2
# ('year', 'experienc', 'depress', 'rainfal') 2
# ('experienc', 'depress', 'rainfal', 'devast') 2
# ('depress', 'rainfal', 'devast', 'drought') 2
# ('rainfal', 'devast', 'drought', 'critic') 2
# ('devast', 'drought', 'critic', 'address') 2
# ('drought', 'critic', 'address', 'challeng') 2
# ('critic', 'address', 'challeng', 'today') 2
# ('address', 'challeng', 'today', 'secur') 2
# ('challeng', 'today', 'secur', 'futur') 2
# ('today', 'secur', 'futur', 'want') 2
# ('secur', 'futur', 'want', 'grow') 2
# ('futur', 'want', 'grow', 'busi') 2
# ('want', 'grow', 'busi', 'sustain') 2
# ('ever', 'pay', 'attent', 'big') 2
# ('pay', 'attent', 'big', 'energi') 2
# ('attent', 'big', 'energi', 'shift') 2
# ('big', 'energi', 'shift', 'surviv') 2
# ('energi', 'shift', 'surviv', 'shift') 2
# ('shift', 'surviv', 'shift', 'wood') 2
# ('surviv', 'shift', 'wood', 'coal') 2
# ('shift', 'wood', 'coal', 'gave') 2
# ('wood', 'coal', 'gave', 'way') 2
# ('coal', 'gave', 'way', 'crude') 2
# ('gave', 'way', 'crude', 'oil') 2
# ('way', 'crude', 'oil', 'natur') 2
# ('crude', 'oil', 'natur', 'gas') 2
# ('oil', 'natur', 'gas', 'run') 2
# ('natur', 'gas', 'run', 'economi') 2
# ('gas', 'run', 'economi', 'took') 2
# ('run', 'economi', 'took', 'decad') 2
# ('time', 'come', 'us', 'shift') 2
# ('come', 'us', 'shift', 'renew') 2
# ('us', 'shift', 'renew', 'sourc') 2
# ('shift', 'renew', 'sourc', 'sound') 2
# ('renew', 'sourc', 'sound', 'busi') 2
# ('sourc', 'sound', 'busi', 'continu') 2
# ('sound', 'busi', 'continu', 'take') 2
# ('busi', 'continu', 'take', 'stock') 2
# ('continu', 'take', 'stock', 'asset') 2
# ('take', 'stock', 'asset', 'know') 2
# ('stock', 'asset', 'know', 'stand') 2
# ('asset', 'know', 'stand', 'busi') 2
# ('know', 'stand', 'busi', 'individu') 2
# ('stand', 'busi', 'individu', 'must') 2
# ('busi', 'individu', 'must', 'take') 2
# ('individu', 'must', 'take', 'stock') 2
# ('must', 'take', 'stock', 'posit') 2
# ('take', 'stock', 'posit', 'negat') 2
# ('stock', 'posit', 'negat', 'impact') 2
# ('posit', 'negat', 'impact', 'natur') 2
# ('negat', 'impact', 'natur', 'environ') 2
# ('impact', 'natur', 'environ', 'global') 2
# ('natur', 'environ', 'global', 'financi') 2
# ('environ', 'global', 'financi', 'institut') 2
# ('global', 'financi', 'institut', 'lead') 2
# ('financi', 'institut', 'lead', 'way') 2
# ('institut', 'lead', 'way', 'align') 2
# ('lead', 'way', 'align', 'busi') 2
# ('way', 'align', 'busi', 'environment') 2
# ('align', 'busi', 'environment', 'sustain') 2
# ('kcb', 'group', 'exampl', 'seek') 2
# ('group', 'exampl', 'seek', 'sustain') 2
# ('exampl', 'seek', 'sustain', 'bank') 2
# ('seek', 'sustain', 'bank', 'know') 2
# ('sustain', 'bank', 'know', 'onli') 2
# ('bank', 'know', 'onli', 'way') 2
# ('know', 'onli', 'way', 'ensur') 2
# ('onli', 'way', 'ensur', 'busi') 2
# ('way', 'ensur', 'busi', 'success') 2
# ('ensur', 'busi', 'success', 'contribut') 2
# ('busi', 'success', 'contribut', 'toward') 2
# ('success', 'contribut', 'toward', 'econom') 2
# ('contribut', 'toward', 'econom', 'social') 2
# ('toward', 'econom', 'social', 'develop') 2
# ('econom', 'social', 'develop', 'healthi') 2
# ('social', 'develop', 'healthi', 'environ') 2
# ('develop', 'healthi', 'environ', 'stabl') 2
# ('healthi', 'environ', 'stabl', 'societi') 2
# ('green', 'climat', 'fund', 'kcb') 2
# ('kcb', 'recent', 'nomin', 'nation') 2
# ('recent', 'nomin', 'nation', 'treasuri') 2
# ('nomin', 'nation', 'treasuri', 'accredit') 2
# ('nation', 'treasuri', 'accredit', 'green') 2
# ('treasuri', 'accredit', 'green', 'climat') 2
# ('accredit', 'green', 'climat', 'fund') 2
# ('climat', 'fund', 'gcf', 'tune') 2
# ('fund', 'gcf', 'tune', 'us') 2
# ('gcf', 'tune', 'us', 'million') 2
# ('tune', 'us', 'million', 'given') 2
# ('us', 'million', 'given', 'urgenc') 2
# ('million', 'given', 'urgenc', 'serious') 2
# ('given', 'urgenc', 'serious', 'climat') 2
# ('urgenc', 'serious', 'climat', 'chang') 2
# ('serious', 'climat', 'chang', 'gcf') 2
# ('climat', 'chang', 'gcf', 'meant') 2
# ('chang', 'gcf', 'meant', 'make') 2
# ('gcf', 'meant', 'make', 'signific') 2
# ('meant', 'make', 'signific', 'ambiti') 2
# ('make', 'signific', 'ambiti', 'contribut') 2
# ('signific', 'ambiti', 'contribut', 'global') 2
# ('ambiti', 'contribut', 'global', 'effort') 2
# ('contribut', 'global', 'effort', 'toward') 2
# ('global', 'effort', 'toward', 'attain') 2
# ('effort', 'toward', 'attain', 'goal') 2
# ('toward', 'attain', 'goal', 'set') 2
# ('attain', 'goal', 'set', 'combat') 2
# ('goal', 'set', 'combat', 'climat') 2
# ('set', 'combat', 'climat', 'chang') 2
# ('combat', 'climat', 'chang', 'fund') 2
# ('climat', 'chang', 'fund', 'contribut') 2
# ('chang', 'fund', 'contribut', 'achiev') 2
# ('fund', 'contribut', 'achiev', 'ultim') 2
# ('contribut', 'achiev', 'ultim', 'object') 2
# ('achiev', 'ultim', 'object', 'unit') 2
# ('ultim', 'object', 'unit', 'nation') 2
# ('object', 'unit', 'nation', 'framework') 2
# ('context', 'sustain', 'develop', 'fund') 2
# ('sustain', 'develop', 'fund', 'promot') 2
# ('develop', 'fund', 'promot', 'paradigm') 2
# ('fund', 'promot', 'paradigm', 'shift') 2
# ('promot', 'paradigm', 'shift', 'toward') 2
# ('paradigm', 'shift', 'toward', 'low') 2
# ('shift', 'toward', 'low', 'emiss') 2
# ('toward', 'low', 'emiss', 'develop') 2
# ('low', 'emiss', 'develop', 'pathway') 2
# ('emiss', 'develop', 'pathway', 'provid') 2
# ('develop', 'pathway', 'provid', 'support') 2
# ('pathway', 'provid', 'support', 'develop') 2
# ('provid', 'support', 'develop', 'countri') 2
# ('support', 'develop', 'countri', 'limit') 2
# ('develop', 'countri', 'limit', 'reduc') 2
# ('countri', 'limit', 'reduc', 'greenhous') 2
# ('limit', 'reduc', 'greenhous', 'gas') 2
# ('greenhous', 'gas', 'emiss', 'adapt') 2
# ('gas', 'emiss', 'adapt', 'impact') 2
# ('emiss', 'adapt', 'impact', 'climat') 2
# ('impact', 'climat', 'chang', 'commit') 2
# ('climat', 'chang', 'commit', 'meet') 2
# ('chang', 'commit', 'meet', 'busi') 2
# ('commit', 'meet', 'busi', 'need') 2
# ('meet', 'busi', 'need', 'today') 2
# ('busi', 'need', 'today', 'without') 2
# ('need', 'today', 'without', 'compromis') 2
# ('today', 'without', 'compromis', 'live') 2
# ('without', 'compromis', 'live', 'futur') 2
# ('compromis', 'live', 'futur', 'generat') 2
# ('sustain', 'framework', 'outlin', 'various') 2
# ('framework', 'outlin', 'various', 'strateg') 2
# ('outlin', 'various', 'strateg', 'initi') 2
# ('various', 'strateg', 'initi', 'includ') 2
# ('strateg', 'initi', 'includ', 'respons') 2
# ('initi', 'includ', 'respons', 'lend') 2
# ('includ', 'respons', 'lend', 'incorpor') 2
# ('respons', 'lend', 'incorpor', 'environment') 2
# ('lend', 'incorpor', 'environment', 'due') 2
# ('incorpor', 'environment', 'due', 'dilig') 2
# ('environment', 'due', 'dilig', 'befor') 2
# ('due', 'dilig', 'befor', 'give') 2
# ('dilig', 'befor', 'give', 'loan') 2
# ('manag', 'energi', 'conserv', 'reduc') 2
# ('energi', 'conserv', 'reduc', 'consumpt') 2
# ('conserv', 'reduc', 'consumpt', 'utilis') 2
# ('reduc', 'consumpt', 'utilis', 'green') 2
# ('consumpt', 'utilis', 'green', 'energi') 2
# ('utilis', 'green', 'energi', 'intellig') 2
# ('green', 'energi', 'intellig', 'build') 2
# ('energi', 'intellig', 'build', 'technolog') 2
# ('intellig', 'build', 'technolog', 'good') 2
# ('build', 'technolog', 'good', 'exampl') 2
# ('technolog', 'good', 'exampl', 'new') 2
# ('good', 'exampl', 'new', 'headquart') 2
# ('exampl', 'new', 'headquart', 'upper') 2
# ('new', 'headquart', 'upper', 'hill') 2
# ('headquart', 'upper', 'hill', 'one') 2
# ('upper', 'hill', 'one', 'build') 2
# ('use', 'natur', 'light', 'dure') 2
# ('natur', 'light', 'dure', 'day') 2
# ('light', 'dure', 'day', 'fit') 2
# ('dure', 'day', 'fit', 'solar') 2
# ('day', 'fit', 'solar', 'panel') 2
# ('fit', 'solar', 'panel', 'reduc') 2
# ('solar', 'panel', 'reduc', 'consumpt') 2
# ('panel', 'reduc', 'consumpt', 'electr') 2
# ('reduc', 'consumpt', 'electr', 'smart') 2
# ('consumpt', 'electr', 'smart', 'technolog') 2
# ('electr', 'smart', 'technolog', 'regul') 2
# ('smart', 'technolog', 'regul', 'consumpt') 2
# ('technolog', 'regul', 'consumpt', 'water') 2
# ('regul', 'consumpt', 'water', 'energi') 2
# ('consumpt', 'water', 'energi', 'incorpor') 2
# ('water', 'energi', 'incorpor', 'water') 2
# ('energi', 'incorpor', 'water', 'harvest') 2
# ('incorpor', 'water', 'harvest', 'also') 2
# ('water', 'harvest', 'also', 'forefront') 2
# ('harvest', 'also', 'forefront', 'explor') 2
# ('also', 'forefront', 'explor', 'issuanc') 2
# ('forefront', 'explor', 'issuanc', 'green') 2
# ('explor', 'issuanc', 'green', 'bond') 2
# ('issuanc', 'green', 'bond', 'rais') 2
# ('green', 'bond', 'rais', 'capit') 2
# ('bond', 'rais', 'capit', 'support') 2
# ('rais', 'capit', 'support', 'environment') 2
# ('capit', 'support', 'environment', 'climat') 2
# ('support', 'environment', 'climat', 'relat') 2
# ('environment', 'climat', 'relat', 'project') 2
# ('climat', 'relat', 'project', 'like') 2
# ('relat', 'project', 'like', 'busi') 2
# ('project', 'like', 'busi', 'cut') 2
# ('like', 'busi', 'cut', 'amount') 2
# ('busi', 'cut', 'amount', 'paper') 2
# ('cut', 'amount', 'paper', 'use') 2
# ('amount', 'paper', 'use', 'reduc') 2
# ('paper', 'use', 'reduc', 'need') 2
# ('use', 'reduc', 'need', 'travel') 2
# ('reduc', 'need', 'travel', 'subsidiari') 2
# ('need', 'travel', 'subsidiari', 'use') 2
# ('travel', 'subsidiari', 'use', 'meet') 2
# ('subsidiari', 'use', 'meet', 'everi') 2
# ('use', 'meet', 'everi', 'littl') 2
# ('meet', 'everi', 'littl', 'help') 2
# ('everi', 'littl', 'help', 'oigara') 2
# ('littl', 'help', 'oigara', 'kcb') 2
# ('help', 'oigara', 'kcb', 'group') 2
# ('oigara', 'kcb', 'group', 'chief') 2
# ('kcb', 'group', 'chief', 'execut') 2
# ('group', 'chief', 'execut', 'offic') 2
# ('chief', 'execut', 'offic', 'manag') 2
# ('execut', 'offic', 'manag', 'director') 2
# ('degre', 'celsius', 'abov', 'level') 2
# ('agre', 'set', 'climat', 'chang') 2
# ('water', 'forest', 'energi', 'disast') 2
# ('state', 'climat', 'chang', 'wing') 2
# ('climat', 'chang', 'wing', 'work') 2
# ('forest', 'divis', 'state', 'work') 2
# ('divis', 'state', 'work', 'plan') 2
# ('nation', 'work', 'plan', 'code') 2
# ('approv', 'chief', 'wildlif', 'warden') 2
# ('djk', 'sharma', 'addit', 'princip') 2
# ('sharma', 'addit', 'princip', 'chief') 2
# ('addit', 'princip', 'chief', 'conserv') 2
# ('chief', 'conserv', 'forest', 'environ') 2
# ('conserv', 'forest', 'environ', 'climat') 2
# ('forest', 'environ', 'climat', 'chang') 2
# ('climat', 'chang', 'work', 'plan') 2
# ('chang', 'work', 'plan', 'forest') 2
# ('jha', 'nodal', 'offic', 'environ') 2
# ('nodal', 'offic', 'environ', 'climat') 2
# ('offic', 'environ', 'climat', 'chang') 2
# ('differ', 'indic', 'climat', 'chang') 2
# ('forest', 'divis', 'would', 'take') 2
# ('divis', 'would', 'take', 'account') 2
# ('rashmi', 'bajaj', 'consult', 'unit') 2
# ('bajaj', 'consult', 'unit', 'nation') 2
# ('consult', 'unit', 'nation', 'develop') 2
# ('climat', 'chang', 'uttarakhand', 'said') 2
# ('chang', 'uttarakhand', 'said', 'state') 2
# ('uttarakhand', 'said', 'state', 'depart') 2
# ('due', 'extrem', 'weather', 'event') 2
# ('centr', 'climat', 'chang', 'empri') 2
# ('coastal', 'communiti', 'tropic', 'countri') 2
# ('increas', 'sea', 'surfac', 'temperatur') 2
# ('said', 'virbhadra', 'singh', 'said') 2
# ('nation', 'develop', 'program', 'undp') 2
# ('state', 'prepar', 'action', 'plan') 2
# ('climat', 'chang', 'energi', 'resourc') 2
# ('chang', 'energi', 'resourc', 'institut') 2
# ('energi', 'resourc', 'institut', 'teri') 2
# ('climat', 'chang', 'adapt', 'measur') 2
# ('total', 'budget', 'depart', 'toward') 2
# ('budget', 'depart', 'toward', 'climat') 2
# ('depart', 'toward', 'climat', 'chang') 2
# ('implement', 'state', 'action', 'plan') 2
# ('manoj', 'pant', 'chief', 'coordin') 2
# ('pant', 'chief', 'coordin', 'offic') 2
# ('chief', 'coordin', 'offic', 'state') 2
# ('coordin', 'offic', 'state', 'plan') 2
# ('offic', 'state', 'plan', 'depart') 2
# ('state', 'plan', 'depart', 'told') 2
# ('plan', 'depart', 'told', 'toi') 2
# ('alloc', 'total', 'budget', 'depart') 2
# ('scheme', 'sustain', 'develop', 'goal') 2
# ('said', 'separ', 'fund', 'climat') 2
# ('separ', 'fund', 'climat', 'chang') 2
# ('fund', 'climat', 'chang', 'would') 2
# ('depart', 'field', 'climat', 'chang') 2
# ('field', 'climat', 'chang', 'good') 2
# ('climat', 'chang', 'good', 'begin') 2
# ('chang', 'good', 'begin', 'made') 2
# ('good', 'begin', 'made', 'environ') 2
# ('begin', 'made', 'environ', 'wing') 2
# ('made', 'environ', 'wing', 'state') 2
# ('state', 'forest', 'depart', 'abl') 2
# ('forest', 'depart', 'abl', 'bring') 2
# ('depart', 'abl', 'bring', 'togeth') 2
# ('abl', 'bring', 'togeth', 'senior') 2
# ('bring', 'togeth', 'senior', 'offici') 2
# ('togeth', 'senior', 'offici', 'differ') 2
# ('senior', 'offici', 'differ', 'depart') 2
# ('offici', 'differ', 'depart', 'one') 2
# ('differ', 'depart', 'one', 'roof') 2
# ('depart', 'one', 'roof', 'discuss') 2
# ('one', 'roof', 'discuss', 'mandat') 2
# ('roof', 'discuss', 'mandat', 'strategi') 2
# ('discuss', 'mandat', 'strategi', 'implement') 2
# ('mandat', 'strategi', 'implement', 'sapcc') 2
# ('strategi', 'implement', 'sapcc', 'activ') 2
# ('implement', 'sapcc', 'activ', 'mix') 2
# ('sapcc', 'activ', 'mix', 'budget') 2
# ('serv', 'purpos', 'hope', 'new') 2
# ('purpos', 'hope', 'new', 'govern') 2
# ('hope', 'new', 'govern', 'state') 2
# ('pay', 'heed', 'said', 'major') 2
# ('heed', 'said', 'major', 'decis') 2
# ('said', 'major', 'decis', 'expand') 2
# ('major', 'decis', 'expand', 'base') 2
# ('decis', 'expand', 'base', 'prioriti') 2
# ('expand', 'base', 'prioriti', 'area') 2
# ('base', 'prioriti', 'area', 'also') 2
# ('prioriti', 'area', 'also', 'taken') 2
# ('area', 'also', 'taken', 'meet') 2
# ('also', 'taken', 'meet', 'held') 2
# ('taken', 'meet', 'held', 'environ') 2
# ('meet', 'held', 'environ', 'wing') 2
# ('held', 'environ', 'wing', 'offici') 2
# ('environ', 'wing', 'offici', 'state') 2
# ('wing', 'offici', 'state', 'govern') 2
# ('offici', 'state', 'govern', 'depart') 2
# ('state', 'govern', 'depart', 'unit') 2
# ('govern', 'depart', 'unit', 'nation') 2
# ('depart', 'unit', 'nation', 'develop') 2
# ('chief', 'conserv', 'forest', 'nodal') 2
# ('conserv', 'forest', 'nodal', 'offic') 2
# ('forest', 'nodal', 'offic', 'climat') 2
# ('select', 'four', 'prioriti', 'area') 2
# ('forest', 'energi', 'disast', 'manag') 2
# ('energi', 'disast', 'manag', 'adapt') 2
# ('disast', 'manag', 'adapt', 'implement') 2
# ('manag', 'adapt', 'implement', 'climat') 2
# ('adapt', 'implement', 'climat', 'chang') 2
# ('take', 'area', 'main', 'educ') 2
# ('educ', 'much', 'earli', 'stage') 2
# ('induc', 'sensit', 'understand', 'toward') 2
# ('sensit', 'understand', 'toward', 'extent') 2
# ('understand', 'toward', 'extent', 'magnitud') 2
# ('toward', 'extent', 'magnitud', 'way') 2
# ('extent', 'magnitud', 'way', 'deal') 2
# ('climat', 'chang', 'habitat', 'area') 2
# ('amalgam', 'depart', 'complement', 'mandat') 2
# ('depart', 'complement', 'mandat', 'tourism') 2
# ('complement', 'mandat', 'tourism', 'transport') 2
# ('mandat', 'tourism', 'transport', 'agricultur') 2
# ('transport', 'agricultur', 'horticultur', 'anim') 2
# ('agricultur', 'horticultur', 'anim', 'husbandri') 2
# ('horticultur', 'anim', 'husbandri', 'way') 2
# ('anim', 'husbandri', 'way', 'abl') 2
# ('husbandri', 'way', 'abl', 'bring') 2
# ('way', 'abl', 'bring', 'import') 2
# ('abl', 'bring', 'import', 'sector') 2

# %%
from nltk.util import skipgrams

# %%
newsWords = news['normalized_tokens'].sum()
skipgrams = skipgrams(newsWords, 3, 3) # trigrams, skip 3 words

skipFiltered = countDict(list(skipgrams))
printDesc(skipFiltered)
# Out:
# ('climat', 'chang', 'climat') 55
# ('climat', 'chang', 'said') 49
# ('impact', 'climat', 'chang') 45
# ('greenhous', 'gas', 'emiss') 40
# ('chang', 'climat', 'chang') 39
# ('said', 'climat', 'chang') 33
# ('risk', 'climat', 'chang') 32
# ('presid', 'donald', 'trump') 31
# ('climat', 'chang', 'confer') 31
# ('effect', 'climat', 'chang') 31
# ('ap', 'associ', 'press') 30
# ('un', 'climat', 'chang') 28
# ('climat', 'climat', 'chang') 28
# ('climat', 'chang', 'chang') 28
# ('climat', 'chang', 'global') 27
# ('nation', 'climat', 'chang') 27
# ('global', 'climat', 'chang') 27
# ('state', 'climat', 'chang') 26
# ('adapt', 'climat', 'chang') 26
# ('trump', 'climat', 'chang') 25
# ('action', 'climat', 'chang') 25
# ('climat', 'chang', 'risk') 25
# ('climat', 'confer', 'bonn') 24
# ('confer', 'bonn', 'germani') 23
# ('chang', 'confer', 'bonn') 22
# ('climat', 'chang', 'trump') 22
# ('climat', 'chang', 'bonn') 21
# ('climat', 'chang', 'real') 21
# ('climat', 'chang', 'action') 21
# ('un', 'climat', 'confer') 21
# ('climat', 'bonn', 'germani') 21
# ('climat', 'chang', 'polici') 20
# ('convent', 'climat', 'chang') 20
# ('climat', 'chang', 'impact') 20
# ('climat', 'chang', 'threat') 20
# ('climat', 'chang', 'state') 20
# ('climat', 'chang', 'issu') 19
# ('pari', 'climat', 'chang') 19
# ('framework', 'climat', 'chang') 19
# ('govern', 'climat', 'chang') 19
# ('unit', 'climat', 'chang') 19
# ('un', 'chang', 'confer') 19
# ('climat', 'confer', 'germani') 19
# ('climat', 'chang', 'nation') 18
# ('climat', 'chang', 'adapt') 18
# ('chang', 'bonn', 'germani') 18
# ('fight', 'climat', 'chang') 17
# ('plan', 'climat', 'chang') 17
# ('framework', 'convent', 'climat') 17
# ('climat', 'chang', 'also') 17
# ('say', 'climat', 'chang') 17
# ('chang', 'confer', 'germani') 17
# ('climat', 'chang', 'depart') 17
# ('climat', 'chang', 'agreement') 16
# ('us', 'presid', 'trump') 16
# ('us', 'donald', 'trump') 16
# ('climat', 'chang', 'alreadi') 16
# ('climat', 'chang', 'would') 16
# ('us', 'climat', 'chang') 16
# ('deal', 'climat', 'chang') 16
# ('tackl', 'climat', 'chang') 16
# ('climat', 'chang', 'work') 16
# ('climat', 'chang', 'germani') 16
# ('unit', 'nation', 'climat') 16
# ('copyright', 'arab', 'news') 15
# ('us', 'presid', 'donald') 15
# ('climat', 'chang', 'pari') 15
# ('framework', 'convent', 'chang') 15
# ('climat', 'chang', 'us') 15
# ('un', 'climat', 'bonn') 15
# ('un', 'confer', 'bonn') 15
# ('extrem', 'weather', 'event') 15
# ('confer', 'bonn', 'saturday') 15
# ('confer', 'germani', 'saturday') 15
# ('bonn', 'germani', 'saturday') 15
# ('climat', 'chang', 'presid') 14
# ('donald', 'trump', 'pari') 14
# ('rise', 'sea', 'level') 14
# ('climat', 'chang', 'caus') 14
# ('climat', 'chang', 'countri') 14
# ('climat', 'chang', 'china') 14
# ('climat', 'chang', 'need') 14
# ('climat', 'chang', 'fund') 14
# ('un', 'chang', 'bonn') 14
# ('unit', 'nation', 'chang') 14
# ('climat', 'chang', 'say') 14
# ('cop', 'fiji', 'un') 14
# ('cop', 'fiji', 'climat') 14
# ('cop', 'fiji', 'chang') 14
# ('cop', 'fiji', 'confer') 14
# ('cop', 'un', 'climat') 14
# ('cop', 'un', 'chang') 14
# ('cop', 'un', 'confer') 14
# ('cop', 'climat', 'chang') 14
# ('cop', 'climat', 'confer') 14
# ('cop', 'chang', 'confer') 14
# ('fiji', 'un', 'climat') 14
# ('fiji', 'un', 'chang') 14
# ('fiji', 'un', 'confer') 14
# ('fiji', 'climat', 'chang') 14
# ('fiji', 'climat', 'confer') 14
# ('fiji', 'chang', 'confer') 14
# ('depart', 'climat', 'chang') 14
# ('take', 'climat', 'chang') 13
# ('mitig', 'climat', 'chang') 13
# ('address', 'climat', 'chang') 13
# ('pari', 'climat', 'accord') 13
# ('measur', 'climat', 'chang') 13
# ('climat', 'chang', 'weather') 13
# ('agre', 'climat', 'chang') 13
# ('climat', 'chang', 'effect') 13
# ('climat', 'chang', 'temperatur') 13
# ('respons', 'climat', 'chang') 13
# ('challeng', 'climat', 'chang') 13
# ('need', 'climat', 'chang') 13
# ('combat', 'climat', 'chang') 13
# ('climat', 'chang', 'take') 13
# ('peopl', 'climat', 'chang') 13
# ('climat', 'chang', 'plan') 13
# ('implement', 'climat', 'chang') 13
# ('climat', 'chang', 'year') 12
# ('pari', 'climat', 'agreement') 12
# ('climat', 'chang', 'world') 12
# ('climat', 'chang', 'accord') 12
# ('energi', 'climat', 'chang') 12
# ('climat', 'chang', 'one') 12
# ('climat', 'chang', 'project') 12
# ('climat', 'chang', 'agricultur') 12
# ('climat', 'chang', 'part') 12
# ('climat', 'chang', 'sustain') 12
# ('busi', 'climat', 'chang') 12
# ('world', 'climat', 'chang') 12
# ('trump', 'pull', 'pari') 12
# ('un', 'climat', 'germani') 12
# ('un', 'chang', 'germani') 12
# ('un', 'confer', 'germani') 12
# ('un', 'bonn', 'germani') 12
# ('help', 'climat', 'chang') 12
# ('effort', 'climat', 'chang') 12
# ('ap', 'meissner', 'associ') 12
# ('ap', 'meissner', 'press') 12
# ('meissner', 'associ', 'press') 12
# ('climat', 'chang', 'could') 12
# ('climat', 'chang', 'expect') 11
# ('presid', 'trump', 'pari') 11
# ('panel', 'climat', 'chang') 11
# ('climat', 'chang', 'increas') 11
# ('pari', 'agreement', 'climat') 11
# ('also', 'climat', 'chang') 11
# ('countri', 'climat', 'chang') 11
# ('report', 'climat', 'chang') 11
# ('vulner', 'climat', 'chang') 11
# ('climat', 'chang', 'secur') 11
# ('climat', 'chang', 'serious') 11
# ('studi', 'climat', 'chang') 11
# ('climat', 'chang', 'human') 11
# ('climat', 'chang', 'act') 11
# ('threat', 'climat', 'chang') 11
# ('fiji', 'un', 'bonn') 11
# ('fiji', 'climat', 'bonn') 11
# ('fiji', 'chang', 'bonn') 11
# ('fiji', 'confer', 'bonn') 11
# ('climat', 'chang', 'saturday') 11
# ('climat', 'confer', 'saturday') 11
# ('climat', 'bonn', 'saturday') 11
# ('climat', 'germani', 'saturday') 11
# ('chang', 'confer', 'saturday') 11
# ('chang', 'bonn', 'saturday') 11
# ('chang', 'germani', 'saturday') 11
# ('forest', 'climat', 'chang') 11
# ('action', 'plan', 'climat') 11
# ('state', 'action', 'plan') 11
# ('new', 'climat', 'chang') 10
# ('climat', 'chang', 'get') 10
# ('agreement', 'climat', 'chang') 10
# ('research', 'climat', 'chang') 10
# ('year', 'climat', 'chang') 10
# ('climat', 'chang', 'made') 10
# ('climat', 'chang', 'reduc') 10
# ('climat', 'chang', 'rise') 10
# ('donald', 'trump', 'climat') 10
# ('climat', 'chang', 'research') 10
# ('pull', 'pari', 'agreement') 10
# ('climat', 'chang', 'onli') 10
# ('trump', 'nation', 'secur') 10
# ('climat', 'chang', 'govern') 10
# ('would', 'climat', 'chang') 10
# ('climat', 'chang', 'report') 10
# ('centr', 'climat', 'chang') 10
# ('climat', 'chang', 'environ') 10
# ('per', 'cent', 'per') 10
# ('cent', 'per', 'cent') 10
# ('climat', 'chang', 'litig') 10
# ('environ', 'climat', 'chang') 10
# ('green', 'climat', 'fund') 10
# ('action', 'plan', 'chang') 10
# ('issu', 'climat', 'chang') 9
# ('climat', 'chang', 'challeng') 9
# ('disast', 'climat', 'chang') 9
# ('presid', 'donald', 'pari') 9
# ('cost', 'climat', 'chang') 9
# ('keep', 'temperatur', 'rise') 9
# ('pari', 'agreement', 'chang') 9
# ('environment', 'protect', 'agenc') 9
# ('climat', 'chang', 'due') 9
# ('climat', 'chang', 'economi') 9
# ('climat', 'chang', 'recent') 9
# ('sea', 'level', 'rise') 9
# ('fossil', 'fuel', 'energi') 9
# ('global', 'temperatur', 'rise') 9
# ('china', 'climat', 'chang') 9
# ('rise', 'climat', 'chang') 9
# ('climat', 'chang', 'includ') 9
# ('climat', 'chang', 'unit') 9
# ('unit', 'state', 'pari') 9
# ('chang', 'pari', 'agreement') 9
# ('climat', 'chang', 'agenda') 9
# ('trump', 'pari', 'agreement') 9
# ('donald', 'trump', 'pull') 9
# ('unit', 'nation', 'framework') 9
# ('unit', 'framework', 'climat') 9
# ('unit', 'framework', 'chang') 9
# ('nation', 'framework', 'climat') 9
# ('nation', 'framework', 'chang') 9
# ('climat', 'presid', 'trump') 9
# ('nation', 'secur', 'strategi') 9
# ('climat', 'chang', 'extrem') 9
# ('germani', 'saturday', 'ap') 9
# ('germani', 'saturday', 'associ') 9
# ('germani', 'ap', 'associ') 9
# ('saturday', 'ap', 'associ') 9
# ('saturday', 'ap', 'press') 9
# ('saturday', 'associ', 'press') 9
# ('associ', 'press', 'presid') 9
# ('climat', 'action', 'center') 9
# ('polici', 'climat', 'chang') 9
# ('climat', 'chang', 'develop') 9
# ('manag', 'climat', 'chang') 9
# ('state', 'action', 'climat') 9
# ('state', 'plan', 'climat') 9
# ('fund', 'climat', 'chang') 8
# ('climat', 'chang', 'busi') 8
# ('stop', 'climat', 'chang') 8
# ('intergovernment', 'panel', 'climat') 8
# ('intergovernment', 'panel', 'chang') 8
# ('intergovernment', 'climat', 'chang') 8
# ('time', 'climat', 'chang') 8
# ('climat', 'chang', 'emiss') 8
# ('presid', 'climat', 'chang') 8
# ('think', 'climat', 'chang') 8
# ('believ', 'climat', 'chang') 8
# ('includ', 'climat', 'chang') 8
# ('climat', 'action', 'state') 8
# ('concern', 'climat', 'chang') 8
# ('climat', 'chang', 'new') 8
# ('public', 'climat', 'chang') 8
# ('assess', 'climat', 'chang') 8
# ('climat', 'chang', 'vulner') 8
# ('econom', 'climat', 'chang') 8
# ('region', 'climat', 'chang') 8
# ('caus', 'climat', 'chang') 8
# ('climat', 'chang', 'industri') 8
# ('cooper', 'climat', 'chang') 8
# ('unit', 'state', 'climat') 8
# ('climat', 'pari', 'agreement') 8
# ('climat', 'chang', 'energi') 8
# ('climat', 'chang', 'natur') 8
# ('climat', 'chang', 'area') 8
# ('climat', 'chang', 'cooper') 8
# ('us', 'pari', 'agreement') 8
# ('climat', 'chang', 'sinc') 8
# ('financi', 'climat', 'chang') 8
# ('presid', 'trump', 'pull') 8
# ('presid', 'pull', 'pari') 8
# ('climat', 'chang', 'commit') 8
# ('unit', 'nation', 'convent') 8
# ('unit', 'framework', 'convent') 8
# ('unit', 'convent', 'climat') 8
# ('unit', 'convent', 'chang') 8
# ('nation', 'framework', 'convent') 8
# ('nation', 'convent', 'climat') 8
# ('nation', 'convent', 'chang') 8
# ('climat', 'chang', 'donald') 8
# ('climat', 'donald', 'trump') 8
# ('chang', 'presid', 'donald') 8
# ('chang', 'presid', 'trump') 8
# ('chang', 'donald', 'trump') 8
# ('climat', 'chang', 'affect') 8
# ('chang', 'secur', 'threat') 8
# ('set', 'climat', 'chang') 8
# ('bear', 'protest', 'climat') 8
# ('protest', 'climat', 'confer') 8
# ('climat', 'confer', 'cop') 8
# ('press', 'donald', 'trump') 8
# ('pull', 'pari', 'accord') 8
# ('climat', 'action', 'cop') 8
# ('america', 'pledg', 'campaign') 8
# ('produc', 'climat', 'chang') 8
# ('climat', 'chang', 'per') 8
# ('weather', 'climat', 'chang') 8
# ('due', 'climat', 'chang') 8
# ('per', 'per', 'cent') 8
# ('counti', 'climat', 'chang') 8
# ('climat', 'chang', 'cell') 8
# ('state', 'action', 'chang') 8
# ('state', 'plan', 'chang') 8
# ('climat', 'chang', 'forest') 8
# ('develop', 'climat', 'chang') 7
# ('climat', 'chang', 'peopl') 7
# ('climat', 'chang', 'becaus') 7
# ('climat', 'chang', 'problem') 7
# ('sustain', 'develop', 'goal') 7
# ('reduc', 'greenhous', 'gas') 7
# ('reduc', 'greenhous', 'emiss') 7
# ('reduc', 'gas', 'emiss') 7
# ('law', 'climat', 'chang') 7
# ('trump', 'pari', 'accord') 7
# ('climat', 'chang', 'un') 7
# ('climat', 'global', 'warm') 7
# ('un', 'framework', 'climat') 7
# ('un', 'convent', 'climat') 7
# ('former', 'new', 'york') 7
# ('new', 'york', 'mayor') 7
# ('scienc', 'climat', 'chang') 7
# ('confer', 'climat', 'chang') 7
# ('climat', 'chang', 'address') 7
# ('like', 'climat', 'chang') 7
# ('lead', 'climat', 'chang') 7
# ('burn', 'fossil', 'fuel') 7
# ('climat', 'chang', 'point') 7
# ('climat', 'chang', 'public') 7
# ('increas', 'climat', 'chang') 7
# ('climat', 'chang', 'pose') 7
# ('climat', 'chang', 'product') 7
# ('chang', 'said', 'climat') 7
# ('withdraw', 'pari', 'agreement') 7
# ('pari', 'agreement', 'trump') 7
# ('climat', 'chang', 'two') 7
# ('trump', 'global', 'warm') 7
# ('climat', 'action', 'busi') 7
# ('climat', 'chang', 'mani') 7
# ('climat', 'chang', 'compani') 7
# ('million', 'climat', 'chang') 7
# ('warn', 'climat', 'chang') 7
# ('chang', 'nation', 'secur') 7
# ('presid', 'donald', 'pull') 7
# ('donald', 'pull', 'pari') 7
# ('climat', 'presid', 'donald') 7
# ('pari', 'agreement', 'us') 7
# ('commit', 'climat', 'chang') 7
# ('administr', 'climat', 'chang') 7
# ('emiss', 'power', 'plant') 7
# ('climat', 'extrem', 'weather') 7
# ('chang', 'extrem', 'weather') 7
# ('work', 'climat', 'chang') 7
# ('state', 'citi', 'busi') 7
# ('economi', 'associ', 'press') 7
# ('associ', 'press', 'donald') 7
# ('associ', 'presid', 'donald') 7
# ('press', 'presid', 'donald') 7
# ('press', 'presid', 'trump') 7
# ('major', 'climat', 'chang') 7
# ('climat', 'action', 'fiji') 7
# ('climat', 'action', 'un') 7
# ('climat', 'center', 'cop') 7
# ('climat', 'center', 'fiji') 7
# ('climat', 'center', 'un') 7
# ('climat', 'cop', 'fiji') 7
# ('climat', 'cop', 'un') 7
# ('climat', 'fiji', 'un') 7
# ('action', 'center', 'cop') 7
# ('action', 'center', 'fiji') 7
# ('action', 'center', 'un') 7
# ('action', 'center', 'climat') 7
# ('action', 'cop', 'fiji') 7
# ('action', 'cop', 'un') 7
# ('action', 'cop', 'climat') 7
# ('action', 'fiji', 'un') 7
# ('action', 'fiji', 'climat') 7
# ('action', 'un', 'climat') 7
# ('center', 'cop', 'fiji') 7
# ('center', 'cop', 'un') 7
# ('center', 'cop', 'climat') 7
# ('center', 'cop', 'chang') 7
# ('center', 'fiji', 'un') 7
# ('center', 'fiji', 'climat') 7
# ('center', 'fiji', 'chang') 7
# ('center', 'un', 'climat') 7
# ('center', 'un', 'chang') 7
# ('center', 'climat', 'chang') 7
# ('climat', 'action', 'citi') 7
# ('climat', 'state', 'citi') 7
# ('action', 'state', 'citi') 7
# ('climat', 'chang', 'contribut') 7
# ('pari', 'agreement', 'nation') 7
# ('climat', 'chang', 'veri') 7
# ('new', 'hampshir', 'chang') 7
# ('climat', 'chang', 'financi') 7
# ('commit', 'pari', 'agreement') 7
# ('investor', 'climat', 'chang') 7
# ('climat', 'chang', 'face') 7
# ('per', 'cent', 'cent') 7
# ('per', 'cent', 'climat') 7
# ('cent', 'climat', 'chang') 7
# ('climat', 'chang', 'studi') 7
# ('kenya', 'climat', 'chang') 7
# ('pari', 'rule', 'book') 7
# ('work', 'plan', 'forest') 7
# ('plan', 'forest', 'divis') 7
# ('forest', 'work', 'plan') 7
# ('reduc', 'carbon', 'emiss') 6
# ('climat', 'chang', 'great') 6
# ('climat', 'chang', 'potenti') 6
# ('serious', 'climat', 'chang') 6
# ('climat', 'chang', 'investor') 6
# ('donald', 'trump', 'accord') 6
# ('donald', 'pari', 'accord') 6
# ('trump', 'withdraw', 'pari') 6
# ('withdraw', 'pari', 'accord') 6
# ('climat', 'chang', 'measur') 6
# ('climat', 'chang', 'environment') 6
# ('renew', 'energi', 'energi') 6
# ('pari', 'agreement', 'countri') 6
# ('un', 'framework', 'convent') 6
# ('un', 'framework', 'chang') 6
# ('un', 'convent', 'chang') 6
# ('former', 'new', 'mayor') 6
# ('former', 'new', 'michael') 6
# ('former', 'york', 'mayor') 6
# ('former', 'york', 'michael') 6
# ('former', 'mayor', 'michael') 6
# ('new', 'york', 'michael') 6
# ('new', 'york', 'bloomberg') 6
# ('new', 'mayor', 'michael') 6
# ('new', 'mayor', 'bloomberg') 6
# ('new', 'michael', 'bloomberg') 6
# ('york', 'mayor', 'michael') 6
# ('york', 'mayor', 'bloomberg') 6
# ('york', 'michael', 'bloomberg') 6
# ('mayor', 'michael', 'bloomberg') 6
# ('climat', 'chang', 'might') 6
# ('climat', 'chang', 'gas') 6
# ('climat', 'chang', 'sever') 6
# ('role', 'climat', 'chang') 6
# ('gross', 'domest', 'product') 6
# ('climat', 'chang', 'grow') 6
# ('skeptic', 'climat', 'chang') 6
# ('global', 'warm', 'climat') 6
# ('must', 'climat', 'chang') 6
# ('lead', 'fight', 'climat') 6
# ('goal', 'climat', 'chang') 6
# ('climat', 'chang', 'announc') 6
# ('nation', 'determin', 'contribut') 6
# ('climat', 'chang', 'although') 6
# ('look', 'climat', 'chang') 6
# ('risk', 'global', 'warm') 6
# ('awar', 'climat', 'chang') 6
# ('human', 'climat', 'chang') 6
# ('alreadi', 'climat', 'chang') 6
# ('agricultur', 'climat', 'chang') 6
# ('climat', 'chang', 'come') 6
# ('climat', 'chang', 'food') 6
# ('climat', 'chang', 'negoti') 6
# ('said', 'unit', 'state') 6
# ('climat', 'chang', 'carbon') 6
# ('contribut', 'climat', 'chang') 6
# ('climat', 'chang', 'last') 6
# ('chang', 'last', 'year') 6
# ('author', 'china', 'daili') 6
# ('climat', 'chang', 'major') 6
# ('climat', 'chang', 'dure') 6
# ('posit', 'climat', 'chang') 6
# ('us', 'clean', 'energi') 6
# ('much', 'climat', 'chang') 6
# ('renew', 'energi', 'effici') 6
# ('financi', 'risk', 'climat') 6
# ('financi', 'risk', 'chang') 6
# ('come', 'climat', 'chang') 6
# ('mitig', 'adapt', 'climat') 6
# ('climat', 'chang', 'creat') 6
# ('keep', 'global', 'temperatur') 6
# ('climat', 'chang', 'despit') 6
# ('trump', 'pari', 'climat') 6
# ('climat', 'chang', 'clear') 6
# ('statement', 'climat', 'chang') 6
# ('intern', 'climat', 'chang') 6
# ('climat', 'chang', 'chief') 6
# ('face', 'climat', 'chang') 6
# ('put', 'climat', 'chang') 6
# ('pull', 'pari', 'climat') 6
# ('level', 'climat', 'chang') 6
# ('new', 'nation', 'secur') 6
# ('new', 'nation', 'strategi') 6
# ('new', 'secur', 'strategi') 6
# ('monday', 'climat', 'chang') 6
# ('obama', 'climat', 'chang') 6
# ('climat', 'secur', 'threat') 6
# ('climat', 'chang', 'hoax') 6
# ('creat', 'climat', 'chang') 6
# ('away', 'fossil', 'fuel') 6
# ('climat', 'chang', 'first') 6
# ('climat', 'chang', 'set') 6
# ('temperatur', 'rise', 'degre') 6
# ('bonn', 'germani', 'ap') 6
# ('bear', 'climat', 'chang') 6
# ('first', 'climat', 'chang') 6
# ('germani', 'saturday', 'america') 6
# ('saturday', 'america', 'pledg') 6
# ('america', 'pledg', 'work') 6
# ('america', 'pledg', 'compil') 6
# ('america', 'pledg', 'talli') 6
# ('america', 'campaign', 'work') 6
# ('america', 'campaign', 'compil') 6
# ('america', 'campaign', 'talli') 6
# ('america', 'work', 'compil') 6
# ('america', 'work', 'talli') 6
# ('america', 'compil', 'talli') 6
# ('pledg', 'campaign', 'work') 6
# ('pledg', 'campaign', 'compil') 6
# ('pledg', 'campaign', 'talli') 6
# ('pledg', 'campaign', 'climat') 6
# ('pledg', 'work', 'compil') 6
# ('pledg', 'work', 'talli') 6
# ('pledg', 'work', 'climat') 6
# ('pledg', 'compil', 'talli') 6
# ('pledg', 'compil', 'climat') 6
# ('pledg', 'talli', 'climat') 6
# ('campaign', 'work', 'compil') 6
# ('campaign', 'work', 'talli') 6
# ('campaign', 'work', 'climat') 6
# ('campaign', 'work', 'action') 6
# ('campaign', 'compil', 'talli') 6
# ('campaign', 'compil', 'climat') 6
# ('campaign', 'compil', 'action') 6
# ('campaign', 'talli', 'climat') 6
# ('campaign', 'talli', 'action') 6
# ('campaign', 'climat', 'action') 6
# ('work', 'compil', 'talli') 6
# ('work', 'compil', 'climat') 6
# ('work', 'compil', 'action') 6
# ('work', 'compil', 'state') 6
# ('work', 'talli', 'climat') 6
# ('work', 'talli', 'action') 6
# ('work', 'talli', 'state') 6
# ('work', 'climat', 'action') 6
# ('work', 'climat', 'state') 6
# ('work', 'action', 'state') 6
# ('compil', 'talli', 'climat') 6
# ('compil', 'talli', 'action') 6
# ('compil', 'talli', 'state') 6
# ('compil', 'talli', 'citi') 6
# ('compil', 'climat', 'action') 6
# ('compil', 'climat', 'state') 6
# ('compil', 'climat', 'citi') 6
# ('compil', 'action', 'state') 6
# ('compil', 'action', 'citi') 6
# ('compil', 'state', 'citi') 6
# ('talli', 'climat', 'action') 6
# ('talli', 'climat', 'state') 6
# ('talli', 'climat', 'citi') 6
# ('talli', 'climat', 'colleg') 6
# ('talli', 'action', 'state') 6
# ('talli', 'action', 'citi') 6
# ('talli', 'action', 'colleg') 6
# ('talli', 'state', 'citi') 6
# ('talli', 'state', 'colleg') 6
# ('talli', 'citi', 'colleg') 6
# ('climat', 'action', 'colleg') 6
# ('climat', 'state', 'colleg') 6
# ('climat', 'state', 'busi') 6
# ('climat', 'citi', 'colleg') 6
# ('climat', 'citi', 'busi') 6
# ('climat', 'colleg', 'busi') 6
# ('action', 'state', 'colleg') 6
# ('action', 'state', 'busi') 6
# ('action', 'state', 'local') 6
# ('action', 'citi', 'colleg') 6
# ('action', 'citi', 'busi') 6
# ('action', 'citi', 'local') 6
# ('action', 'colleg', 'busi') 6
# ('action', 'colleg', 'local') 6
# ('action', 'busi', 'local') 6
# ('state', 'citi', 'colleg') 6
# ('state', 'citi', 'local') 6
# ('state', 'citi', 'actor') 6
# ('state', 'colleg', 'busi') 6
# ('state', 'colleg', 'local') 6
# ('state', 'colleg', 'actor') 6
# ('state', 'busi', 'local') 6
# ('state', 'busi', 'actor') 6
# ('state', 'local', 'actor') 6
# ('citi', 'colleg', 'busi') 6
# ('citi', 'colleg', 'local') 6
# ('citi', 'colleg', 'actor') 6
# ('citi', 'colleg', 'across') 6
# ('citi', 'busi', 'local') 6
# ('citi', 'busi', 'actor') 6
# ('citi', 'busi', 'across') 6
# ('citi', 'local', 'actor') 6
# ('citi', 'local', 'across') 6
# ('citi', 'actor', 'across') 6
# ('colleg', 'busi', 'local') 6
# ('colleg', 'busi', 'actor') 6
# ('colleg', 'busi', 'across') 6
# ('colleg', 'busi', 'entir') 6
# ('colleg', 'local', 'actor') 6
# ('colleg', 'local', 'across') 6
# ('colleg', 'local', 'entir') 6
# ('colleg', 'actor', 'across') 6
# ('colleg', 'actor', 'entir') 6
# ('colleg', 'across', 'entir') 6
# ('busi', 'local', 'actor') 6
# ('busi', 'local', 'across') 6
# ('busi', 'local', 'entir') 6
# ('busi', 'local', 'economi') 6
# ('busi', 'actor', 'across') 6
# ('busi', 'actor', 'entir') 6
# ('busi', 'actor', 'economi') 6
# ('busi', 'across', 'entir') 6
# ('busi', 'across', 'economi') 6
# ('busi', 'entir', 'economi') 6
# ('local', 'actor', 'across') 6
# ('local', 'actor', 'entir') 6
# ('local', 'actor', 'economi') 6
# ('local', 'actor', 'ap') 6
# ('local', 'across', 'entir') 6
# ('local', 'across', 'economi') 6
# ('local', 'across', 'ap') 6
# ('local', 'entir', 'economi') 6
# ('local', 'entir', 'ap') 6
# ('local', 'economi', 'ap') 6
# ('actor', 'across', 'entir') 6
# ('actor', 'across', 'economi') 6
# ('actor', 'across', 'ap') 6
# ('actor', 'across', 'meissner') 6
# ('actor', 'entir', 'economi') 6
# ('actor', 'entir', 'ap') 6
# ('actor', 'entir', 'meissner') 6
# ('actor', 'economi', 'ap') 6
# ('actor', 'economi', 'meissner') 6
# ('actor', 'ap', 'meissner') 6
# ('across', 'entir', 'economi') 6
# ('across', 'entir', 'ap') 6
# ('across', 'entir', 'meissner') 6
# ('across', 'entir', 'associ') 6
# ('across', 'economi', 'ap') 6
# ('across', 'economi', 'meissner') 6
# ('across', 'economi', 'associ') 6
# ('across', 'ap', 'meissner') 6
# ('across', 'ap', 'associ') 6
# ('across', 'meissner', 'associ') 6
# ('entir', 'economi', 'ap') 6
# ('entir', 'economi', 'meissner') 6
# ('entir', 'economi', 'associ') 6
# ('entir', 'economi', 'press') 6
# ('entir', 'ap', 'meissner') 6
# ('entir', 'ap', 'associ') 6
# ('entir', 'ap', 'press') 6
# ('entir', 'meissner', 'associ') 6
# ('entir', 'meissner', 'press') 6
# ('entir', 'associ', 'press') 6
# ('economi', 'ap', 'meissner') 6
# ('economi', 'ap', 'associ') 6
# ('economi', 'ap', 'press') 6
# ('economi', 'meissner', 'associ') 6
# ('economi', 'meissner', 'press') 6
# ('ap', 'meissner', 'former') 6
# ('ap', 'associ', 'former') 6
# ('ap', 'press', 'former') 6
# ('meissner', 'associ', 'former') 6
# ('meissner', 'press', 'former') 6
# ('associ', 'press', 'former') 6
# ('presid', 'climat', 'action') 6
# ('mapl', 'syrup', 'produc') 6
# ('syrup', 'produc', 'climat') 6
# ('produc', 'new', 'hampshir') 6
# ('climat', 'chang', 'good') 6
# ('new', 'hampshir', 'climat') 6
# ('hampshir', 'climat', 'chang') 6
# ('climat', 'chang', 'institut') 6
# ('relat', 'climat', 'chang') 6
# ('compani', 'climat', 'chang') 6
# ('climat', 'chang', 'mitig') 6
# ('climat', 'chang', 'case') 6
# ('climat', 'chang', 'disclosur') 6
# ('chang', 'per', 'cent') 6
# ('per', 'climat', 'chang') 6
# ('nodal', 'climat', 'chang') 6
# ('chief', 'conserv', 'forest') 6
# ('conserv', 'forest', 'climat') 6
# ('climat', 'chang', 'especi') 5
# ('chief', 'execut', 'offic') 5
# ('climat', 'chang', 'may') 5
# ('univers', 'climat', 'chang') 5
# ('avoid', 'climat', 'chang') 5
# ('climat', 'chang', 'go') 5
# ('pari', 'climat', 'sign') 5
# ('pari', 'agreement', 'sign') 5
# ('one', 'planet', 'summit') 5
# ('us', 'withdraw', 'pari') 5
# ('climat', 'summit', 'pari') 5
# ('problem', 'climat', 'chang') 5
# ('would', 'global', 'warm') 5
# ('us', 'pari', 'accord') 5
# ('ani', 'climat', 'chang') 5
# ('california', 'governor', 'brown') 5
# ('california', 'jerri', 'brown') 5
# ('governor', 'jerri', 'brown') 5
# ('bank', 'england', 'governor') 5
# ('climat', 'chang', 'debat') 5
# ('climat', 'chang', 'futur') 5
# ('climat', 'chang', 'greenhous') 5
# ('drought', 'contribut', 'conflict') 5
# ('climat', 'chang', 'drought') 5
# ('climat', 'chang', 'continu') 5
# ('climat', 'chang', 'make') 5
# ('climat', 'chang', 'look') 5
# ('politician', 'climat', 'chang') 5
# ('former', 'us', 'al') 5
# ('last', 'year', 'climat') 5
# ('last', 'climat', 'chang') 5
# ('climat', 'chang', 'list') 5
# ('global', 'warm', 'chang') 5
# ('warm', 'climat', 'chang') 5
# ('climat', 'chang', 'level') 5
# ('consequ', 'climat', 'chang') 5
# ('climat', 'chang', 'far') 5
# ('lead', 'fight', 'chang') 5
# ('climat', 'chang', 'concern') 5
# ('bonn', 'germani', 'meet') 5
# ('energi', 'wind', 'solar') 5
# ('climat', 'chang', 'still') 5
# ('climat', 'chang', 'cost') 5
# ('limit', 'temperatur', 'rise') 5
# ('energi', 'energi', 'effici') 5
# ('climat', 'chang', 'must') 5
# ('around', 'climat', 'chang') 5
# ('global', 'rise', 'c') 5
# ('climat', 'chang', 'signific') 5
# ('effect', 'climat', 'climat') 5
# ('effect', 'chang', 'climat') 5
# ('negat', 'climat', 'chang') 5
# ('strategi', 'climat', 'chang') 5
# ('climat', 'chang', 'like') 5
# ('climat', 'chang', 'counti') 5
# ('climat', 'chang', 'even') 5
# ('climat', 'chang', 'well') 5
# ('pari', 'chang', 'agreement') 5
# ('chief', 'climat', 'chang') 5
# ('world', 'econom', 'forum') 5
# ('china', 'play', 'role') 5
# ('unit', 'state', 'chang') 5
# ('whether', 'climat', 'chang') 5
# ('climat', 'chang', 'econom') 5
# ('climat', 'chang', 'materi') 5
# ('discuss', 'climat', 'chang') 5
# ('global', 'warm', 'research') 5
# ('result', 'climat', 'chang') 5
# ('climat', 'chang', 'scientist') 5
# ('human', 'activ', 'chang') 5
# ('curb', 'climat', 'chang') 5
# ('research', 'global', 'warm') 5
# ('trump', 'pull', 'agreement') 5
# ('sign', 'execut', 'order') 5
# ('clean', 'power', 'plan') 5
# ('greenhous', 'power', 'plant') 5
# ('climat', 'chang', 'instead') 5
# ('climat', 'chang', 'activ') 5
# ('climat', 'chang', 'meet') 5
# ('climat', 'nation', 'secur') 5
# ('trump', 'execut', 'order') 5
# ('market', 'clean', 'energi') 5
# ('chang', 'climat', 'confer') 5
# ('sinc', 'climat', 'chang') 5
# ('clean', 'energi', 'technolog') 5
# ('countri', 'pari', 'agreement') 5
# ('pari', 'agreement', 'global') 5
# ('associ', 'climat', 'chang') 5
# ('presid', 'pari', 'agreement') 5
# ('mitig', 'adapt', 'chang') 5
# ('chang', 'unit', 'state') 5
# ('one', 'climat', 'chang') 5
# ('import', 'climat', 'chang') 5
# ('support', 'climat', 'chang') 5
# ('shift', 'toward', 'energi') 5
# ('dure', 'climat', 'confer') 5
# ('climat', 'chang', 'intern') 5
# ('industri', 'climat', 'chang') 5
# ('us', 'pari', 'climat') 5
# ('accord', 'climat', 'chang') 5
# ('offici', 'climat', 'chang') 5
# ('rise', 'degre', 'celsius') 5
# ('temperatur', 'degre', 'celsius') 5
# ('describ', 'climat', 'chang') 5
# ('nation', 'secur', 'threat') 5
# ('nation', 'secur', 'trump') 5
# ('presid', 'donald', 'nation') 5
# ('presid', 'trump', 'nation') 5
# ('donald', 'trump', 'nation') 5
# ('donald', 'trump', 'secur') 5
# ('donald', 'nation', 'secur') 5
# ('trump', 'nation', 'strategi') 5
# ('trump', 'secur', 'strategi') 5
# ('gas', 'power', 'plant') 5
# ('emiss', 'climat', 'chang') 5
# ('link', 'climat', 'chang') 5
# ('climat', 'chang', 'support') 5
# ('propos', 'climat', 'chang') 5
# ('around', 'world', 'climat') 5
# ('climat', 'chang', 'show') 5
# ('studi', 'impact', 'climat') 5
# ('weather', 'event', 'chang') 5
# ('climat', 'chang', 'cop') 5
# ('chang', 'confer', 'cop') 5
# ('ap', 'associ', 'presid') 5
# ('ap', 'press', 'presid') 5
# ('file', 'file', 'photo') 5
# ('donald', 'pull', 'accord') 5
# ('trump', 'pull', 'accord') 5
# ('bonn', 'germani', 'bloomberg') 5
# ('bonn', 'saturday', 'bloomberg') 5
# ('germani', 'saturday', 'bloomberg') 5
# ('germani', 'bloomberg', 'america') 5
# ('saturday', 'bloomberg', 'america') 5
# ('saturday', 'bloomberg', 'pledg') 5
# ('bloomberg', 'america', 'pledg') 5
# ('bloomberg', 'america', 'campaign') 5
# ('bloomberg', 'america', 'work') 5
# ('bloomberg', 'america', 'compil') 5
# ('bloomberg', 'pledg', 'campaign') 5
# ('bloomberg', 'pledg', 'work') 5
# ('bloomberg', 'pledg', 'compil') 5
# ('bloomberg', 'campaign', 'work') 5
# ('bloomberg', 'campaign', 'compil') 5
# ('bloomberg', 'work', 'compil') 5
# ('chang', 'confer', 'ap') 5
# ('chang', 'bonn', 'ap') 5
# ('chang', 'germani', 'ap') 5
# ('chang', 'saturday', 'ap') 5
# ('confer', 'bonn', 'ap') 5
# ('confer', 'bonn', 'meissner') 5
# ('confer', 'germani', 'ap') 5
# ('confer', 'germani', 'meissner') 5
# ('confer', 'saturday', 'ap') 5
# ('confer', 'saturday', 'meissner') 5
# ('confer', 'ap', 'meissner') 5
# ('bonn', 'germani', 'meissner') 5
# ('bonn', 'germani', 'associ') 5
# ('bonn', 'saturday', 'ap') 5
# ('bonn', 'saturday', 'meissner') 5
# ('bonn', 'saturday', 'associ') 5
# ('bonn', 'ap', 'meissner') 5
# ('bonn', 'ap', 'associ') 5
# ('bonn', 'meissner', 'associ') 5
# ('germani', 'saturday', 'meissner') 5
# ('germani', 'saturday', 'press') 5
# ('germani', 'ap', 'meissner') 5
# ('germani', 'ap', 'press') 5
# ('germani', 'meissner', 'associ') 5
# ('germani', 'meissner', 'press') 5
# ('germani', 'associ', 'press') 5
# ('saturday', 'ap', 'meissner') 5
# ('saturday', 'meissner', 'associ') 5
# ('saturday', 'meissner', 'press') 5
# ('associ', 'press', 'new') 5
# ('billionair', 'michael', 'bloomberg') 5
# ('climat', 'scientist', 'said') 5
# ('realiti', 'climat', 'chang') 5
# ('want', 'climat', 'chang') 5
# ('attorney', 'general', 'investig') 5
# ('scientif', 'climat', 'chang') 5
# ('regul', 'greenhous', 'gas') 5
# ('regul', 'greenhous', 'emiss') 5
# ('regul', 'gas', 'emiss') 5
# ('climat', 'chang', 'becom') 5
# ('tuesday', 'brooklin', 'maggi') 5
# ('tuesday', 'brooklin', 'hassan') 5
# ('tuesday', 'brooklin', 'led') 5
# ('tuesday', 'brooklin', 'discuss') 5
# ('tuesday', 'maggi', 'hassan') 5
# ('tuesday', 'maggi', 'led') 5
# ('tuesday', 'maggi', 'discuss') 5
# ('tuesday', 'hassan', 'led') 5
# ('tuesday', 'hassan', 'discuss') 5
# ('tuesday', 'led', 'discuss') 5
# ('brooklin', 'maggi', 'hassan') 5
# ('brooklin', 'maggi', 'led') 5
# ('brooklin', 'maggi', 'discuss') 5
# ('brooklin', 'maggi', 'mapl') 5
# ('brooklin', 'hassan', 'led') 5
# ('brooklin', 'hassan', 'discuss') 5
# ('brooklin', 'hassan', 'mapl') 5
# ('brooklin', 'led', 'discuss') 5
# ('brooklin', 'led', 'mapl') 5
# ('brooklin', 'discuss', 'mapl') 5
# ('maggi', 'hassan', 'led') 5
# ('maggi', 'hassan', 'discuss') 5
# ('maggi', 'hassan', 'mapl') 5
# ('maggi', 'hassan', 'syrup') 5
# ('maggi', 'led', 'discuss') 5
# ('maggi', 'led', 'mapl') 5
# ('maggi', 'led', 'syrup') 5
# ('maggi', 'discuss', 'mapl') 5
# ('maggi', 'discuss', 'syrup') 5
# ('maggi', 'mapl', 'syrup') 5
# ('hassan', 'led', 'discuss') 5
# ('hassan', 'led', 'mapl') 5
# ('hassan', 'led', 'syrup') 5
# ('hassan', 'led', 'produc') 5
# ('hassan', 'discuss', 'mapl') 5
# ('hassan', 'discuss', 'syrup') 5
# ('hassan', 'discuss', 'produc') 5
# ('hassan', 'mapl', 'syrup') 5
# ('hassan', 'mapl', 'produc') 5
# ('hassan', 'syrup', 'produc') 5
# ('led', 'discuss', 'mapl') 5
# ('led', 'discuss', 'syrup') 5
# ('led', 'discuss', 'produc') 5
# ('led', 'discuss', 'new') 5
# ('led', 'mapl', 'syrup') 5
# ('led', 'mapl', 'produc') 5
# ('led', 'mapl', 'new') 5
# ('led', 'syrup', 'produc') 5
# ('led', 'syrup', 'new') 5
# ('led', 'produc', 'new') 5
# ('discuss', 'mapl', 'syrup') 5
# ('discuss', 'mapl', 'produc') 5
# ('discuss', 'mapl', 'new') 5
# ('discuss', 'mapl', 'hampshir') 5
# ('discuss', 'syrup', 'produc') 5
# ('discuss', 'syrup', 'new') 5
# ('discuss', 'syrup', 'hampshir') 5
# ('discuss', 'produc', 'new') 5
# ('discuss', 'produc', 'hampshir') 5
# ('discuss', 'new', 'hampshir') 5
# ('mapl', 'syrup', 'new') 5
# ('mapl', 'syrup', 'hampshir') 5
# ('mapl', 'syrup', 'climat') 5
# ('mapl', 'produc', 'new') 5
# ('mapl', 'produc', 'hampshir') 5
# ('mapl', 'produc', 'climat') 5
# ('mapl', 'new', 'hampshir') 5
# ('mapl', 'new', 'climat') 5
# ('mapl', 'hampshir', 'climat') 5
# ('syrup', 'produc', 'new') 5
# ('syrup', 'produc', 'hampshir') 5
# ('syrup', 'produc', 'chang') 5
# ('syrup', 'new', 'hampshir') 5
# ('syrup', 'new', 'climat') 5
# ('syrup', 'new', 'chang') 5
# ('syrup', 'hampshir', 'climat') 5
# ('syrup', 'hampshir', 'chang') 5
# ('syrup', 'climat', 'chang') 5
# ('produc', 'new', 'climat') 5
# ('produc', 'new', 'chang') 5
# ('produc', 'new', 'impact') 5
# ('produc', 'hampshir', 'climat') 5
# ('produc', 'hampshir', 'chang') 5
# ('produc', 'hampshir', 'impact') 5
# ('produc', 'climat', 'impact') 5
# ('produc', 'chang', 'impact') 5
# ('new', 'hampshir', 'impact') 5
# ('new', 'hampshir', 'industri') 5
# ('new', 'climat', 'impact') 5
# ('new', 'climat', 'industri') 5
# ('new', 'chang', 'impact') 5
# ('new', 'chang', 'industri') 5
# ('new', 'impact', 'industri') 5
# ('hampshir', 'climat', 'impact') 5
# ('hampshir', 'climat', 'industri') 5
# ('hampshir', 'climat', 'ap') 5
# ('hampshir', 'chang', 'impact') 5
# ('hampshir', 'chang', 'industri') 5
# ('hampshir', 'chang', 'ap') 5
# ('hampshir', 'impact', 'industri') 5
# ('hampshir', 'impact', 'ap') 5
# ('hampshir', 'industri', 'ap') 5
# ('climat', 'chang', 'ap') 5
# ('climat', 'chang', 'amendola') 5
# ('climat', 'impact', 'industri') 5
# ('climat', 'impact', 'ap') 5
# ('climat', 'impact', 'amendola') 5
# ('climat', 'industri', 'ap') 5
# ('climat', 'industri', 'amendola') 5
# ('climat', 'ap', 'amendola') 5
# ('chang', 'impact', 'industri') 5
# ('chang', 'impact', 'ap') 5
# ('chang', 'impact', 'amendola') 5
# ('chang', 'impact', 'associ') 5
# ('chang', 'industri', 'ap') 5
# ('chang', 'industri', 'amendola') 5
# ('chang', 'industri', 'associ') 5
# ('chang', 'ap', 'amendola') 5
# ('chang', 'ap', 'associ') 5
# ('chang', 'amendola', 'associ') 5
# ('impact', 'industri', 'ap') 5
# ('impact', 'industri', 'amendola') 5
# ('impact', 'industri', 'associ') 5
# ('impact', 'industri', 'press') 5
# ('impact', 'ap', 'amendola') 5
# ('impact', 'ap', 'associ') 5
# ('impact', 'ap', 'press') 5
# ('impact', 'amendola', 'associ') 5
# ('impact', 'amendola', 'press') 5
# ('impact', 'associ', 'press') 5
# ('industri', 'ap', 'amendola') 5
# ('industri', 'ap', 'associ') 5
# ('industri', 'ap', 'press') 5
# ('industri', 'amendola', 'associ') 5
# ('industri', 'amendola', 'press') 5
# ('industri', 'associ', 'press') 5
# ('ap', 'amendola', 'associ') 5
# ('ap', 'amendola', 'press') 5
# ('amendola', 'associ', 'press') 5
# ('carbon', 'dioxid', 'warm') 5
# ('carbon', 'global', 'warm') 5
# ('climat', 'chang', 'call') 5
# ('announc', 'pari', 'climat') 5
# ('climat', 'chang', 'factor') 5
# ('said', 'chang', 'would') 5
# ('director', 'climat', 'chang') 5
# ('climat', 'chang', 'minist') 5
# ('extrem', 'weather', 'climat') 5
# ('willow', 'warbler', 'site') 5
# ('climat', 'chang', 'warm') 5
# ('climat', 'chang', 'compromis') 5
# ('action', 'must', 'scale') 5
# ('action', 'urgent', 'scale') 5
# ('mr', 'trump', 'plan') 5
# ('pull', 'climat', 'accord') 5
# ('climat', 'chang', 'offici') 5
# ('seek', 'climat', 'chang') 5
# ('climat', 'chang', 'initi') 5
# ('natur', 'climat', 'chang') 5
# ('project', 'climat', 'chang') 5
# ('respond', 'climat', 'chang') 5
# ('climat', 'action', 'plan') 5
# ('climat', 'chang', 'exist') 5
# ('defenc', 'climat', 'chang') 5
# ('australian', 'climat', 'chang') 5
# ('climat', 'chang', 'cent') 5
# ('climat', 'per', 'cent') 5
# ('global', 'warm', 'degre') 5
# ('becaus', 'climat', 'chang') 5
# ('chang', 'weather', 'pattern') 5
# ('climat', 'chang', 'scenario') 5
# ('per', 'cent', 'increas') 5
# ('organis', 'climat', 'chang') 5
# ('poverti', 'climat', 'chang') 5
# ('chang', 'action', 'plan') 5
# ('money', 'grow', 'tree') 5
# ('wit', 'climat', 'chang') 5
# ('nodal', 'offic', 'climat') 5
# ('nodal', 'offic', 'chang') 5
# ('offic', 'climat', 'chang') 5
# ('work', 'plan', 'divis') 5
# ('work', 'forest', 'divis') 5
# ('environ', 'climat', 'depart') 5
# ('environ', 'chang', 'depart') 5
# ('prepar', 'action', 'plan') 5
# ('environ', 'wing', 'state') 5
# ('environ', 'wing', 'depart') 5
# ('environ', 'state', 'depart') 5
# ('wing', 'state', 'depart') 5
# ('climat', 'chang', 'open') 4
# ('account', 'climat', 'chang') 4
# ('climat', 'chang', 'citi') 4
# ('get', 'climat', 'chang') 4
# ('climat', 'chang', 'urgent') 4
# ('fossil', 'fuel', 'subsidi') 4
# ('climat', 'chang', 'summit') 4
# ('chang', 'summit', 'pari') 4
# ('climat', 'chang', 'ipcc') 4
# ('carbon', 'dioxid', 'emiss') 4
# ('energi', 'fossil', 'fuel') 4
# ('review', 'climat', 'chang') 4
# ('energi', 'renew', 'energi') 4
# ('california', 'governor', 'jerri') 4
# ('task', 'forc', 'tcfd') 4
# ('task', 'financi', 'tcfd') 4
# ('task', 'disclosur', 'tcfd') 4
# ('forc', 'financi', 'tcfd') 4
# ('forc', 'disclosur', 'tcfd') 4
# ('forc', 'tcfd', 'initi') 4
# ('financi', 'disclosur', 'tcfd') 4
# ('financi', 'tcfd', 'initi') 4
# ('disclosur', 'tcfd', 'initi') 4
# ('disclosur', 'tcfd', 'bank') 4
# ('tcfd', 'initi', 'bank') 4
# ('tcfd', 'initi', 'england') 4
# ('tcfd', 'bank', 'england') 4
# ('bank', 'england', 'mark') 4
# ('bank', 'england', 'carney') 4
# ('bank', 'governor', 'mark') 4
# ('bank', 'governor', 'carney') 4
# ('bank', 'mark', 'carney') 4
# ('england', 'governor', 'mark') 4
# ('england', 'governor', 'carney') 4
# ('england', 'mark', 'carney') 4
# ('governor', 'mark', 'carney') 4
# ('contribut', 'conflict', 'drought') 4
# ('drought', 'increas', 'risk') 4
# ('climat', 'due', 'emiss') 4
# ('chang', 'due', 'emiss') 4
# ('drought', 'climat', 'chang') 4
# ('evid', 'climat', 'chang') 4
# ('climat', 'chang', 'degre') 4
# ('climat', 'chang', 'play') 4
# ('author', 'climat', 'chang') 4
# ('far', 'climat', 'chang') 4
# ('understand', 'climat', 'chang') 4
# ('leader', 'climat', 'chang') 4
# ('former', 'us', 'gore') 4
# ('former', 'al', 'gore') 4
# ('us', 'al', 'gore') 4
# ('donald', 'trump', 'us') 4
# ('human', 'human', 'human') 4
# ('human', 'interest', 'human') 4
# ('reduc', 'carbon', 'footprint') 4
# ('onli', 'climat', 'chang') 4
# ('meet', 'bonn', 'germani') 4
# ('climat', 'chang', 'manag') 4
# ('sea', 'surfac', 'temperatur') 4
# ('sinc', 'record', 'began') 4
# ('global', 'climat', 'said') 4
# ('burn', 'oil', 'gas') 4
# ('greenhous', 'gase', 'atmospher') 4
# ('depend', 'fossil', 'fuel') 4
# ('renew', 'energi', 'solar') 4
# ('climat', 'chang', 'everi') 4
# ('climat', 'chang', 'share') 4
# ('fossil', 'fuel', 'industri') 4
# ('climat', 'chang', 'live') 4
# ('rich', 'richest', 'countri') 4
# ('chang', 'reduc', 'emiss') 4
# ('intern', 'energi', 'agenc') 4
# ('despit', 'global', 'warm') 4
# ('move', 'fossil', 'fuel') 4
# ('renew', 'energi', 'use') 4
# ('increas', 'energi', 'effici') 4
# ('good', 'climat', 'chang') 4
# ('use', 'climat', 'chang') 4
# ('climat', 'chang', 'build') 4
# ('right', 'climat', 'chang') 4
# ('alreadi', 'effect', 'climat') 4
# ('alreadi', 'effect', 'chang') 4
# ('temperatur', 'climat', 'chang') 4
# ('chang', 'rise', 'sea') 4
# ('frequent', 'extrem', 'event') 4
# ('climat', 'chang', 'strategi') 4
# ('climat', 'chang', 'rice') 4
# ('climat', 'chang', 'southern') 4
# ('affect', 'climat', 'chang') 4
# ('climat', 'chang', 'posit') 4
# ('agricultur', 'technolog', 'agricultur') 4
# ('technolog', 'agricultur', 'technolog') 4
# ('climat', 'chang', 'toward') 4
# ('climat', 'unit', 'nation') 4
# ('chang', 'unit', 'nation') 4
# ('china', 'carbon', 'trade') 4
# ('forum', 'climat', 'chang') 4
# ('continu', 'climat', 'chang') 4
# ('climat', 'chang', 'group') 4
# ('friday', 'climat', 'chang') 4
# ('climat', 'chang', 'withdraw') 4
# ('climat', 'chang', 'note') 4
# ('warm', 'human', 'activ') 4
# ('unit', 'state', 'accord') 4
# ('meet', 'climat', 'chang') 4
# ('pari', 'agreement', 'said') 4
# ('fight', 'global', 'warm') 4
# ('climat', 'chang', 'sea') 4
# ('global', 'warm', 'us') 4
# ('global', 'warm', 'presid') 4
# ('said', 'global', 'warm') 4
# ('express', 'climat', 'chang') 4
# ('take', 'action', 'climat') 4
# ('climat', 'chang', 'denier') 4
# ('presid', 'trump', 'climat') 4
# ('alleg', 'climat', 'chang') 4
# ('deni', 'climat', 'chang') 4
# ('agreement', 'donald', 'trump') 4
# ('announc', 'withdraw', 'pari') 4
# ('pari', 'accord', 'administr') 4
# ('sign', 'execut', 'rescind') 4
# ('sign', 'order', 'rescind') 4
# ('execut', 'order', 'rescind') 4
# ('climat', 'chang', 'use') 4
# ('climat', 'chang', 'administr') 4
# ('chang', 'human', 'activ') 4
# ('human', 'activ', 'climat') 4
# ('trump', 'announc', 'withdraw') 4
# ('climat', 'chang', 'top') 4
# ('climat', 'chang', 'among') 4
# ('global', 'fight', 'climat') 4
# ('global', 'fight', 'chang') 4
# ('clean', 'energi', 'carbon') 4
# ('govern', 'pari', 'agreement') 4
# ('climat', 'chang', 'achiev') 4
# ('energi', 'effici', 'technolog') 4
# ('emiss', 'reduct', 'target') 4
# ('climat', 'chang', 'implement') 4
# ('clean', 'energi', 'energi') 4
# ('energi', 'solar', 'power') 4
# ('confer', 'presid', 'donald') 4
# ('us', 'presid', 'pull') 4
# ('us', 'donald', 'pull') 4
# ('us', 'trump', 'pull') 4
# ('presid', 'trump', 'agreement') 4
# ('end', 'fossil', 'fuel') 4
# ('german', 'chancellor', 'angela') 4
# ('german', 'chancellor', 'merkel') 4
# ('german', 'angela', 'merkel') 4
# ('chancellor', 'angela', 'merkel') 4
# ('economi', 'climat', 'chang') 4
# ('climat', 'chang', 'agre') 4
# ('climat', 'chang', 'yet') 4
# ('keep', 'global', 'rise') 4
# ('global', 'temperatur', 'c') 4
# ('temperatur', 'rise', 'c') 4
# ('call', 'climat', 'chang') 4
# ('bonn', 'germani', 'monday') 4
# ('withdraw', 'pari', 'climat') 4
# ('shift', 'cleaner', 'energi') 4
# ('us', 'global', 'warm') 4
# ('negoti', 'climat', 'chang') 4
# ('climat', 'chang', 'sign') 4
# ('climat', 'chang', 'relat') 4
# ('pari', 'agreement', 'near') 4
# ('climat', 'us', 'trump') 4
# ('unit', 'state', 'agreement') 4
# ('unit', 'pari', 'climat') 4
# ('unit', 'pari', 'agreement') 4
# ('state', 'pari', 'climat') 4
# ('state', 'pari', 'agreement') 4
# ('climat', 'agreement', 'nation') 4
# ('view', 'climat', 'chang') 4
# ('convent', 'climat', 'climat') 4
# ('convent', 'chang', 'climat') 4
# ('unit', 'state', 'china') 4
# ('climat', 'chang', 'put') 4
# ('catastroph', 'climat', 'chang') 4
# ('presid', 'donald', 'expect') 4
# ('presid', 'trump', 'expect') 4
# ('donald', 'trump', 'expect') 4
# ('pull', 'us', 'climat') 4
# ('environment', 'climat', 'chang') 4
# ('climat', 'chang', 'effort') 4
# ('global', 'temperatur', 'degre') 4
# ('fossil', 'fuel', 'climat') 4
# ('two', 'climat', 'chang') 4
# ('pari', 'agreement', 'polici') 4
# ('washington', 'nation', 'secur') 4
# ('chang', 'nation', 'threat') 4
# ('nation', 'secur', 'presid') 4
# ('presid', 'donald', 'secur') 4
# ('presid', 'trump', 'secur') 4
# ('presid', 'nation', 'secur') 4
# ('roll', 'back', 'administr') 4
# ('chang', 'trump', 'said') 4
# ('trump', 'said', 'pari') 4
# ('said', 'pari', 'agreement') 4
# ('general', 'climat', 'chang') 4
# ('campaign', 'climat', 'chang') 4
# ('activ', 'climat', 'chang') 4
# ('oil', 'gas', 'coal') 4
# ('factor', 'climat', 'chang') 4
# ('protect', 'climat', 'chang') 4
# ('climat', 'chang', 'frequent') 4
# ('state', 'attorney', 'general') 4
# ('greenhous', 'gas', 'power') 4
# ('greenhous', 'gas', 'plant') 4
# ('greenhous', 'emiss', 'power') 4
# ('greenhous', 'emiss', 'plant') 4
# ('gas', 'emiss', 'power') 4
# ('gas', 'emiss', 'plant') 4
# ('exacerb', 'climat', 'chang') 4
# ('climat', 'chang', 'everyon') 4
# ('climat', 'chang', 'big') 4
# ('properti', 'valu', 'go') 4
# ('valu', 'go', 'flood') 4
# ('around', 'world', 'chang') 4
# ('presid', 'trump', 'execut') 4
# ('climat', 'caus', 'human') 4
# ('chang', 'caus', 'human') 4
# ('climat', 'chang', 'found') 4
# ('studi', 'impact', 'chang') 4
# ('potenti', 'climat', 'chang') 4
# ('current', 'climat', 'chang') 4
# ('air', 'climat', 'chang') 4
# ('chang', 'extrem', 'event') 4
# ('extrem', 'weather', 'chang') 4
# ('event', 'climat', 'chang') 4
# ('climat', 'chang', 'water') 4
# ('curb', 'presid', 'donald') 4
# ('promot', 'renew', 'energi') 4
# ('climat', 'chang', 'next') 4
# ('demonstr', 'costum', 'presid') 4
# ('demonstr', 'costum', 'donald') 4
# ('demonstr', 'costum', 'trump') 4
# ('demonstr', 'costum', 'polar') 4
# ('demonstr', 'presid', 'donald') 4
# ('demonstr', 'presid', 'trump') 4
# ('demonstr', 'presid', 'polar') 4
# ('demonstr', 'donald', 'trump') 4
# ('demonstr', 'donald', 'polar') 4
# ('demonstr', 'trump', 'polar') 4
# ('costum', 'presid', 'donald') 4
# ('costum', 'presid', 'trump') 4
# ('costum', 'presid', 'polar') 4
# ('costum', 'presid', 'bear') 4
# ('costum', 'donald', 'trump') 4
# ('costum', 'donald', 'polar') 4
# ('costum', 'donald', 'bear') 4
# ('costum', 'trump', 'polar') 4
# ('costum', 'trump', 'bear') 4
# ('costum', 'polar', 'bear') 4
# ('presid', 'donald', 'polar') 4
# ('presid', 'donald', 'bear') 4
# ('presid', 'donald', 'protest') 4
# ('presid', 'trump', 'polar') 4
# ('presid', 'trump', 'bear') 4
# ('presid', 'trump', 'protest') 4
# ('presid', 'polar', 'bear') 4
# ('presid', 'polar', 'protest') 4
# ('presid', 'bear', 'protest') 4
# ('donald', 'trump', 'polar') 4
# ('donald', 'trump', 'bear') 4
# ('donald', 'trump', 'protest') 4
# ('donald', 'polar', 'bear') 4
# ('donald', 'polar', 'protest') 4
# ('donald', 'polar', 'climat') 4
# ('donald', 'bear', 'protest') 4
# ('donald', 'bear', 'climat') 4
# ('donald', 'protest', 'climat') 4
# ('trump', 'polar', 'bear') 4
# ('trump', 'polar', 'protest') 4
# ('trump', 'polar', 'climat') 4
# ('trump', 'polar', 'chang') 4
# ('trump', 'bear', 'protest') 4
# ('trump', 'bear', 'climat') 4
# ('trump', 'bear', 'chang') 4
# ('trump', 'protest', 'climat') 4
# ('trump', 'protest', 'chang') 4
# ('polar', 'bear', 'protest') 4
# ('polar', 'bear', 'climat') 4
# ('polar', 'bear', 'chang') 4
# ('polar', 'bear', 'dure') 4
# ('polar', 'protest', 'climat') 4
# ('polar', 'protest', 'chang') 4
# ('polar', 'protest', 'dure') 4
# ('polar', 'climat', 'chang') 4
# ('polar', 'climat', 'dure') 4
# ('polar', 'chang', 'dure') 4
# ('bear', 'protest', 'chang') 4
# ('bear', 'protest', 'dure') 4
# ('bear', 'climat', 'dure') 4
# ('bear', 'climat', 'climat') 4
# ('bear', 'chang', 'dure') 4
# ('bear', 'chang', 'climat') 4
# ('bear', 'dure', 'climat') 4
# ('protest', 'climat', 'chang') 4
# ('protest', 'climat', 'dure') 4
# ('protest', 'climat', 'climat') 4
# ('protest', 'chang', 'dure') 4
# ('protest', 'chang', 'climat') 4
# ('protest', 'chang', 'confer') 4
# ('protest', 'dure', 'climat') 4
# ('protest', 'dure', 'confer') 4
# ('climat', 'dure', 'climat') 4
# ('climat', 'dure', 'confer') 4
# ('climat', 'dure', 'cop') 4
# ('climat', 'climat', 'confer') 4
# ('climat', 'climat', 'cop') 4
# ('chang', 'dure', 'climat') 4
# ('chang', 'dure', 'confer') 4
# ('chang', 'dure', 'cop') 4
# ('chang', 'dure', 'bonn') 4
# ('chang', 'climat', 'cop') 4
# ('chang', 'climat', 'bonn') 4
# ('chang', 'cop', 'bonn') 4
# ('dure', 'climat', 'cop') 4
# ('dure', 'climat', 'bonn') 4
# ('dure', 'climat', 'western') 4
# ('dure', 'confer', 'cop') 4
# ('dure', 'confer', 'bonn') 4
# ('dure', 'confer', 'western') 4
# ('dure', 'cop', 'bonn') 4
# ('dure', 'cop', 'western') 4
# ('dure', 'bonn', 'western') 4
# ('climat', 'confer', 'western') 4
# ('climat', 'cop', 'bonn') 4
# ('climat', 'cop', 'western') 4
# ('climat', 'cop', 'germani') 4
# ('climat', 'bonn', 'western') 4
# ('climat', 'western', 'germani') 4
# ('confer', 'cop', 'bonn') 4
# ('confer', 'cop', 'western') 4
# ('confer', 'cop', 'germani') 4
# ('confer', 'cop', 'saturday') 4
# ('confer', 'bonn', 'western') 4
# ('confer', 'western', 'germani') 4
# ('confer', 'western', 'saturday') 4
# ('cop', 'bonn', 'western') 4
# ('cop', 'bonn', 'germani') 4
# ('cop', 'bonn', 'saturday') 4
# ('cop', 'bonn', 'bernd') 4
# ('cop', 'western', 'germani') 4
# ('cop', 'western', 'saturday') 4
# ('cop', 'western', 'bernd') 4
# ('cop', 'germani', 'saturday') 4
# ('cop', 'germani', 'bernd') 4
# ('cop', 'saturday', 'bernd') 4
# ('bonn', 'western', 'germani') 4
# ('bonn', 'western', 'saturday') 4
# ('bonn', 'western', 'bernd') 4
# ('bonn', 'western', 'via') 4
# ('bonn', 'germani', 'bernd') 4
# ('bonn', 'germani', 'via') 4
# ('bonn', 'saturday', 'bernd') 4
# ('bonn', 'saturday', 'via') 4
# ('bonn', 'bernd', 'via') 4
# ('western', 'germani', 'saturday') 4
# ('western', 'germani', 'bernd') 4
# ('western', 'germani', 'via') 4
# ('western', 'germani', 'ap') 4
# ('western', 'saturday', 'bernd') 4
# ('western', 'saturday', 'via') 4
# ('western', 'saturday', 'ap') 4
# ('western', 'bernd', 'via') 4
# ('western', 'bernd', 'ap') 4
# ('western', 'via', 'ap') 4
# ('germani', 'saturday', 'bernd') 4
# ('germani', 'saturday', 'via') 4
# ('germani', 'bernd', 'via') 4
# ('germani', 'bernd', 'ap') 4
# ('germani', 'bernd', 'associ') 4
# ('germani', 'via', 'ap') 4
# ('germani', 'via', 'associ') 4
# ('saturday', 'bernd', 'via') 4
# ('saturday', 'bernd', 'ap') 4
# ('saturday', 'bernd', 'associ') 4
# ('saturday', 'bernd', 'press') 4
# ('saturday', 'via', 'ap') 4
# ('saturday', 'via', 'associ') 4
# ('saturday', 'via', 'press') 4
# ('bernd', 'via', 'ap') 4
# ('bernd', 'via', 'associ') 4
# ('bernd', 'via', 'press') 4
# ('bernd', 'ap', 'associ') 4
# ('bernd', 'ap', 'press') 4
# ('bernd', 'associ', 'press') 4
# ('via', 'ap', 'associ') 4
# ('via', 'ap', 'press') 4
# ('via', 'associ', 'press') 4
# ('associ', 'press', 'file') 4
# ('associ', 'file', 'photo') 4
# ('press', 'file', 'photo') 4
# ('steam', 'power', 'plant') 4
# ('climat', 'confer', 'take') 4
# ('chang', 'confer', 'take') 4
# ('chang', 'take', 'place') 4
# ('chang', 'sinc', 'trump') 4
# ('presid', 'trump', 'said') 4
# ('said', 'pari', 'accord') 4
# ('secur', 'better', 'deal') 4
# ('deal', 'associ', 'press') 4
# ('speak', 'climat', 'action') 4
# ('speak', 'climat', 'center') 4
# ('speak', 'climat', 'cop') 4
# ('speak', 'climat', 'fiji') 4
# ('speak', 'action', 'center') 4
# ('speak', 'action', 'cop') 4
# ('speak', 'action', 'fiji') 4
# ('speak', 'center', 'cop') 4
# ('speak', 'center', 'fiji') 4
# ('speak', 'cop', 'fiji') 4
# ('ap', 'meissner', 'new') 4
# ('ap', 'associ', 'new') 4
# ('ap', 'press', 'new') 4
# ('ap', 'former', 'new') 4
# ('meissner', 'associ', 'new') 4
# ('meissner', 'associ', 'york') 4
# ('meissner', 'press', 'new') 4
# ('meissner', 'press', 'york') 4
# ('meissner', 'former', 'new') 4
# ('meissner', 'former', 'york') 4
# ('meissner', 'new', 'york') 4
# ('associ', 'press', 'york') 4
# ('associ', 'press', 'mayor') 4
# ('associ', 'former', 'new') 4
# ('associ', 'former', 'york') 4
# ('associ', 'former', 'mayor') 4
# ('associ', 'new', 'york') 4
# ('associ', 'new', 'mayor') 4
# ('associ', 'york', 'mayor') 4
# ('press', 'former', 'new') 4
# ('press', 'former', 'york') 4
# ('press', 'former', 'mayor') 4
# ('press', 'former', 'billionair') 4
# ('press', 'new', 'york') 4
# ('press', 'new', 'mayor') 4
# ('press', 'new', 'billionair') 4
# ('press', 'york', 'mayor') 4
# ('press', 'york', 'billionair') 4
# ('press', 'mayor', 'billionair') 4
# ('former', 'new', 'billionair') 4
# ('former', 'york', 'billionair') 4
# ('former', 'mayor', 'billionair') 4
# ('former', 'billionair', 'michael') 4
# ('new', 'york', 'billionair') 4
# ('new', 'mayor', 'billionair') 4
# ('new', 'billionair', 'michael') 4
# ('new', 'billionair', 'bloomberg') 4
# ('york', 'mayor', 'billionair') 4
# ('york', 'billionair', 'michael') 4
# ('york', 'billionair', 'bloomberg') 4
# ('mayor', 'billionair', 'michael') 4
# ('mayor', 'billionair', 'bloomberg') 4
# ('mayor', 'billionair', 'speak') 4
# ('mayor', 'michael', 'speak') 4
# ('mayor', 'bloomberg', 'speak') 4
# ...
# ('said', 'base', 'prioriti') 2
# ('major', 'decis', 'expand') 2
# ('major', 'decis', 'base') 2
# ('major', 'decis', 'prioriti') 2
# ('major', 'decis', 'area') 2
# ('major', 'expand', 'base') 2
# ('major', 'expand', 'prioriti') 2
# ('major', 'expand', 'area') 2
# ('major', 'base', 'prioriti') 2
# ('major', 'base', 'area') 2
# ('major', 'prioriti', 'area') 2
# ('decis', 'expand', 'base') 2
# ('decis', 'expand', 'prioriti') 2
# ('decis', 'expand', 'area') 2
# ('decis', 'expand', 'also') 2
# ('decis', 'base', 'prioriti') 2
# ('decis', 'base', 'area') 2
# ('decis', 'base', 'also') 2
# ('decis', 'prioriti', 'area') 2
# ('decis', 'prioriti', 'also') 2
# ('decis', 'area', 'also') 2
# ('expand', 'base', 'prioriti') 2
# ('expand', 'base', 'area') 2
# ('expand', 'base', 'also') 2
# ('expand', 'base', 'taken') 2
# ('expand', 'prioriti', 'area') 2
# ('expand', 'prioriti', 'also') 2
# ('expand', 'prioriti', 'taken') 2
# ('expand', 'area', 'also') 2
# ('expand', 'area', 'taken') 2
# ('expand', 'also', 'taken') 2
# ('base', 'prioriti', 'area') 2
# ('base', 'prioriti', 'also') 2
# ('base', 'prioriti', 'taken') 2
# ('base', 'prioriti', 'meet') 2
# ('base', 'area', 'also') 2
# ('base', 'area', 'taken') 2
# ('base', 'area', 'meet') 2
# ('base', 'also', 'taken') 2
# ('base', 'also', 'meet') 2
# ('base', 'taken', 'meet') 2
# ('prioriti', 'area', 'also') 2
# ('prioriti', 'area', 'taken') 2
# ('prioriti', 'area', 'meet') 2
# ('prioriti', 'area', 'held') 2
# ('prioriti', 'also', 'taken') 2
# ('prioriti', 'also', 'meet') 2
# ('prioriti', 'also', 'held') 2
# ('prioriti', 'taken', 'meet') 2
# ('prioriti', 'taken', 'held') 2
# ('prioriti', 'meet', 'held') 2
# ('area', 'also', 'taken') 2
# ('area', 'also', 'meet') 2
# ('area', 'also', 'held') 2
# ('area', 'also', 'environ') 2
# ('area', 'taken', 'meet') 2
# ('area', 'taken', 'held') 2
# ('area', 'taken', 'environ') 2
# ('area', 'meet', 'held') 2
# ('area', 'meet', 'environ') 2
# ('area', 'held', 'environ') 2
# ('also', 'taken', 'meet') 2
# ('also', 'taken', 'held') 2
# ('also', 'taken', 'environ') 2
# ('also', 'taken', 'wing') 2
# ('also', 'meet', 'held') 2
# ('also', 'meet', 'environ') 2
# ('also', 'meet', 'wing') 2
# ('also', 'held', 'environ') 2
# ('also', 'held', 'wing') 2
# ('also', 'environ', 'wing') 2
# ('taken', 'meet', 'held') 2
# ('taken', 'meet', 'environ') 2
# ('taken', 'meet', 'wing') 2
# ('taken', 'meet', 'offici') 2
# ('taken', 'held', 'environ') 2
# ('taken', 'held', 'wing') 2
# ('taken', 'held', 'offici') 2
# ('taken', 'environ', 'wing') 2
# ('taken', 'environ', 'offici') 2
# ('taken', 'wing', 'offici') 2
# ('meet', 'held', 'environ') 2
# ('meet', 'held', 'wing') 2
# ('meet', 'held', 'offici') 2
# ('meet', 'held', 'state') 2
# ('meet', 'environ', 'wing') 2
# ('meet', 'environ', 'offici') 2
# ('meet', 'environ', 'state') 2
# ('meet', 'wing', 'offici') 2
# ('meet', 'wing', 'state') 2
# ('meet', 'offici', 'state') 2
# ('held', 'environ', 'wing') 2
# ('held', 'environ', 'offici') 2
# ('held', 'environ', 'state') 2
# ('held', 'environ', 'govern') 2
# ('held', 'wing', 'offici') 2
# ('held', 'wing', 'state') 2
# ('held', 'wing', 'govern') 2
# ('held', 'offici', 'state') 2
# ('held', 'offici', 'govern') 2
# ('held', 'state', 'govern') 2
# ('environ', 'wing', 'offici') 2
# ('environ', 'wing', 'govern') 2
# ('environ', 'offici', 'govern') 2
# ('environ', 'offici', 'depart') 2
# ('environ', 'state', 'govern') 2
# ('environ', 'govern', 'depart') 2
# ('wing', 'offici', 'state') 2
# ('wing', 'offici', 'govern') 2
# ('wing', 'offici', 'depart') 2
# ('wing', 'offici', 'unit') 2
# ('wing', 'state', 'govern') 2
# ('wing', 'state', 'unit') 2
# ('wing', 'govern', 'depart') 2
# ('wing', 'govern', 'unit') 2
# ('wing', 'depart', 'unit') 2
# ('offici', 'state', 'govern') 2
# ('offici', 'state', 'unit') 2
# ('offici', 'state', 'nation') 2
# ('offici', 'govern', 'depart') 2
# ('offici', 'govern', 'unit') 2
# ('offici', 'govern', 'nation') 2
# ('offici', 'depart', 'unit') 2
# ('offici', 'depart', 'nation') 2
# ('offici', 'unit', 'nation') 2
# ('state', 'govern', 'depart') 2
# ('state', 'govern', 'unit') 2
# ('state', 'govern', 'nation') 2
# ('state', 'govern', 'develop') 2
# ('state', 'depart', 'unit') 2
# ('state', 'depart', 'nation') 2
# ('state', 'unit', 'nation') 2
# ('state', 'unit', 'develop') 2
# ('state', 'nation', 'develop') 2
# ('govern', 'depart', 'unit') 2
# ('govern', 'depart', 'nation') 2
# ('govern', 'depart', 'develop') 2
# ('govern', 'unit', 'nation') 2
# ('govern', 'unit', 'develop') 2
# ('govern', 'nation', 'develop') 2
# ('depart', 'unit', 'nation') 2
# ('depart', 'unit', 'develop') 2
# ('depart', 'unit', 'undp') 2
# ('depart', 'nation', 'develop') 2
# ('depart', 'nation', 'undp') 2
# ('depart', 'develop', 'undp') 2
# ('develop', 'undp', 'chief') 2
# ('undp', 'chief', 'conserv') 2
# ('undp', 'chief', 'forest') 2
# ('undp', 'conserv', 'forest') 2
# ('chief', 'conserv', 'nodal') 2
# ('chief', 'conserv', 'offic') 2
# ('chief', 'forest', 'nodal') 2
# ('chief', 'forest', 'offic') 2
# ('chief', 'nodal', 'offic') 2
# ('chief', 'nodal', 'climat') 2
# ('chief', 'offic', 'climat') 2
# ('conserv', 'forest', 'nodal') 2
# ('conserv', 'forest', 'offic') 2
# ('conserv', 'nodal', 'offic') 2
# ('conserv', 'nodal', 'climat') 2
# ('conserv', 'nodal', 'chang') 2
# ('conserv', 'offic', 'climat') 2
# ('conserv', 'offic', 'chang') 2
# ('forest', 'nodal', 'offic') 2
# ('forest', 'nodal', 'climat') 2
# ('forest', 'nodal', 'chang') 2
# ('forest', 'offic', 'climat') 2
# ('forest', 'offic', 'chang') 2
# ('chang', 'said', 'select') 2
# ('said', 'select', 'four') 2
# ('said', 'select', 'prioriti') 2
# ('said', 'select', 'area') 2
# ('said', 'four', 'prioriti') 2
# ('said', 'four', 'area') 2
# ('said', 'prioriti', 'area') 2
# ('select', 'four', 'prioriti') 2
# ('select', 'four', 'area') 2
# ('select', 'four', 'forest') 2
# ('select', 'prioriti', 'area') 2
# ('select', 'prioriti', 'forest') 2
# ('select', 'area', 'forest') 2
# ('four', 'prioriti', 'area') 2
# ('four', 'prioriti', 'forest') 2
# ('four', 'prioriti', 'energi') 2
# ('four', 'area', 'forest') 2
# ('four', 'area', 'energi') 2
# ('four', 'forest', 'energi') 2
# ('prioriti', 'area', 'forest') 2
# ('prioriti', 'area', 'energi') 2
# ('prioriti', 'area', 'disast') 2
# ('prioriti', 'forest', 'energi') 2
# ('prioriti', 'forest', 'disast') 2
# ('prioriti', 'energi', 'disast') 2
# ('area', 'forest', 'energi') 2
# ('area', 'forest', 'disast') 2
# ('area', 'forest', 'manag') 2
# ('area', 'energi', 'disast') 2
# ('area', 'energi', 'manag') 2
# ('area', 'disast', 'manag') 2
# ('forest', 'energi', 'manag') 2
# ('forest', 'energi', 'adapt') 2
# ('forest', 'energi', 'implement') 2
# ('forest', 'disast', 'manag') 2
# ('forest', 'disast', 'adapt') 2
# ('forest', 'disast', 'implement') 2
# ('forest', 'manag', 'adapt') 2
# ('forest', 'manag', 'implement') 2
# ('forest', 'adapt', 'implement') 2
# ('energi', 'disast', 'manag') 2
# ('energi', 'disast', 'adapt') 2
# ('energi', 'disast', 'implement') 2
# ('energi', 'disast', 'climat') 2
# ('energi', 'manag', 'adapt') 2
# ('energi', 'manag', 'implement') 2
# ('energi', 'manag', 'climat') 2
# ('energi', 'adapt', 'implement') 2
# ('energi', 'adapt', 'climat') 2
# ('energi', 'implement', 'climat') 2
# ('disast', 'manag', 'adapt') 2
# ('disast', 'manag', 'implement') 2
# ('disast', 'adapt', 'implement') 2
# ('disast', 'adapt', 'climat') 2
# ('disast', 'adapt', 'chang') 2
# ('disast', 'implement', 'climat') 2
# ('disast', 'implement', 'chang') 2
# ('manag', 'adapt', 'implement') 2
# ('manag', 'adapt', 'climat') 2
# ('manag', 'adapt', 'chang') 2
# ('manag', 'adapt', 'action') 2
# ('manag', 'implement', 'climat') 2
# ('manag', 'implement', 'chang') 2
# ('manag', 'implement', 'action') 2
# ('manag', 'climat', 'action') 2
# ('manag', 'chang', 'action') 2
# ('adapt', 'implement', 'climat') 2
# ('adapt', 'implement', 'chang') 2
# ('adapt', 'implement', 'action') 2
# ('adapt', 'climat', 'action') 2
# ('adapt', 'chang', 'action') 2
# ('implement', 'climat', 'take') 2
# ('implement', 'chang', 'take') 2
# ('implement', 'action', 'take') 2
# ('climat', 'action', 'take') 2
# ('climat', 'action', 'area') 2
# ('climat', 'take', 'area') 2
# ('chang', 'action', 'take') 2
# ('chang', 'action', 'area') 2
# ('chang', 'action', 'main') 2
# ('chang', 'take', 'area') 2
# ('chang', 'take', 'main') 2
# ('chang', 'area', 'main') 2
# ('action', 'take', 'area') 2
# ('action', 'take', 'main') 2
# ('action', 'take', 'educ') 2
# ('action', 'area', 'main') 2
# ('action', 'area', 'educ') 2
# ('action', 'main', 'educ') 2
# ('take', 'area', 'main') 2
# ('area', 'main', 'much') 2
# ('main', 'much', 'earli') 2
# ('educ', 'much', 'induc') 2
# ('educ', 'earli', 'induc') 2
# ('educ', 'stage', 'induc') 2
# ('much', 'earli', 'stage') 2
# ('much', 'earli', 'induc') 2
# ('much', 'earli', 'sensit') 2
# ('much', 'stage', 'induc') 2
# ('much', 'stage', 'sensit') 2
# ('much', 'induc', 'sensit') 2
# ('earli', 'stage', 'induc') 2
# ('earli', 'stage', 'sensit') 2
# ('earli', 'stage', 'understand') 2
# ('earli', 'induc', 'sensit') 2
# ('earli', 'induc', 'understand') 2
# ('earli', 'sensit', 'understand') 2
# ('stage', 'induc', 'sensit') 2
# ('stage', 'induc', 'understand') 2
# ('stage', 'induc', 'toward') 2
# ('stage', 'sensit', 'understand') 2
# ('stage', 'sensit', 'toward') 2
# ('stage', 'understand', 'toward') 2
# ('induc', 'sensit', 'understand') 2
# ('induc', 'sensit', 'toward') 2
# ('induc', 'sensit', 'extent') 2
# ('induc', 'sensit', 'magnitud') 2
# ('induc', 'understand', 'toward') 2
# ('induc', 'understand', 'extent') 2
# ('induc', 'understand', 'magnitud') 2
# ('induc', 'toward', 'extent') 2
# ('induc', 'toward', 'magnitud') 2
# ('induc', 'extent', 'magnitud') 2
# ('sensit', 'understand', 'toward') 2
# ('sensit', 'understand', 'extent') 2
# ('sensit', 'understand', 'magnitud') 2
# ('sensit', 'understand', 'way') 2
# ('sensit', 'toward', 'extent') 2
# ('sensit', 'toward', 'magnitud') 2
# ('sensit', 'toward', 'way') 2
# ('sensit', 'extent', 'magnitud') 2
# ('sensit', 'extent', 'way') 2
# ('sensit', 'magnitud', 'way') 2
# ('understand', 'toward', 'extent') 2
# ('understand', 'toward', 'magnitud') 2
# ('understand', 'toward', 'way') 2
# ('understand', 'toward', 'deal') 2
# ('understand', 'extent', 'magnitud') 2
# ('understand', 'extent', 'way') 2
# ('understand', 'extent', 'deal') 2
# ('understand', 'magnitud', 'way') 2
# ('understand', 'magnitud', 'deal') 2
# ('understand', 'way', 'deal') 2
# ('toward', 'extent', 'magnitud') 2
# ('toward', 'extent', 'way') 2
# ('toward', 'extent', 'deal') 2
# ('toward', 'magnitud', 'way') 2
# ('toward', 'magnitud', 'deal') 2
# ('toward', 'way', 'deal') 2
# ('extent', 'magnitud', 'way') 2
# ('extent', 'magnitud', 'deal') 2
# ('extent', 'magnitud', 'climat') 2
# ('extent', 'way', 'deal') 2
# ('extent', 'way', 'climat') 2
# ('extent', 'deal', 'climat') 2
# ('magnitud', 'way', 'deal') 2
# ('magnitud', 'way', 'climat') 2
# ('magnitud', 'way', 'chang') 2
# ('magnitud', 'deal', 'climat') 2
# ('magnitud', 'deal', 'chang') 2
# ('magnitud', 'climat', 'chang') 2
# ('way', 'deal', 'climat') 2
# ('way', 'deal', 'chang') 2
# ('way', 'deal', 'habitat') 2
# ('way', 'climat', 'habitat') 2
# ('way', 'chang', 'habitat') 2
# ('deal', 'climat', 'habitat') 2
# ('deal', 'climat', 'area') 2
# ('deal', 'chang', 'habitat') 2
# ('deal', 'chang', 'area') 2
# ('deal', 'habitat', 'area') 2
# ('climat', 'chang', 'amalgam') 2
# ('climat', 'habitat', 'area') 2
# ('climat', 'habitat', 'amalgam') 2
# ('climat', 'area', 'amalgam') 2
# ('chang', 'habitat', 'area') 2
# ('chang', 'habitat', 'amalgam') 2
# ('chang', 'habitat', 'depart') 2
# ('chang', 'area', 'amalgam') 2
# ('chang', 'area', 'depart') 2
# ('chang', 'amalgam', 'depart') 2
# ('habitat', 'area', 'amalgam') 2
# ('habitat', 'area', 'depart') 2
# ('habitat', 'area', 'complement') 2
# ('habitat', 'amalgam', 'depart') 2
# ('habitat', 'amalgam', 'complement') 2
# ('habitat', 'depart', 'complement') 2
# ('area', 'amalgam', 'depart') 2
# ('area', 'amalgam', 'complement') 2
# ('area', 'amalgam', 'mandat') 2
# ('area', 'depart', 'complement') 2
# ('area', 'depart', 'mandat') 2
# ('area', 'complement', 'mandat') 2
# ('amalgam', 'depart', 'complement') 2
# ('amalgam', 'depart', 'mandat') 2
# ('amalgam', 'depart', 'tourism') 2
# ('amalgam', 'depart', 'transport') 2
# ('amalgam', 'complement', 'mandat') 2
# ('amalgam', 'complement', 'tourism') 2
# ('amalgam', 'complement', 'transport') 2
# ('amalgam', 'mandat', 'tourism') 2
# ('amalgam', 'mandat', 'transport') 2
# ('amalgam', 'tourism', 'transport') 2
# ('depart', 'complement', 'mandat') 2
# ('depart', 'complement', 'tourism') 2
# ('depart', 'complement', 'transport') 2
# ('depart', 'complement', 'agricultur') 2
# ('depart', 'mandat', 'tourism') 2
# ('depart', 'mandat', 'transport') 2
# ('depart', 'mandat', 'agricultur') 2
# ('depart', 'tourism', 'transport') 2
# ('depart', 'tourism', 'agricultur') 2
# ('depart', 'transport', 'agricultur') 2
# ('complement', 'mandat', 'tourism') 2
# ('complement', 'mandat', 'transport') 2
# ('complement', 'mandat', 'agricultur') 2
# ('complement', 'mandat', 'horticultur') 2
# ('complement', 'tourism', 'transport') 2
# ('complement', 'tourism', 'agricultur') 2
# ('complement', 'tourism', 'horticultur') 2
# ('complement', 'transport', 'agricultur') 2
# ('complement', 'transport', 'horticultur') 2
# ('complement', 'agricultur', 'horticultur') 2
# ('mandat', 'tourism', 'transport') 2
# ('mandat', 'tourism', 'agricultur') 2
# ('mandat', 'tourism', 'horticultur') 2
# ('mandat', 'tourism', 'anim') 2
# ('mandat', 'transport', 'agricultur') 2
# ('mandat', 'transport', 'horticultur') 2
# ('mandat', 'transport', 'anim') 2
# ('mandat', 'agricultur', 'horticultur') 2
# ('mandat', 'agricultur', 'anim') 2
# ('mandat', 'horticultur', 'anim') 2
# ('tourism', 'transport', 'anim') 2
# ('tourism', 'transport', 'husbandri') 2
# ('tourism', 'agricultur', 'anim') 2
# ('tourism', 'agricultur', 'husbandri') 2
# ('tourism', 'horticultur', 'anim') 2
# ('tourism', 'horticultur', 'husbandri') 2
# ('tourism', 'anim', 'husbandri') 2
# ('transport', 'agricultur', 'anim') 2
# ('transport', 'agricultur', 'husbandri') 2
# ('transport', 'agricultur', 'way') 2
# ('transport', 'horticultur', 'anim') 2
# ('transport', 'horticultur', 'husbandri') 2
# ('transport', 'horticultur', 'way') 2
# ('transport', 'anim', 'husbandri') 2
# ('transport', 'anim', 'way') 2
# ('transport', 'husbandri', 'way') 2
# ('agricultur', 'horticultur', 'anim') 2
# ('agricultur', 'horticultur', 'husbandri') 2
# ('agricultur', 'horticultur', 'way') 2
# ('agricultur', 'horticultur', 'abl') 2
# ('agricultur', 'anim', 'husbandri') 2
# ('agricultur', 'anim', 'way') 2
# ('agricultur', 'anim', 'abl') 2
# ('agricultur', 'husbandri', 'way') 2
# ('agricultur', 'husbandri', 'abl') 2
# ('agricultur', 'way', 'abl') 2
# ('horticultur', 'anim', 'husbandri') 2
# ('horticultur', 'anim', 'way') 2
# ('horticultur', 'anim', 'abl') 2
# ('horticultur', 'anim', 'bring') 2
# ('horticultur', 'husbandri', 'way') 2
# ('horticultur', 'husbandri', 'abl') 2
# ('horticultur', 'husbandri', 'bring') 2
# ('horticultur', 'way', 'abl') 2
# ('horticultur', 'way', 'bring') 2
# ('horticultur', 'abl', 'bring') 2
# ('anim', 'husbandri', 'way') 2
# ('anim', 'husbandri', 'abl') 2
# ('anim', 'husbandri', 'bring') 2
# ('anim', 'husbandri', 'import') 2
# ('anim', 'way', 'abl') 2
# ('anim', 'way', 'bring') 2
# ('anim', 'way', 'import') 2
# ('anim', 'abl', 'bring') 2
# ('anim', 'abl', 'import') 2
# ('anim', 'bring', 'import') 2
# ('husbandri', 'way', 'abl') 2
# ('husbandri', 'way', 'bring') 2
# ('husbandri', 'way', 'import') 2
# ('husbandri', 'way', 'sector') 2
# ('husbandri', 'abl', 'bring') 2
# ('husbandri', 'abl', 'import') 2
# ('husbandri', 'abl', 'sector') 2
# ('husbandri', 'bring', 'import') 2
# ('husbandri', 'bring', 'sector') 2
# ('husbandri', 'import', 'sector') 2
# ('way', 'abl', 'bring') 2
# ('way', 'abl', 'import') 2
# ('way', 'abl', 'sector') 2
# ('way', 'bring', 'import') 2
# ('way', 'bring', 'sector') 2
# ('way', 'import', 'sector') 2
# ('abl', 'bring', 'import') 2
# ('abl', 'bring', 'sector') 2
# ('abl', 'bring', 'ambit') 2
# ('abl', 'bring', 'sapcc') 2
# ('abl', 'import', 'sector') 2
# ('abl', 'import', 'ambit') 2
# ('abl', 'import', 'sapcc') 2
# ('abl', 'sector', 'ambit') 2
# ('abl', 'sector', 'sapcc') 2
# ('bring', 'import', 'sector') 2
# ('bring', 'import', 'ambit') 2
# ('bring', 'import', 'sapcc') 2
# ('bring', 'sector', 'ambit') 2
# ('bring', 'sector', 'sapcc') 2
# ('import', 'sector', 'ambit') 2
# ('import', 'sector', 'sapcc') 2
# ('overal', 'budget', 'sustain') 2
# ('budget', 'sustain', 'develop') 2
# ('budget', 'depart', 'budget') 2
# ('technolog', 'centr', 'excel') 2
# ('research', 'scholar', 'look') 2
# ('cyclon', 'past', 'decad') 2
# ('averag', 'radius', 'cyclon') 2
# ('bangladesh', 'long', 'wave') 2
# ('long', 'wave', 'generat') 2
# ('wave', 'generat', 'wind') 2
# ('increas', 'eastern', 'side') 2
# ('eastern', 'side', 'alter') 2
# ('side', 'alter', 'sedimentari') 2

# %%
newsWords = news['normalized_tokens'].sum()
skipgrams = skipgrams(newsWords, 2, 6) # bigrams, skip 6 words

skipFiltered = countDict(list(skipgrams))
printDesc(skipFiltered)
# Out:
# ('climat', 'chang') 950
# ('chang', 'climat') 156
# ('climat', 'climat') 138
# ('climat', 'said') 99
# ('chang', 'chang') 94
# ('pari', 'agreement') 93
# ('global', 'warm') 91
# ('chang', 'said') 88
# ('said', 'climat') 82
# ('per', 'cent') 75
# ('said', 'chang') 67
# ('climat', 'risk') 64
# ('pari', 'climat') 63
# ('global', 'climat') 62
# ('climat', 'global') 58
# ('trump', 'climat') 57
# ('climat', 'action') 57
# ('donald', 'trump') 56
# ('renew', 'energi') 55
# ('impact', 'climat') 54
# ('nation', 'climat') 54
# ('chang', 'global') 53
# ('us', 'climat') 53
# ('unit', 'state') 50
# ('climat', 'us') 50
# ('fossil', 'fuel') 49
# ('impact', 'chang') 49
# ('climat', 'confer') 48
# ('state', 'climat') 48
# ('action', 'climat') 47
# ('risk', 'climat') 45
# ('presid', 'trump') 44
# ('climat', 'polici') 44
# ('climat', 'nation') 44
# ('chang', 'us') 42
# ('nation', 'chang') 42
# ('climat', 'trump') 42
# ('chang', 'nation') 42
# ('climat', 'state') 42
# ('risk', 'chang') 42
# ('chang', 'state') 42
# ('greenhous', 'gas') 41
# ('effect', 'climat') 41
# ('chang', 'risk') 41
# ('greenhous', 'emiss') 40
# ('gas', 'emiss') 40
# ('state', 'chang') 40
# ('carbon', 'emiss') 39
# ('un', 'climat') 39
# ('climat', 'fund') 39
# ('clean', 'energi') 39
# ('trump', 'chang') 38
# ('world', 'climat') 38
# ('energi', 'energi') 38
# ('last', 'year') 38
# ('global', 'chang') 38
# ('say', 'climat') 38
# ('climat', 'research') 38
# ('chang', 'confer') 37
# ('govern', 'climat') 37
# ('action', 'chang') 37
# ('climat', 'scientist') 37
# ('chang', 'trump') 36
# ('effect', 'chang') 36
# ('pari', 'accord') 35
# ('climat', 'pari') 35
# ('climat', 'increas') 35
# ('chang', 'impact') 35
# ('climat', 'busi') 34
# ('climat', 'agreement') 34
# ('year', 'climat') 34
# ('us', 'chang') 34
# ('climat', 'bonn') 34
# ('associ', 'press') 34
# ('presid', 'donald') 33
# ('climat', 'year') 32
# ('us', 'trump') 32
# ('chang', 'polici') 32
# ('countri', 'climat') 32
# ('unit', 'nation') 32
# ('chang', 'would') 32
# ('presid', 'climat') 32
# ('china', 'climat') 32
# ('chang', 'action') 32
# ('un', 'chang') 31
# ('climat', 'world') 31
# ('also', 'climat') 31
# ('adapt', 'climat') 31
# ('plan', 'climat') 30
# ('trump', 'pari') 30
# ('chang', 'increas') 30
# ('pari', 'chang') 30
# ('climat', 'accord') 30
# ('said', 'would') 30
# ('climat', 'energi') 30
# ('unit', 'climat') 30
# ('ap', 'associ') 30
# ('ap', 'press') 30
# ('new', 'climat') 29
# ('take', 'climat') 29
# ('need', 'climat') 29
# ('plan', 'chang') 29
# ('chang', 'world') 29
# ('climat', 'would') 29
# ('one', 'climat') 29
# ('develop', 'countri') 29
# ('climat', 'impact') 29
# ('bonn', 'germani') 29
# ('climat', 'germani') 29
# ('chang', 'issu') 28
# ('chang', 'year') 28
# ('sustain', 'develop') 28
# ('temperatur', 'rise') 28
# ('research', 'climat') 28
# ('chang', 'bonn') 28
# ('climat', 'report') 28
# ('adapt', 'chang') 28
# ('depart', 'climat') 28
# ('extrem', 'weather') 28
# ('peopl', 'climat') 27
# ('us', 'presid') 27
# ('us', 'pari') 27
# ('chang', 'pari') 27
# ('studi', 'climat') 27
# ('polici', 'climat') 27
# ('chang', 'energi') 27
# ('climat', 'adapt') 27
# ('chang', 'also') 27
# ('climat', 'china') 27
# ('say', 'chang') 27
# ('said', 'state') 27
# ('nation', 'secur') 27
# ('climat', 'say') 27
# ('reduc', 'emiss') 26
# ('climat', 'issu') 26
# ('energi', 'climat') 26
# ('framework', 'climat') 26
# ('govern', 'chang') 26
# ('climat', 'countri') 26
# ('chang', 'adapt') 26
# ('report', 'climat') 26
# ('chang', 'say') 26
# ('world', 'chang') 25
# ('chang', 'agreement') 25
# ('confer', 'bonn') 25
# ('sea', 'level') 25
# ('energi', 'chang') 25
# ('climat', 'work') 25
# ('chang', 'report') 25
# ('report', 'chang') 25
# ('chang', 'threat') 25
# ('chang', 'germani') 25
# ('new', 'york') 24
# ('chang', 'one') 24
# ('help', 'climat') 24
# ('trump', 'us') 24
# ('chang', 'weather') 24
# ('chang', 'extrem') 24
# ('climat', 'govern') 24
# ('chang', 'work') 24
# ('climat', 'also') 24
# ('chang', 'china') 24
# ('climat', 'need') 24
# ('climat', 'unit') 24
# ('chang', 'research') 24
# ('depart', 'chang') 24
# ('chang', 'depart') 24
# ('climat', 'scienc') 24
# ('chang', 'busi') 23
# ('take', 'chang') 23
# ('climat', 'plan') 23
# ('said', 'global') 23
# ('chang', 'countri') 23
# ('un', 'confer') 23
# ('framework', 'chang') 23
# ('climat', 'take') 23
# ('busi', 'climat') 23
# ('peopl', 'chang') 23
# ('climat', 'threat') 23
# ('confer', 'germani') 23
# ('climat', 'depart') 23
# ('state', 'plan') 23
# ('fight', 'climat') 22
# ('climat', 'peopl') 22
# ('would', 'climat') 22
# ('agreement', 'climat') 22
# ('climat', 'alreadi') 22
# ('chang', 'govern') 22
# ('extrem', 'event') 22
# ('chang', 'fund') 22
# ('unit', 'chang') 22
# ('work', 'climat') 22
# ('polici', 'chang') 22
# ('financi', 'risk') 22
# ('fund', 'climat') 21
# ('trump', 'administr') 21
# ('trump', 'said') 21
# ('carbon', 'dioxid') 21
# ('convent', 'climat') 21
# ('research', 'chang') 21
# ('said', 'said') 21
# ('chang', 'real') 21
# ('climat', 'one') 21
# ('chang', 'need') 21
# ('countri', 'chang') 21
# ('tackl', 'climat') 21
# ('accord', 'climat') 21
# ('challeng', 'climat') 21
# ('climat', 'includ') 21
# ('chang', 'take') 21
# ('centr', 'climat') 21
# ('action', 'plan') 21
# ('work', 'plan') 21
# ('develop', 'climat') 20
# ('need', 'chang') 20
# ('climat', 'presid') 20
# ('rise', 'level') 20
# ('climat', 'made') 20
# ('climat', 'real') 20
# ('chang', 'temperatur') 20
# ('global', 'temperatur') 20
# ('environ', 'climat') 20
# ('climat', 'project') 20
# ('chang', 'compani') 20
# ('power', 'plant') 20
# ('fight', 'chang') 19
# ('issu', 'climat') 19
# ('chang', 'peopl') 19
# ('climat', 'could') 19
# ('import', 'climat') 19
# ('agreement', 'chang') 19
# ('climat', 'environment') 19
# ('chang', 'alreadi') 19
# ('climat', 'caus') 19
# ('climat', 'weather') 19
# ('climat', 'secur') 19
# ('climat', 'mani') 19
# ('public', 'climat') 19
# ('like', 'climat') 19
# ('chang', 'effect') 19
# ('includ', 'climat') 19
# ('chang', 'develop') 19
# ('global', 'said') 19
# ('econom', 'growth') 19
# ('climat', 'temperatur') 19
# ('chang', 'project') 19
# ('china', 'chang') 19
# ('climat', 'rise') 19
# ('help', 'chang') 19
# ('said', 'trump') 19
# ('whether', 'climat') 19
# ('chang', 'plan') 19
# ('effort', 'climat') 19
# ('climat', 'cop') 19
# ('cop', 'climat') 19
# ('mr', 'said') 19
# ('chang', 'presid') 18
# ('climat', 'may') 18
# ('presid', 'pari') 18
# ('climat', 'warm') 18
# ('climat', 'onli') 18
# ('futur', 'climat') 18
# ('chang', 'accord') 18
# ('also', 'chang') 18
# ('intern', 'climat') 18
# ('convent', 'chang') 18
# ('increas', 'climat') 18
# ('million', 'peopl') 18
# ('per', 'per') 18
# ('climat', 'recent') 18
# ('climat', 'effect') 18
# ('said', 'us') 18
# ('climat', 'compani') 18
# ('chang', 'rise') 18
# ('chang', 'secur') 18
# ('chang', 'unit') 18
# ('would', 'chang') 18
# ('pull', 'pari') 18
# ('weather', 'climat') 18
# ('un', 'bonn') 18
# ('climat', 'develop') 18
# ('compani', 'climat') 18
# ('chang', 'could') 18
# ('cent', 'per') 18
# ('chang', 'economi') 17
# ('us', 'donald') 17
# ('global', 'global') 17
# ('rise', 'climat') 17
# ('oil', 'gas') 17
# ('rise', 'sea') 17
# ('make', 'climat') 17
# ('chang', 'emiss') 17
# ('threat', 'climat') 17
# ('scienc', 'climat') 17
# ('climat', 'part') 17
# ('climat', 'extrem') 17
# ('year', 'chang') 17
# ('climat', 'economi') 17
# ('risk', 'said') 17
# ('donald', 'climat') 17
# ('us', 'global') 17
# ('deal', 'climat') 17
# ('deal', 'chang') 17
# ('sustain', 'climat') 17
# ('climat', 'new') 17
# ('tackl', 'chang') 17
# ('respons', 'climat') 17
# ('meet', 'climat') 17
# ('chang', 'environ') 17
# ('climat', 'natur') 17
# ('studi', 'chang') 17
# ('said', 'pari') 17
# ('trump', 'secur') 17
# ('emiss', 'climat') 17
# ('financi', 'climat') 17
# ('un', 'germani') 17
# ('implement', 'climat') 17
# ('small', 'busi') 17
# ('fiji', 'climat') 17
# ('energi', 'project') 17
# ('investor', 'risk') 17
# ('mr', 'trump') 17
# ('issu', 'chang') 16
# ('busi', 'chang') 16
# ('manag', 'climat') 16
# ('address', 'climat') 16
# ('climat', 'expect') 16
# ('donald', 'pari') 16
# ('withdraw', 'pari') 16
# ('climat', 'un') 16
# ('commit', 'pari') 16
# ('vulner', 'climat') 16
# ('chang', 'environment') 16
# ('measur', 'climat') 16
# ('drought', 'conflict') 16
# ('chang', 'caus') 16
# ('weather', 'event') 16
# ('china', 'global') 16
# ('chang', 'made') 16
# ('agre', 'climat') 16
# ('warm', 'climat') 16
# ('chang', 'new') 16
# ('contribut', 'climat') 16
# ('state', 'state') 16
# ('around', 'world') 16
# ('trump', 'agreement') 16
# ('pari', 'global') 16
# ('climat', 'commit') 16
# ('project', 'climat') 16
# ('chang', 'area') 16
# ('climat', 'environ') 16
# ('econom', 'climat') 16
# ('chang', 'agricultur') 16
# ('challeng', 'chang') 16
# ('chang', 'includ') 16
# ('climat', 'human') 16
# ('fiji', 'bonn') 16
# ('implement', 'chang') 16
# ('chang', 'affect') 16
# ('set', 'climat') 16
# ('climat', 'citi') 15
# ('white', 'hous') 15
# ('year', 'said') 15
# ('address', 'chang') 15
# ('copyright', 'arab') 15
# ('copyright', 'news') 15
# ('arab', 'news') 15
# ('climat', 'challeng') 15
# ('mitig', 'climat') 15
# ('investor', 'climat') 15
# ('trump', 'accord') 15
# ('panel', 'climat') 15
# ('percent', 'percent') 15
# ('think', 'climat') 15
# ('us', 'energi') 15
# ('measur', 'chang') 15
# ('caus', 'chang') 15
# ('risk', 'risk') 15
# ('play', 'role') 15
# ('like', 'chang') 15
# ('chang', 'mani') 15
# ('scientist', 'climat') 15
# ('climat', 'public') 15
# ('chang', 'public') 15
# ('chief', 'climat') 15
# ('human', 'climat') 15
# ('chang', 'first') 15
# ('economi', 'climat') 15
# ('chang', 'industri') 15
# ('one', 'chang') 15
# ('first', 'climat') 15
# ('respons', 'chang') 15
# ('nation', 'nation') 15
# ('energi', 'effici') 15
# ('accord', 'chang') 15
# ('rise', 'chang') 15
# ('chang', 'natur') 15
# ('climat', 'agricultur') 15
# ('climat', 'sustain') 15
# ('chang', 'sustain') 15
# ('chang', 'food') 15
# ('call', 'climat') 15
# ('econom', 'chang') 15
# ('energi', 'said') 15
# ('climat', 'carbon') 15
# ('chang', 'onli') 15
# ('chang', 'human') 15
# ('administr', 'climat') 15
# ('financi', 'chang') 15
# ('effort', 'chang') 15
# ('fiji', 'confer') 15
# ('work', 'chang') 15
# ('climat', 'saturday') 15
# ('confer', 'saturday') 15
# ('cop', 'bonn') 15
# ('cop', 'germani') 15
# ('bonn', 'saturday') 15
# ('germani', 'saturday') 15
# ('cop', 'chang') 15
# ('forest', 'chang') 15
# ('per', 'climat') 15
# ('kenya', 'climat') 15
# ('chang', 'forest') 15
# ('state', 'depart') 15
# ('new', 'chang') 14
# ('michael', 'bloomberg') 14
# ('chang', 'get') 14
# ('chief', 'execut') 14
# ('chief', 'said') 14
# ('prime', 'minist') 14
# ('global', 'pari') 14
# ('mitig', 'chang') 14
# ('chang', 'investor') 14
# ('climat', 'univers') 14
# ('agreement', 'us') 14
# ('drought', 'contribut') 14
# ('climat', 'futur') 14
# ('chang', 'warm') 14
# ('us', 'china') 14
# ('framework', 'convent') 14
# ('energi', 'us') 14
# ('conflict', 'drought') 14
# ('climat', 'emiss') 14
# ('threat', 'chang') 14
# ('chang', 'contribut') 14
# ('confer', 'climat') 14
# ('climat', 'two') 14
# ('countri', 'said') 14
# ('presid', 'chang') 14
# ('chang', 'recent') 14
# ('trump', 'global') 14
# ('agre', 'chang') 14
# ('must', 'climat') 14
# ('must', 'chang') 14
# ('lead', 'climat') 14
# ('chang', 'part') 14
# ('climat', 'like') 14
# ('greenhous', 'gase') 14
# ('climat', 'first') 14
# ('climat', 'industri') 14
# ('rise', 'temperatur') 14
# ('climat', 'point') 14
# ('industri', 'climat') 14
# ('climat', 'reduc') 14
# ('chang', 'reduc') 14
# ('chang', 'serious') 14
# ('due', 'climat') 14
# ('vulner', 'chang') 14
# ('extrem', 'climat') 14
# ('combat', 'climat') 14
# ('environment', 'climat') 14
# ('said', 'unit') 14
# ('continu', 'climat') 14
# ('human', 'activ') 14
# ('climat', 'serious') 14
# ('us', 'state') 14
# ('trump', 'pull') 14
# ('climat', 'meet') 14
# ('trump', 'nation') 14
# ('us', 'agreement') 14
# ('mani', 'climat') 14
# ('air', 'pollut') 14
# ('natur', 'disast') 14
# ('state', 'citi') 14
# ('cop', 'fiji') 14
# ('cop', 'un') 14
# ('cop', 'confer') 14
# ('fiji', 'un') 14
# ('fiji', 'chang') 14
# ('chang', 'financi') 14
# ('centr', 'chang') 14
# ('forest', 'climat') 14
# ('risk', 'investor') 14
# ('cent', 'cent') 14
# ('fund', 'develop') 13
# ('world', 'also') 13
# ('climat', 'get') 13
# ('chang', 'becaus') 13
# ('chief', 'chang') 13
# ('chang', 'chief') 13
# ('trade', 'agreement') 13
# ('univers', 'climat') 13
# ('good', 'climat') 13
# ('chang', 'expect') 13
# ('climat', 'sign') 13
# ('world', 'leader') 13
# ('world', 'global') 13
# ('climat', 'vulner') 13
# ('agreement', 'global') 13
# ('time', 'climat') 13
# ('trump', 'trump') 13
# ('environment', 'protect') 13
# ('energi', 'renew') 13
# ('agreement', 'countri') 13
# ('us', 'world') 13
# ('caus', 'climat') 13
# ('increas', 'chang') 13
# ('chang', 'continu') 13
# ('center', 'climat') 13
# ('climat', 'found') 13
# ('understand', 'climat') 13
# ('chang', 'intern') 13
# ('past', 'year') 13
# ('said', 'nation') 13
# ('commit', 'climat') 13
# ('public', 'chang') 13
# ('climat', 'concern') 13
# ('countri', 'pari') 13
# ('climat', 'intern') 13
# ('support', 'climat') 13
# ('level', 'climat') 13
# ('major', 'climat') 13
# ('chang', 'point') 13
# ('natur', 'resourc') 13
# ('environ', 'chang') 13
# ('chang', 'last') 13
# ('nation', 'framework') 13
# ('global', 'rise') 13
# ('chang', 'carbon') 13
# ('project', 'chang') 13
# ('climat', 'area') 13
# ('climat', 'food') 13
# ('region', 'chang') 13
# ('come', 'climat') 13
# ('chang', 'studi') 13
# ('combat', 'chang') 13
# ('environment', 'chang') 13
# ('climat', 'sinc') 13
# ('chang', 'sinc') 13
# ('state', 'polici') 13
# ('state', 'said') 13
# ('cooper', 'climat') 13
# ('offic', 'climat') 13
# ('agreement', 'trump') 13
# ('polici', 'said') 13
# ('energi', 'world') 13
# ('discuss', 'climat') 13
# ('warn', 'climat') 13
# ('warn', 'chang') 13
# ('weather', 'chang') 13
# ('much', 'climat') 13
# ('climat', 'act') 13
# ('said', 'risk') 13
# ('nation', 'strategi') 13
# ('said', 'energi') 13
# ('chang', 'associ') 13
# ('director', 'climat') 13
# ('environ', 'depart') 13
# ('risk', 'compani') 13
# ('compani', 'risk') 13
# ('manag', 'risk') 13
# ('cent', 'climat') 13
# ('kenya', 'chang') 13
# ('counti', 'climat') 13
# ('state', 'action') 13
# ('plan', 'forest') 13
# ('get', 'climat') 12
# ('trump', 'presid') 12
# ('climat', 'face') 12
# ('chang', 'may') 12
# ('could', 'climat') 12
# ('global', 'energi') 12
# ('disast', 'climat') 12
# ('develop', 'develop') 12
# ('climat', 'cost') 12
# ('act', 'climat') 12
# ('show', 'climat') 12
# ('climat', 'come') 12
# ('keep', 'temperatur') 12
# ('green', 'energi') 12
# ('green', 'climat') 12
# ('chang', 'measur') 12
# ('chang', 'well') 12
# ('ani', 'climat') 12
# ('pari', 'us') 12
# ('toward', 'climat') 12
# ('contribut', 'conflict') 12
# ('make', 'chang') 12
# ('climat', 'continu') 12
# ('climat', 'contribut') 12
# ('face', 'climat') 12
# ('said', 'need') 12
# ('develop', 'energi') 12
# ('chang', 'two') 12
# ('fund', 'fund') 12
# ('new', 'said') 12
# ('us', 'said') 12
# ('climat', 'talk') 12
# ('climat', 'level') 12
# ('chang', 'level') 12
# ('believ', 'climat') 12
# ('chang', 'scientist') 12
# ('peopl', 'live') 12
# ('world', 'econom') 12
# ('nation', 'global') 12
# ('state', 'govern') 12
# ('concern', 'climat') 12
# ('said', 'report') 12
# ('said', 'director') 12
# ('climat', 'still') 12
# ('look', 'climat') 12
# ('countri', 'global') 12
# ('cut', 'emiss') 12
# ('us', 'decis') 12
# ('kyoto', 'protocol') 12
# ('state', 'pari') 12
# ('action', 'busi') 12
# ('environ', 'said') 12
# ('project', 'project') 12
# ('around', 'climat') 12
# ('level', 'chang') 12
# ('natur', 'climat') 12
# ('chang', 'product') 12
# ('region', 'climat') 12
# ('climat', 'studi') 12
# ('climat', 'well') 12
# ('carbon', 'trade') 12
# ('offic', 'chang') 12
# ('meet', 'chang') 12
# ('discuss', 'chang') 12
# ('mani', 'us') 12
# ('offici', 'state') 12
# ('million', 'climat') 12
# ('dure', 'climat') 12
# ('chang', 'act') 12
# ('climat', 'affect') 12
# ('offici', 'said') 12
# ('speak', 'climat') 12
# ('regul', 'emiss') 12
# ('climat', 'per') 12
# ('ap', 'meissner') 12
# ('meissner', 'associ') 12
# ('meissner', 'press') 12
# ('climat', 'ap') 12
# ('recent', 'climat') 12
# ('manag', 'chang') 12
# ('investor', 'chang') 12
# ('climat', 'help') 12
# ('chang', 'per') 12
# ('chang', 'litig') 12
# ('per', 'chang') 12
# ('cent', 'chang') 12
# ('forest', 'divis') 12
# ('state', 'forest') 12
# ('former', 'mayor') 11
# ('develop', 'chang') 11
# ('said', 'carbon') 11
# ('said', 'world') 11
# ('reduc', 'carbon') 11
# ('fund', 'chang') 11
# ('said', 'new') 11
# ('climat', 'invest') 11
# ('presid', 'said') 11
# ('chang', 'challeng') 11
# ('climat', 'problem') 11
# ('chang', 'problem') 11
# ('serious', 'climat') 11
# ('percent', 'climat') 11
# ('chang', 'go') 11
# ('trump', 'withdraw') 11
# ('mani', 'peopl') 11
# ('cost', 'climat') 11
# ('climat', 'summit') 11
# ('world', 'pari') 11
# ('panel', 'chang') 11
# ('carbon', 'climat') 11
# ('emiss', 'target') 11
# ('invest', 'energi') 11
# ('current', 'climat') 11
# ('global', 'challeng') 11
# ('countri', 'also') 11
# ('scott', 'pruitt') 11
# ('intern', 'chang') 11
# ('countri', 'world') 11
# ('toward', 'chang') 11
# ('renew', 'climat') 11
# ('chang', 'futur') 11
# ('increas', 'risk') 11
# ('drought', 'climat') 11
# ('think', 'chang') 11
# ('climat', 'event') 11
# ('invest', 'climat') 11
# ('confer', 'chang') 11
# ('year', 'year') 11
# ('fuel', 'climat') 11
# ('talk', 'climat') 11
# ('last', 'climat') 11
# ('chang', 'come') 11
# ('warm', 'chang') 11
# ('believ', 'chang') 11
# ('major', 'chang') 11
# ('chang', 'set') 11
# ('achiev', 'climat') 11
# ('includ', 'chang') 11
# ('countri', 'agreement') 11
# ('climat', 'import') 11
# ('action', 'state') 11
# ('new', 'nation') 11
# ('year', 'record') 11
# ('level', 'rise') 11
# ('energi', 'solar') 11
# ('industri', 'chang') 11
# ('mani', 'countri') 11
# ('new', 'industri') 11
# ('last', 'week') 11
# ('first', 'chang') 11
# ('climat', 'group') 11
# ('renew', 'sourc') 11
# ('veri', 'said') 11
# ('said', 'china') 11
# ('assess', 'climat') 11
# ('chang', 'vulner') 11
# ('agricultur', 'climat') 11
# ('chang', 'pose') 11
# ('call', 'chang') 11
# ('strategi', 'climat') 11
# ('reduc', 'climat') 11
# ('global', 'countri') 11
# ('pledg', 'climat') 11
# ('pari', 'pact') 11
# ('whether', 'chang') 11
# ('week', 'climat') 11
# ('million', 'chang') 11
# ('pull', 'agreement') 11
# ('climat', 'major') 11
# ('us', 'us') 11
# ('climat', 'administr') 11
# ('chang', 'administr') 11
# ('climat', 'activ') 11
# ('energi', 'technolog') 11
# ('emiss', 'chang') 11
# ('climat', 'implement') 11
# ('chang', 'commit') 11
# ('unit', 'framework') 11
# ('climat', 'relat') 11
# ('said', 'countri') 11
# ('prepar', 'chang') 11
# ('nation', 'develop') 11
# ('set', 'chang') 11
# ('way', 'climat') 11
# ('chang', 'initi') 11
# ('pruitt', 'said') 11
# ('attorney', 'general') 11
# ('climat', 'veri') 11
# ('associ', 'presid') 11
# ('press', 'presid') 11
# ('fiji', 'germani') 11
# ('fiji', 'saturday') 11
# ('un', 'saturday') 11
# ('chang', 'saturday') 11
# ('america', 'climat') 11
# ('work', 'state') 11
# ('climat', 'local') 11
# ('chang', 'ap') 11
# ('new', 'hampshir') 11
# ('depart', 'depart') 11
# ('compani', 'chang') 11
# ('due', 'chang') 11
# ('green', 'fund') 11
# ('risk', 'say') 11
# ('climat', 'litig') 11
# ('counti', 'chang') 11
# ('pari', 'rule') 11
# ('forest', 'depart') 11
# ('climat', 'forest') 11
# ('forest', 'plan') 11
# ('global', 'mani') 10
# ('busi', 'busi') 10
# ('get', 'said') 10
# ('percent', 'world') 10
# ('problem', 'climat') 10
# ('climat', 'becaus') 10
# ('climat', 'financ') 10
# ('execut', 'said') 10
# ('chang', 'execut') 10
# ('global', 'economi') 10
# ('also', 'said') 10
# ('chief', 'offic') 10
# ('chang', 'face') 10
# ('govern', 'polici') 10
# ('serious', 'chang') 10
# ('agreement', 'nation') 10
# ('climat', 'might') 10
# ('year', 'global') 10
# ('global', 'would') 10
# ('disast', 'chang') 10
# ('two', 'year') 10
# ('us', 'withdraw') 10
# ('us', 'accord') 10
# ('cost', 'chang') 10
# ('pari', 'trump') 10
# ('chang', 'un') 10
# ('accord', 'global') 10
# ('emiss', 'global') 10
# ('keep', 'rise') 10
# ('polici', 'energi') 10
# ('climat', 'damag') 10
# ('climat', 'make') 10
# ('climat', 'much') 10
# ('keep', 'global') 10
# ('time', 'chang') 10
# ('fuel', 'energi') 10
# ('energi', 'polici') 10
# ('pari', 'countri') 10
# ('climat', 'fiji') 10
# ('climat', 'due') 10
# ('chang', 'due') 10
# ('chang', 'sever') 10
# ('chang', 'drought') 10
# ('chang', 'like') 10
# ('scienc', 'chang') 10
# ('dure', 'confer') 10
# ('futur', 'chang') 10
# ('fund', 'help') 10
# ('need', 'said') 10
# ('privat', 'sector') 10
# ('energi', 'global') 10
# ('see', 'chang') 10
# ('govern', 'said') 10
# ('step', 'climat') 10
# ('fossil', 'climat') 10
# ('fuel', 'chang') 10
# ('climat', 'last') 10
# ('global', 'level') 10
# ('also', 'increas') 10
# ('energi', 'power') 10
# ('said', 'develop') 10
# ('thing', 'climat') 10
# ('scientist', 'said') 10
# ('temperatur', 'celsius') 10
# ('world', 'us') 10
# ('said', 'warm') 10
# ('chang', 'show') 10
# ('economi', 'chang') 10
# ('climat', 'becom') 10
# ('chang', 'still') 10
# ('countri', 'emiss') 10
# ('pari', 'deal') 10
# ('state', 'develop') 10
# ('chang', 'time') 10
# ('pari', 'nation') 10
# ('energi', 'use') 10
# ('climat', 'must') 10
# ('put', 'climat') 10
# ('use', 'climat') 10
# ('work', 'year') 10
# ('chang', 'veri') 10
# ('human', 'chang') 10
# ('alreadi', 'chang') 10
# ('accord', 'report') 10
# ('assess', 'chang') 10
# ('chang', 'econom') 10
# ('frequent', 'extrem') 10
# ('event', 'climat') 10
# ('climat', 'pose') 10
# ('food', 'product') 10
# ('climat', 'counti') 10
# ('come', 'chang') 10
# ('climat', 'econom') 10
# ('product', 'climat') 10
# ('technolog', 'climat') 10
# ('climat', 'director') 10
# ('climat', 'negoti') 10
# ('chang', 'use') 10
# ('unit', 'pari') 10
# ('china', 'carbon') 10
# ('state', 'energi') 10
# ('cooper', 'chang') 10
# ('withdraw', 'agreement') 10
# ('pari', 'said') 10
# ('climat', 'agenda') 10
# ('univers', 'said') 10
# ('contribut', 'chang') 10
# ('said', 'make') 10
# ('may', 'chang') 10
# ('extrem', 'chang') 10
# ('chang', 'activ') 10
# ('climat', 'dure') 10
# ('climat', 'leader') 10
# ('chang', 'leader') 10
# ('secur', 'climat') 10
# ('global', 'effort') 10
# ('solar', 'power') 10
# ('climat', 'donald') 10
# ('chang', 'donald') 10
# ('donald', 'pull') 10
# ('climat', 'creat') 10
# ('bonn', 'confer') 10
# ('chang', 'sign') 10
# ('africa', 'climat') 10
# ('nation', 'convent') 10
# ('climat', 'chief') 10
# ('face', 'chang') 10
# ('pull', 'climat') 10
# ('temperatur', 'increas') 10
# ('temperatur', 'degre') 10
# ('secur', 'threat') 10
# ('campaign', 'climat') 10
# ('chang', 'scienc') 10
# ('chang', 'import') 10
# ('state', 'busi') 10
# ('climat', 'set') 10
# ('chang', 'found') 10
# ('bonn', 'ap') 10
# ('germani', 'ap') 10
# ('america', 'pledg') 10
# ('bear', 'climat') 10
# ('saturday', 'ap') 10
# ('ap', 'presid') 10
# ('climat', 'center') 10
# ('action', 'cop') 10
# ('minist', 'climat') 10
# ('said', 'polici') 10
# ('said', 'plan') 10
# ('plan', 'state') 10
# ('produc', 'climat') 10
# ('climat', 'financi') 10
# ('risk', 'busi') 10
# ('work', 'forest') 10
# ('natur', 'chang') 10
# ('risk', 'australian') 10
# ('climat', 'disclosur') 10
# ('disclos', 'risk') 10
# ('disclos', 'climat') 10
# ('conserv', 'climat') 10
# ('forest', 'work') 10
# ('increas', 'temperatur') 10
# ('climat', 'cell') 10
# ('chang', 'cell') 10
# ('global', 'busi') 9
# ('world', 'bank') 9
# ('would', 'world') 9
# ('main', 'climat') 9
# ('becaus', 'climat') 9
# ('administr', 'said') 9
# ('former', 'presid') 9
# ('need', 'global') 9
# ('intern', 'global') 9
# ('intern', 'trade') 9
# ('action', 'scale') 9
# ('negoti', 'climat') 9
# ('climat', 'potenti') 9
# ('climat', 'investor') 9
# ('would', 'global') 9
# ('develop', 'goal') 9
# ('reduc', 'gas') 9
# ('global', 'percent') 9
# ('climat', 'go') 9
# ('econom', 'develop') 9
# ('two', 'climat') 9
# ('presid', 'accord') 9
# ('climat', 'even') 9
# ('intergovernment', 'panel') 9
# ('intergovernment', 'climat') 9
# ('contribut', 'drought') 9
# ('drought', 'drought') 9
# ('emiss', 'pari') 9
# ('emiss', 'reduct') 9
# ('climat', 'cent') 9
# ('generat', 'climat') 9
# ('climat', 'despit') 9
# ('consensus', 'climat') 9
# ('energi', 'develop') 9
# ('shift', 'energi') 9
# ('sourc', 'climat') 9
# ('global', 'peopl') 9
# ('global', 'nation') 9
# ('donald', 'us') 9
# ('year', 'us') 9
# ('year', 'accord') 9
# ('world', 'trump') 9
# ('environment', 'agenc') 9
# ('protect', 'agenc') 9
# ('energi', 'sector') 9
# ('research', 'us') 9
# ('fund', 'us') 9
# ('bank', 'england') 9
# ('climat', 'debat') 9
# ('conflict', 'conflict') 9
# ('becom', 'climat') 9
# ('increas', 'drought') 9
# ('drought', 'chang') 9
# ('increas', 'peopl') 9
# ('risk', 'countri') 9
# ('world', 'includ') 9
# ('global', 'world') 9
# ('water', 'climat') 9
# ('water', 'also') 9
# ('consequ', 'climat') 9
# ('chang', 'make') 9
# ('busi', 'risk') 9
# ('fund', 'manag') 9
# ('climat', 'grow') 9
# ('energi', 'sourc') 9
# ('countri', 'nation') 9
# ('climat', 'press') 9
# ('five', 'year') 9
# ('said', 'alreadi') 9
# ('step', 'chang') 9
# ('donald', 'chang') 9
# ('us', 'year') 9
# ('year', 'trump') 9
# ('last', 'chang') 9
# ('global', 'human') 9
# ('onli', 'climat') 9
# ('environment', 'polici') 9
# ('sustain', 'chang') 9
# ('climat', 'announc') 9
# ('chang', 'announc') 9
# ('nation', 'contribut') 9
# ('among', 'climat') 9
# ('econom', 'said') 9
# ('climat', 'call') 9
# ('year', 'increas') 9
# ('year', 'ago') 9
# ('temperatur', 'c') 9
# ('sea', 'rise') 9
# ('fossil', 'energi') 9
# ('energi', 'wind') 9
# ('wind', 'solar') 9
# ('support', 'chang') 9
# ('climat', 'fuel') 9
# ('busi', 'economi') 9
# ('chang', 'live') 9
# ('environment', 'issu') 9
# ('rich', 'countri') 9
# ('director', 'univers') 9
# ('year', 'nation') 9
# ('temperatur', 'level') 9
# ('take', 'step') 9
# ('said', 'work') 9
# ('base', 'chang') 9
# ('low', 'carbon') 9
# ('climat', 'across') 9
# ('environment', 'said') 9
# ('said', 'presid') 9
# ('east', 'africa') 9
# ('chang', 'much') 9
# ('also', 'state') 9
# ('alreadi', 'climat') 9
# ('accord', 'nation') 9
# ('temperatur', 'climat') 9
# ('temperatur', 'chang') 9
# ('chang', 'sea') 9
# ('agricultur', 'chang') 9
# ('climat', 'product') 9
# ('event', 'chang') 9
# ('world', 'largest') 9
# ('research', 'univers') 9
# ('china', 'take') 9
# ('climat', 'bank') 9
# ('leadership', 'climat') 9
# ('climat', 'use') 9
# ('group', 'climat') 9
# ('withdraw', 'climat') 9
# ('new', 'energi') 9
# ('climat', 'execut') 9
# ('chang', 'director') 9
# ('execut', 'director') 9
# ('chang', 'agenda') 9
# ('hurrican', 'harvey') 9
# ('said', 'research') 9
# ('global', 'research') 9
# ('activ', 'chang') 9
# ('climat', 'data') 9
# ('energi', 'say') 9
# ('billion', 'climat') 9
# ('obama', 'administr') 9
# ('trump', 'would') 9
# ('pruitt', 'epa') 9
# ('activ', 'climat') 9
# ('much', 'chang') 9
# ('climat', 'effort') 9
# ('govern', 'nation') 9
# ('global', 'risk') 9
# ('chang', 'implement') 9
# ('research', 'institut') 9
# ('presid', 'pull') 9
# ('mitig', 'adapt') 9
# ('chang', 'creat') 9
# ('trump', 'decis') 9
# ('us', 'govern') 9
# ('rule', 'book') 9
# ('import', 'chang') 9
# ('develop', 'nation') 9
# ('next', 'year') 9
# ('unit', 'convent') 9
# ('climat', 'communiti') 9
# ('chang', 'communiti') 9
# ('low', 'develop') 9
# ('polici', 'plan') 9
# ('research', 'said') 9
# ('nation', 'trump') 9
# ('action', 'across') 9
# ('africa', 'chang') 9
# ('risk', 'report') 9
# ('see', 'climat') 9
# ('global', 'degre') 9
# ('climat', 'howev') 9
# ('new', 'secur') 9
# ('new', 'strategi') 9
# ('secur', 'strategi') 9
# ('administr', 'chang') 9
# ('emiss', 'develop') 9
# ('global', 'carbon') 9
# ('emiss', 'power') 9
# ('press', 'trump') 9
# ('creat', 'climat') 9
# ('trump', 'say') 9
# ('gas', 'climat') 9
# ('said', 'impact') 9
# ('chang', 'big') 9
# ('say', 'peopl') 9
# ('climat', 'show') 9
# ('chang', 'flood') 9
# ('chang', 'place') 9
# ('citi', 'busi') 9
# ('prepar', 'climat') 9
# ('climat', 'good') 9
# ('chang', 'good') 9
# ('bonn', 'associ') 9
# ('germani', 'associ') 9
# ('germani', 'press') 9
# ('saturday', 'associ') 9
# ('saturday', 'press') 9
# ('near', 'climat') 9
# ('pull', 'accord') 9
# ('action', 'center') 9
# ('action', 'fiji') 9
# ('center', 'cop') 9
# ('center', 'fiji') 9
# ('center', 'un') 9
# ('work', 'action') 9
# ('polici', 'state') 9
# ('climat', 'associ') 9
# ('trump', 'plan') 9
# ('new', 'impact') 9
# ('hampshir', 'climat') 9
# ('mapl', 'syrup') 9
# ('tap', 'tree') 9
# ('mapl', 'tree') 9
# ('climat', 'institut') 9
# ('relat', 'climat') 9
# ('relat', 'chang') 9
# ('climat', 'uk') 9
# ('director', 'chang') 9
# ('sector', 'climat') 9
# ('way', 'chang') 9
# ('may', 'climat') 9
# ('scientist', 'research') 9
# ('climat', 'mitig') 9
# ('conserv', 'chang') 9
# ('climat', 'mr') 9
# ('chang', 'mr') 9
# ('respond', 'climat') 9
# ('risk', 'financi') 9
# ('risk', 'disclos') 9
# ('chang', 'million') 9
# ('climat', 'million') 9
# ('climat', 'africa') 9
# ('fund', 'world') 8
# ('emiss', 'also') 8
# ('carbon', 'year') 8
# ('climat', 'main') 8
# ('chang', 'main') 8
# ('problem', 'chang') 8
# ('climat', 'great') 8
# ('chang', 'great') 8
# ('plan', 'year') 8
# ('address', 'global') 8
# ('execut', 'chang') 8
# ('trade', 'trade') 8
# ('world', 'agreement') 8
# ('offic', 'said') 8
# ('global', 'action') 8
# ('global', 'agreement') 8
# ('chang', 'potenti') 8
# ('also', 'energi') 8
# ('good', 'chang') 8
# ('climat', 'trade') 8
# ('climat', 'result') 8
# ('parti', 'climat') 8
# ('climat', 'law') 8
# ('climat', 'billion') 8
# ('reduc', 'greenhous') 8
# ('global', 'emiss') 8
# ('year', 'pari') 8
# ('good', 'one') 8
# ('withdraw', 'accord') 8
# ('stop', 'climat') 8
# ('stop', 'chang') 8
# ('chang', 'even') 8
# ('summit', 'pari') 8
# ('pari', 'world') 8
# ('scienc', 'us') 8
# ('intergovernment', 'chang') 8
# ('warm', 'global') 8
# ('pari', 'year') 8
# ('would', 'temperatur') 8
# ('would', 'rise') 8
# ('ask', 'climat') 8
# ('green', 'develop') 8
# ('next', 'climat') 8
# ('climat', 'instead') 8
# ('energi', 'also') 8
# ('director', 'center') 8
# ('climat', 'measur') 8
# ('ani', 'chang') 8
# ('flood', 'drought') 8
# ('pruitt', 'climat') 8
# ('climat', 'head') 8
# ('energi', 'busi') 8
# ('energi', 'trump') 8
# ('former', 'new') 8
# ('former', 'york') 8
# ('new', 'mayor') 8
# ('chang', 'might') 8
# ('china', 'us') 8
# ('us', 'would') 8
# ('disclosur', 'tcfd') 8
# ('invest', 'bank') 8
# ('invest', 'fund') 8
# ('big', 'climat') 8
# ('toward', 'energi') 8
# ('busi', 'energi') 8
# ('conflict', 'climat') 8
# ('conflict', 'chang') 8
# ('climat', 'greenhous') 8
# ('climat', 'gas') 8
# ('chang', 'gas') 8
# ('chang', 'degre') 8
# ('climat', 'sever') 8
# ('role', 'climat') 8
# ('role', 'chang') 8
# ('author', 'climat') 8
# ('intern', 'communiti') 8
# ('climat', 'way') 8
# ('contribut', 'global') 8
# ('fund', 'invest') 8
# ('invest', 'chang') 8
# ('initi', 'climat') 8
# ('develop', 'also') 8
# ('chang', 'press') 8
# ('economi', 'press') 8
# ('world', 'said') 8
# ('saudi', 'arabia') 8
# ('global', 'year') 8
# ('said', 'meet') 8
# ('onli', 'also') 8
# ('first', 'presid') 8
# ('say', 'risk') 8
# ('said', 'becaus') 8
# ('say', 'compani') 8
# ('develop', 'environ') 8
# ('say', 'us') 8
# ('countri', 'us') 8
# ('recent', 'year') 8
# ('skeptic', 'climat') 8
# ('skeptic', 'chang') 8
# ('peopl', 'said') 8
# ('made', 'climat') 8
# ('environment', 'sustain') 8
# ('scientist', 'chang') 8
# ('scientist', 'univers') 8
# ('carbon', 'global') 8
# ('effect', 'global') 8
# ('achiev', 'goal') 8
# ('state', 'nation') 8
# ('nation', 'govern') 8
# ('lead', 'chang') 8
# ('chang', 'concern') 8
# ('chang', 'manag') 8
# ('bonn', 'meet') 8
# ('concern', 'chang') 8
# ('take', 'global') 8
# ('averag', 'temperatur') 8
# ('carbon', 'atmospher') 8
# ('gase', 'atmospher') 8
# ('said', 'like') 8
# ('million', 'million') 8
# ('climat', 'although') 8
# ('climat', 'expert') 8
# ('chang', 'although') 8
# ('climat', 'fossil') 8
# ('sinc', 'climat') 8
# ('climat', 'case') 8
# ('live', 'climat') 8
# ('look', 'chang') 8
# ('chang', 'cost') 8
# ('energi', 'new') 8
# ('pari', 'treati') 8
# ('risk', 'warm') 8
# ('new', 'global') 8
# ('new', 'develop') 8
# ('say', 'global') 8
# ('climat', 'initi') 8
# ('keep', 'chang') 8
# ('climat', 'renew') 8
# ('chang', 'renew') 8
# ('head', 'climat') 8
# ('climat', 'see') 8
# ('creat', 'chang') 8
# ('around', 'chang') 8
# ('chang', 'across') 8
# ('project', 'said') 8
# ('said', 'environment') 8
# ('chang', 'assess') 8
# ('chang', 'signific') 8
# ('agricultur', 'product') 8
# ('crop', 'climat') 8
# ('food', 'secur') 8
# ('strategi', 'chang') 8
# ('chang', 'region') 8
# ('crop', 'chang') 8
# ('loss', 'climat') 8
# ('chang', 'counti') 8
# ('chang', 'negoti') 8
# ('unit', 'said') 8
# ('climat', 'clean') 8
# ('energi', 'emiss') 8
# ('pari', 'china') 8
# ('carbon', 'said') 8
# ('china', 'daili') 8
# ('carbon', 'carbon') 8
# ('said', 'expect') 8
# ('polici', 'global') 8
# ('environ', 'state') 8
# ('accord', 'trump') 8
# ('trump', 'warm') 8
# ('us', 'clean') 8
# ('agreement', 'said') 8
# ('former', 'climat') 8
# ('fight', 'global') 8
# ('chang', 'offici') 8
# ('execut', 'climat') 8
# ('warm', 'research') 8
# ('impact', 'global') 8
# ('debat', 'climat') 8
# ('climat', 'denier') 8
# ('data', 'climat') 8
# ('chang', 'major') 8
# ('secur', 'trump') 8
# ('announc', 'withdraw') 8
# ('announc', 'pari') 8
# ('execut', 'order') 8
# ('clean', 'power') 8
# ('chang', 'meet') 8
# ('chang', 'dure') 8
# ('climat', 'cooper') 8
# ('chang', 'cooper') 8
# ('cooper', 'us') 8
# ('trump', 'new') 8
# ('commit', 'agreement') 8
# ('big', 'compani') 8
# ('sinc', 'chang') 8
# ('energi', 'generat') 8
# ('peopl', 'peopl') 8
# ('climat', 'agre') 8
# ('chang', 'agre') 8
# ('action', 'un') 8
# ('said', 'water') 8
# ('chang', 'despit') 8
# ('decis', 'pari') 8
# ('director', 'said') 8
# ('rest', 'world') 8
# ('emiss', 'countri') 8
# ('shift', 'toward') 8
# ('climat', 'next') 8
# ('clear', 'climat') 8
# ('devast', 'climat') 8
# ('energi', 'shift') 8
# ('climat', 'survey') 8
# ('back', 'climat') 8
# ('climat', 'lead') 8
# ('per', 'year') 8
# ('offici', 'depart') 8
# ('rise', 'degre') 8
# ('seek', 'climat') 8
# ('climat', 'place') 8
# ('factor', 'climat') 8
# ('nation', 'energi') 8
# ('secur', 'nation') 8
# ('emiss', 'plant') 8
# ('regul', 'chang') 8
# ('economi', 'associ') 8
# ('climat', 'crisi') 8
# ('climat', 'model') 8
# ('find', 'chang') 8
# ('climat', 'cut') 8
# ('climat', 'life') 8
# ('look', 'like') 8
# ('increas', 'increas') 8
# ('bloomberg', 'climat') 8
# ('pledg', 'state') 8
# ('polar', 'climat') 8
# ('protest', 'climat') 8
# ('climat', 'western') 8
# ('ap', 'donald') 8
# ('press', 'donald') 8
# ('file', 'photo') 8
# ('america', 'campaign') 8
# ('pledg', 'campaign') 8
# ('campaign', 'state') 8
# ('action', 'citi') 8
# ('state', 'local') 8
# ('across', 'entir') 8
# ('prime', 'climat') 8
# ('depart', 'said') 8
# ('new', 'ap') 8
# ('need', 'studi') 8
# ('chang', 'see') 8
# ('chang', 'minist') 8
# ('produc', 'chang') 8
# ('chang', 'becom') 8
# ('hampshir', 'chang') 8
# ('parker', 'mapl') 8
# ('carbon', 'warm') 8
# ('warm', 'said') 8
# ('nation', 'environ') 8
# ('risk', 'includ') 8
# ('chang', 'parti') 8
# ('research', 'scientist') 8
# ('climat', 'britain') 8
# ('prof', 'director') 8
# ('climat', 'time') 8
# ('differ', 'climat') 8
# ('appli', 'climat') 8
# ('chang', 'mitig') 8
# ('year', 'drought') 8
# ('climat', 'provid') 8
# ('chang', 'africa') 8
# ('risk', 'carbon') 8
# ('corpor', 'climat') 8
# ('defenc', 'chang') 8
# ('risk', 'disclosur') 8
# ('australian', 'climat') 8
# ('regul', 'risk') 8
# ('compani', 'investor') 8
# ('extrem', 'per') 8
# ('chang', 'cent') 8
# ('compani', 'manag') 8
# ('prepar', 'action') 8
# ('chang', 'help') 8
# ('chang', 'kenya') 8
# ('money', 'doe') 8
# ('plan', 'plan') 8
# ('wing', 'state') 8
# ('depart', 'told') 8
# ('new', 'bloomberg') 7
# ('york', 'bloomberg') 7
# ('chang', 'bloomberg') 7
# ('polit', 'leader') 7
# ('chang', 'citi') 7
# ('carbon', 'world') 7
# ('carbon', 'would') 7
# ('emiss', 'would') 7
# ('citi', 'citi') 7
# ('world', 'need') 7
# ('citi', 'climat') 7
# ('access', 'climat') 7
# ('chang', 'current') 7
# ('said', 'administr') 7
# ('hope', 'climat') 7
# ('global', 'trump') 7
# ('former', 'said') 7
# ('bill', 'said') 7
# ('said', 'peopl') 7
# ('said', 'recent') 7
# ('recent', 'chang') 7
# ('agreement', 'world') 7
# ('agreement', 'agreement') 7
# ('group', 'said') 7
# ('asset', 'manag') 7
# ('global', 'call') 7
# ('polici', 'need') 7
# ('world', 'new') 7
# ('take', 'place') 7
# ('place', 'climat') 7
# ('place', 'chang') 7
# ('univers', 'chang') 7
# ('agreement', 'parti') 7
# ('start', 'climat') 7
# ('germani', 'america') 7
# ('busi', 'invest') 7
# ('would', 'need') 7
# ('benefit', 'climat') 7
# ('billion', 'year') 7
# ('sustain', 'goal') 7
# ('reduc', 'global') 7
# ('law', 'climat') 7
# ('law', 'chang') 7
# ('one', 'planet') 7
# ('donald', 'accord') 7
# ('need', 'impact') 7
# ('pari', 'administr') 7
# ('trump', 'world') 7
# ('drought', 'syria') 7
# ('sinc', 'global') 7
# ('becaus', 'chang') 7
# ('sinc', 'pari') 7
# ('would', 'warm') 7
# ('cost', 'billion') 7
# ('polici', 'us') 7
# ('come', 'pari') 7
# ('top', 'climat') 7
# ('polici', 'research') 7
# ('carbon', 'cut') 7
# ('climat', 'poor') 7
# ('climat', 'everi') 7
# ('climat', 'solut') 7
# ('climat', 'far') 7
# ('climat', 'keep') 7
# ('global', 'well') 7
# ('nation', 'presid') 7
# ('becaus', 'countri') 7
# ('world', 'countri') 7
# ('climat', 'agenc') 7
# ('chang', 'head') 7
# ('energi', 'invest') 7
# ('institut', 'us') 7
# ('us', 'polici') 7
# ('develop', 'china') 7
# ('climat', 'held') 7
# ('former', 'michael') 7
# ('york', 'mayor') 7
# ('mayor', 'michael') 7
# ('mayor', 'bloomberg') 7
# ('jerri', 'brown') 7
# ('pension', 'fund') 7
# ('govern', 'energi') 7
# ('big', 'energi') 7
# ('chang', 'debat') 7
# ('us', 'busi') 7
# ('countri', 'energi') 7
# ('drought', 'increas') 7
# ('chang', 'greenhous') 7
# ('argu', 'climat') 7
# ('climat', 'drought') 7
# ('like', 'increas') 7
# ('risk', 'increas') 7
# ('said', 'area') 7
# ('domest', 'product') 7
# ('world', 'food') 7
# ('climat', 'water') 7
# ('consequ', 'chang') 7
# ('far', 'chang') 7
# ('understand', 'chang') 7
# ('chang', 'grow') 7
# ('initi', 'chang') 7
# ('confer', 'said') 7
# ('chang', 'decis') 7
# ('need', 'energi') 7
# ('also', 'countri') 7
# ('climat', 'address') 7
# ('chang', 'address') 7
# ('said', 'public') 7
# ('chang', 'thing') 7
# ('nation', 'state') 7
# ('state', 'actor') 7
# ('presid', 'secur') 7
# ('energi', 'could') 7
# ('global', 'presid') 7
# ('citi', 'state') 7
# ('nation', 'first') 7
# ('go', 'said') 7
# ('said', 'ad') 7
# ('year', 'countri') 7
# ('former', 'us') 7
# ('environ', 'us') 7
# ('develop', 'said') 7
# ('still', 'climat') 7
# ('said', 'issu') 7
# ('climat', 'ani') 7
# ('commit', 'global') 7
# ('climat', 'america') 7
# ('said', 'govern') 7
# ('us', 'carbon') 7
# ('develop', 'provid') 7
# ('chang', 'achiev') 7
# ('manag', 'busi') 7
# ('busi', 'develop') 7
# ('goal', 'climat') 7
# ('goal', 'chang') 7
# ('countri', 'develop') 7
# ('chang', 'support') 7
# ('result', 'climat') 7
# ('said', 'also') 7
# ('one', 'state') 7
# ('us', 'new') 7
# ('climat', 'high') 7
# ('chang', 'high') 7
# ('said', 'year') 7
# ('global', 'report') 7
# ('burn', 'fossil') 7
# ('burn', 'fuel') 7
# ('dioxid', 'warm') 7
# ('climat', 'gase') 7
# ('record', 'year') 7
# ('c', 'temperatur') 7
# ('rainfal', 'drought') 7
# ('reduc', 'energi') 7
# ('colleg', 'economi') 7
# ('problem', 'countri') 7
# ('chang', 'expert') 7
# ('climat', 'brought') 7
# ('chang', 'start') 7
# ('chang', 'fuel') 7
# ('chang', 'case') 7
# ('know', 'busi') 7
# ('countri', 'reduc') 7
# ('countri', 'carbon') 7
# ('ani', 'one') 7
# ('intern', 'energi') 7
# ('energi', 'agenc') 7
# ('energi', 'job') 7
# ('work', 'work') 7
# ('new', 'new') 7
# ('one', 'world') 7
# ('increas', 'effect') 7
# ('could', 'chang') 7
# ('risk', 'global') 7
# ('risk', 'mani') 7
# ('issu', 'global') 7
# ('address', 'challeng') 7
# ('global', 'develop') 7
# ('risk', 'could') 7
# ('provid', 'develop') 7
# ('effort', 'global') 7
# ('scientist', 'say') 7
# ('say', 'warm') 7
# ('renew', 'electr') 7
# ('meet', 'global') 7
# ('increas', 'energi') 7
# ('reduc', 'consumpt') 7
# ('keep', 'climat') 7
# ('chang', 'must') 7
# ('take', 'first') 7
# ('environment', 'conserv') 7
# ('research', 'research') 7
# ('environment', 'project') 7
# ('put', 'chang') 7
# ('climat', 'build') 7
# ('futur', 'generat') 7
# ('world', 'nation') 7
# ('support', 'busi') 7
# ('busi', 'econom') 7
# ('china', 'develop') 7
# ('would', 'would') 7
# ('right', 'climat') 7
# ('climat', 'past') 7
# ('sea', 'chang') 7
# ('climat', 'assess') 7
# ('nation', 'china') 7
# ('rise', 'c') 7
# ('chang', 'pattern') 7
# ('heat', 'wave') 7
# ('climat', 'signific') 7
# ('sensit', 'climat') 7
# ('product', 'crop') 7
# ('negat', 'impact') 7
# ('climat', 'believ') 7
# ('china', 'percent') 7
# ('climat', 'threaten') 7
# ('market', 'climat') 7
# ('climat', 'strategi') 7
# ('report', 'say') 7
# ('take', 'action') 7
# ('impact', 'come') 7
# ('climat', 'region') 7
# ('sever', 'climat') 7
# ('sever', 'chang') 7
# ('affect', 'climat') 7
# ('impact', 'product') 7
# ('impact', 'risk') 7
# ('adapt', 'mitig') 7
# ('chang', 'posit') 7
# ('accord', 'china') 7
# ('find', 'climat') 7
# ('chang', 'bank') 7
# ('china', 'role') 7
# ('countri', 'china') 7
# ('unit', 'china') 7
# ('nation', 'said') 7
# ('climat', 'promot') 7
# ('energi', 'china') 7
# ('china', 'emiss') 7
# ('emiss', 'per') 7
# ('pari', 'polici') 7
# ('associ', 'former') 7
# ('said', 'continu') 7
# ('continu', 'chang') 7
# ('chang', 'group') 7
# ('work', 'citi') 7
# ('expect', 'climat') 7
# ('chang', 'shift') 7
# ('said', 'agreement') 7
# ('said', 'week') 7
# ('week', 'chang') 7
# ('aim', 'global') 7
# ('global', 'accord') 7
# ('opportun', 'climat') 7
# ('chang', 'stop') 7
# ('natur', 'said') 7
# ('percent', 'chang') 7
# ('new', 'report') 7
# ('debat', 'chang') 7
# ('climat', 'pull') 7
# ('billion', 'chang') 7
# ('want', 'climat') 7
# ('power', 'power') 7
# ('scientist', 'us') 7
# ('lead', 'energi') 7
# ('well', 'climat') 7
# ('well', 'chang') 7
# ('posit', 'climat') 7
# ('posit', 'chang') 7
# ('roll', 'back') 7
# ('pari', 'commit') 7
# ('market', 'energi') 7
# ('larg', 'climat') 7
# ('agreement', 'pari') 7
# ('climat', 'american') 7
# ('china', 'commit') 7
# ('energi', 'countri') 7
# ('target', 'energi') 7
# ('risk', 'associ') 7
# ('associ', 'climat') 7
# ('associ', 'new') 7
# ('us', 'pull') 7
# ('presid', 'agreement') 7
# ('climat', 'end') 7
# ('angela', 'merkel') 7
# ('climat', 'clear') 7
# ('chang', 'clear') 7
# ('hope', 'us') 7
# ('natur', 'gas') 7
# ('among', 'chang') 7
# ('climat', 'four') 7
# ('negoti', 'chang') 7
# ('unit', 'develop') 7
# ('statement', 'climat') 7
# ('statement', 'chang') 7
# ('would', 'also') 7
# ('chang', 'relat') 7
# ('implement', 'pari') 7
# ('provid', 'climat') 7
# ('plan', 'environ') 7
# ('pari', 'pari') 7
# ('said', 'one') 7
# ('climat', 'parti') 7
# ('nation', 'us') 7
# ('mani', 'chang') 7
# ('chang', 'life') 7
# ('view', 'climat') 7
# ('parti', 'pari') 7
# ('wind', 'farm') 7
# ('climat', 'foundat') 7
# ('say', 'make') 7
# ('germani', 'climat') 7
# ('peopl', 'global') 7
# ('pull', 'us') 7
# ('would', 'futur') 7
# ('speak', 'nation') 7
# ('said', 'doe') 7
# ('said', 'major') 7
# ('brought', 'climat') 7
# ('commit', 'chang') 7
# ('chang', 'effort') 7
# ('plan', 'depart') 7
# ('offici', 'climat') 7
# ('degre', 'celsius') 7
# ('first', 'donald') 7
# ('describ', 'climat') 7
# ('program', 'climat') 7
# ('back', 'chang') 7
# ('regul', 'includ') 7
# ('presid', 'center') 7
# ('said', 'import') 7
# ('first', 'trump') 7
# ('protect', 'said') 7
# ('agenc', 'said') 7
# ('climat', 'hoax') 7
# ('chang', 'hoax') 7
# ('reduc', 'chang') 7
# ('would', 'say') 7
# ('power', 'climat') 7
# ('climat', 'epa') 7
# ('said', 'regul') 7
# ('public', 'health') 7
# ('campaign', 'work') 7
# ('regul', 'climat') 7
# ('busi', 'local') 7
# ('climat', 'scientif') 7
# ('climat', 'run') 7
# ('person', 'climat') 7
# ('say', 'impact') 7
# ('potenti', 'climat') 7
# ('per', 'caus') 7
# ('chang', 'water') 7
# ('warmer', 'temperatur') 7
# ('water', 'energi') 7
# ('even', 'climat') 7
# ('effort', 'curb') 7
# ('busi', 'global') 7
# ('report', 'said') 7
# ('chang', 'next') 7
# ('busi', 'group') 7
# ('said', 'could') 7
# ('bear', 'chang') 7
# ('associ', 'donald') 7
# ('associ', 'trump') 7
# ('ap', 'file') 7
# ('meet', 'confer') 7
# ('said', 'secur') 7
# ('speak', 'cop') 7
# ('speak', 'fiji') 7
# ('action', 'confer') 7
# ('center', 'chang') 7
# ('center', 'confer') 7
# ('center', 'bonn') 7
# ('climat', 'colleg') 7
# ('across', 'economi') 7
# ('bainimarama', 'climat') 7
# ('said', 'studi') 7
# ('realiti', 'climat') 7
# ('nation', 'new') 7
# ('secur', 'say') 7
# ('base', 'climat') 7
# ('would', 'state') 7
# ('said', 'scientist') 7
# ('said', 'want') 7
# ('climat', 'resourc') 7
# ('resourc', 'climat') 7
# ('climat', 'offici') 7
# ('plan', 'said') 7
# ('hampshir', 'impact') 7
# ('mapl', 'climat') 7
# ('mapl', 'chang') 7
# ('syrup', 'climat') 7
# ('syrup', 'chang') 7
# ('produc', 'new') 7
# ('chang', 'call') 7
# ('research', 'say') 7
# ('chang', 'institut') 7
# ('chang', 'centr') 7
# ('chang', 'uk') 7
# ('risk', 'bank') 7
# ('institut', 'climat') 7
# ('sector', 'chang') 7
# ('theresa', 'may') 7
# ('centr', 'research') 7
# ('senior', 'said') 7
# ('climat', 'budget') 7
# ('satellit', 'data') 7
# ('say', 'also') 7
# ('say', 'action') 7
# ('climat', 'sector') 7
# ('seek', 'chang') 7
# ('risk', 'becaus') 7
# ('depart', 'develop') 7
# ('project', 'energi') 7
# ('risk', 'polici') 7
# ('respond', 'chang') 7
# ('defenc', 'climat') 7
# ('australia', 'climat') 7
# ('increas', 'impact') 7
# ('chang', 'sector') 7
# ('chang', 'disclosur') 7
# ('chang', 'law') 7
# ('regul', 'financi') 7
# ('compani', 'exposur') 7
# ('mr', 'chappel') 7
# ('first', 'state') 7
# ('financi', 'market') 7
# ('market', 'risk') 7
# ('recommend', 'climat') 7
# ('organis', 'climat') 7
# ('confer', 'parti') 7
# ('implement', 'action') 7
# ('state', 'need') 7
# ('product', 'increas') 7
# ('develop', 'emiss') 7
# ('adapt', 'plan') 7
# ('nodal', 'climat') 7
# ('state', 'work') 7
# ('offic', 'depart') 7
# ('plan', 'divis') 7
# ('forest', 'state') 7
# ('conserv', 'forest') 7
# ('prepar', 'plan') 7
# ('climat', 'open') 6
# ('climat', 'bloomberg') 6
# ('global', 'new') 6
# ('busi', 'leader') 6
# ('take', 'account') 6
# ('market', 'said') 6
# ('fund', 'said') 6
# ('account', 'emiss') 6
# ('percent', 'would') 6
# ('year', 'fund') 6
# ('would', 'develop') 6
# ('develop', 'world') 6
# ('case', 'climat') 6
# ('get', 'chang') 6
# ('main', 'chang') 6
# ('administr', 'trump') 6
# ('complex', 'climat') 6
# ('trump', 'becaus') 6
# ('bank', 'invest') 6
# ('hope', 'chang') 6
# ('chang', 'invest') 6
# ('chang', 'later') 6
# ('invest', 'said') 6
# ('year', 'leader') 6
# ('includ', 'global') 6
# ('administr', 'presid') 6
# ('may', 'new') 6
# ('busi', 'need') 6
# ('leader', 'chang') 6
# ('threat', 'peopl') 6
# ('manag', 'director') 6
# ('director', 'intern') 6
# ('fund', 'also') 6
# ('also', 'global') 6
# ('sign', 'agreement') 6
# ('trade', 'world') 6
# ('growth', 'said') 6
# ('execut', 'offic') 6
# ('said', 'invest') 6
# ('invest', 'asset') 6
# ('world', 'world') 6
# ('copyright', 'climat') 6
# ('challeng', 'global') 6
# ('polici', 'environ') 6
# ('agreement', 'new') 6
# ('solar', 'panel') 6
# ('energi', 'system') 6
# ('govern', 'agreement') 6
# ('start', 'chang') 6
# ('chang', 'trade') 6
# ('investor', 'regul') 6
# ('parti', 'chang') 6
# ('climat', 'warn') 6
# ('chang', 'warn') 6
# ('past', 'decad') 6
# ('green', 'good') 6
# ('year', 'agreement') 6
# ('would', 'reduc') 6
# ('chang', 'univers') 6
# ('intern', 'develop') 6
# ('climat', 'month') 6
# ('emmanuel', 'macron') 6
# ('chang', 'wors') 6
# ('crop', 'yield') 6
# ('state', 'one') 6
# ('requir', 'climat') 6
# ('chang', 'month') 6
# ('chang', 'summit') 6
# ('climat', 'bodi') 6
# ('chang', 'ipcc') 6
# ('year', 'cost') 6
# ('cost', 'percent') 6
# ('warm', 'natur') 6
# ('carbon', 'increas') 6
# ('climat', 'green') 6
# ('increas', 'world') 6
# ('achiev', 'emiss') 6
# ('emiss', 'polici') 6
# ('us', 'whether') 6
# ('better', 'climat') 6
# ('climat', 'benefit') 6
# ('despit', 'pari') 6
# ('climat', 'respons') 6
# ('climat', 'conclud') 6
# ('polici', 'invest') 6
# ('energi', 'research') 6
# ('research', 'develop') 6
# ('price', 'energi') 6
# ('futur', 'energi') 6
# ('energi', 'fossil') 6
# ('energi', 'fuel') 6
# ('worst', 'climat') 6
# ('climat', 'sourc') 6
# ('planet', 'climat') 6
# ('end', 'centuri') 6
# ('trump', 'year') 6
# ('time', 'year') 6
# ('insur', 'compani') 6
# ('countri', 'sign') 6
# ('sign', 'climat') 6
# ('climat', 'skeptic') 6
# ('climat', 'protect') 6
# ('trump', 'energi') 6
# ('also', 'develop') 6
# ('us', 'one') 6
# ('technolog', 'energi') 6
# ('trump', 'make') 6
# ('trump', 'america') 6
# ('america', 'pari') 6
# ('un', 'framework') 6
# ('un', 'convent') 6
# ('provid', 'countri') 6
# ('one', 'countri') 6
# ('former', 'bloomberg') 6
# ('new', 'michael') 6
# ('york', 'michael') 6
# ('pari', 'becaus') 6
# ('accord', 'us') 6
# ('climat', 'indic') 6
# ('chang', 'indic') 6
# ('world', 'china') 6
# ('keep', 'go') 6
# ('back', 'pari') 6
# ('world', 'would') 6
# ('investor', 'manag') 6
# ('financi', 'disclosur') 6
# ('countri', 'like') 6
# ('bhp', 'billiton') 6
# ('us', 'futur') 6
# ('would', 'countri') 6
# ('sever', 'drought') 6
# ('drought', 'factor') 6
# ('increas', 'conflict') 6
# ('becom', 'chang') 6
# ('caus', 'drought') 6
# ('rather', 'chang') 6
# ('climat', 'degre') 6
# ('chang', 'conflict') 6
# ('countri', 'contribut') 6
# ('role', 'play') 6
# ('us', 'scienc') 6
# ('countri', 'intern') 6
# ('high', 'time') 6
# ('gross', 'domest') 6
# ('gross', 'product') 6
# ('far', 'climat') 6
# ('chang', 'understand') 6
# ('extrem', 'drought') 6
# ('leader', 'climat') 6
# ('head', 'said') 6
# ('said', 'decis') 6
# ('energi', 'would') 6
# ('energi', 'becom') 6
# ('year', 'one') 6
# ('discuss', 'new') 6
# ('climat', 'thing') 6
# ('climat', 'look') 6
# ('climat', 'better') 6
# ('chang', 'look') 6
# ('chang', 'better') 6
# ('energi', 'year') 6
# ('year', 'time') 6
# ('per', 'onli') 6
# ('could', 'said') 6
# ('electr', 'energi') 6
# ('say', 'nation') 6
# ('said', 'think') 6
# ('climat', 'panel') 6
# ('chang', 'panel') 6
# ('us', 'environment') 6
# ('develop', 'economi') 6
# ('year', 'like') 6
# ('still', 'chang') 6
# ('peopl', 'think') 6
# ('said', 'made') 6
# ('climat', 'revers') 6
# ('chang', 'revers') 6
# ('chang', 'ani') 6
# ('made', 'pari') 6
# ('climat', 'claim') 6
# ('chang', 'america') 6
# ('come', 'said') 6
# ('make', 'us') 6
# ('scientist', 'global') 6
# ('forum', 'climat') 6
# ('forum', 'chang') 6
# ('chang', 'far') 6
# ('human', 'human') 6
# ('make', 'decis') 6
# ('factor', 'chang') 6
# ('colleg', 'london') 6
# ('tell', 'us') 6
# ('new', 'state') 6
# ('also', 'econom') 6
# ('econom', 'carbon') 6
# ('global', 'effect') 6
# ('govern', 'sustain') 6
# ('peopl', 'also') 6
# ('say', 'first') 6
# ('onli', 'chang') 6
# ('lead', 'fight') 6
# ('achiev', 'chang') 6
# ('climat', 'manag') 6
# ('germani', 'meet') 6
# ('group', 'chang') 6
# ('polici', 'nation') 6
# ('nation', 'determin') 6
# ('nation', 'pari') 6
# ('determin', 'contribut') 6
# ('trade', 'said') 6
# ('trillion', 'trillion') 6
# ('said', 'role') 6
# ('develop', 'action') 6
# ('state', 'temperatur') 6
# ('year', 'new') 6
# ('chang', 'india') 6
# ('said', 'take') 6
# ('report', 'nation') 6
# ('surfac', 'temperatur') 6
# ('year', 'sinc') 6
# ('sinc', 'record') 6
# ('sinc', 'said') 6
# ('said', 'last') 6
# ('global', 'abov') 6
# ('temperatur', 'abov') 6
# ('warm', 'say') 6
# ('warm', 'human') 6
# ('influenc', 'climat') 6
# ('world', 'must') 6
# ('chang', 'centuri') 6
# ('prevent', 'climat') 6
# ('everi', 'countri') 6
# ('solut', 'problem') 6
# ('chang', 'fossil') 6
# ('make', 'live') 6
# ('chang', 'damag') 6
# ('capit', 'busi') 6
# ('sector', 'would') 6
# ('carbon', 'nation') 6
# ('growth', 'climat') 6
# ('live', 'live') 6
# ('grow', 'climat') 6
# ('environment', 'damag') 6
# ('say', 'america') 6
# ('environment', 'degrad') 6
# ('protect', 'environ') 6
# ('countri', 'countri') 6
# ('popul', 'percent') 6
# ('emiss', 'new') 6
# ...
# ('wast', 'water') 2
# ('water', 'host') 2
# ('water', 'direct') 2
# ('depart', 'rural') 2
# ('agricultur', 'urban') 2
# ('health', 'rural') 2
# ('health', 'urban') 2
# ('rural', 'environ') 2
# ('urban', 'environ') 2
# ('index', 'temperatur') 2
# ('index', 'aurangabad') 2
# ('minimum', 'degre') 2
# ('aurangabad', 'project') 2
# ('recommend', 'prioriti') 2
# ('step', 'depart') 2
# ('depart', 'prioriti') 2
# ('top', 'aurangabad') 2
# ('top', 'district') 2
# ('aurangabad', 'marathwada') 2
# ('district', 'maharashtra') 2
# ('high', 'index') 2
# ('marathwada', 'state') 2
# ('natur', 'crisi') 2
# ('decad', 'averag') 2
# ('region', 'averag') 2
# ('averag', 'polici') 2
# ('averag', 'state') 2
# ('polici', 'issu') 2
# ('statist', 'part') 2
# ('part', 'maharashtra') 2
# ('vidarbha', 'state') 2
# ('state', 'averag') 2
# ('state', 'rise') 2
# ('state', 'mention') 2
# ('mention', 'temperatur') 2
# ('temperatur', 'drop') 2
# ('temperatur', 'agricultur') 2
# ('would', 'agricultur') 2
# ('loss', 'properti') 2
# ('live', 'due') 2
# ('met', 'climat') 2
# ('statist', 'climat') 2
# ('statist', 'chang') 2
# ('project', 'part') 2
# ('consequ', 'part') 2
# ('part', 'mitig') 2
# ('part', 'polici') 2
# ('part', 'issu') 2
# ('part', 'centr') 2
# ('maharashtra', 'issu') 2
# ('state', 'centr') 2
# ('issu', 'plan') 2
# ('adapt', 'possibl') 2
# ('water', 'develop') 2
# ('develop', 'given') 2
# ('develop', 'measur') 2
# ('studi', 'nevertheless') 2
# ('studi', 'good') 2
# ('studi', 'shown') 2
# ('due', 'said') 2
# ('toward', 'issu') 2
# ('said', 'deem') 2
# ('deputi', 'cm') 2
# ('deputi', 'said') 2
# ('cm', 'said') 2
# ('modi', 'said') 2
# ('face', 'flood') 2
# ('financi', 'framework') 2
# ('framework', 'symposium') 2
# ('nation', 'symposium') 2
# ('symposium', 'chang') 2
# ('symposium', 'organis') 2
# ('symposium', 'centr') 2
# ('chang', 'tuesday') 2
# ('centr', 'develop') 2
# ('adri', 'climat') 2
# ('adri', 'chang') 2
# ('govern', 'provis') 2
# ('moder', 'lifestyl') 2
# ('impact', 'region') 2
# ('climat', 'bihar') 2
# ('chang', 'bihar') 2
# ('climat', 'yugratna') 2
# ('yugratna', 'youth') 2
# ('yugratna', 'repres') 2
# ('bonn', 'yugratna') 2
# ('germani', 'yugratna') 2
# ('repres', 'youth') 2
# ('summit', 'youth') 2
# ('youth', 'agreement') 2
# ('enhanc', 'capac') 2
# ('initi', 'yugratna') 2
# ('capac', 'yugratna') 2
# ('yugratna', 'becam') 2
# ('yugratna', 'youngest') 2
# ('yugratna', 'person') 2
# ('mani', 'unit') 2
# ('countri', 'treati') 2
# ('treati', 'framework') 2
# ('treati', 'convent') 2
# ('framework', 'intern') 2
# ('framework', 'combat') 2
# ('strengthen', 'respons') 2
# ('two', 'kyoto') 2
# ('two', 'protocol') 2
# ('year', 'protocol') 2
# ('later', 'kyoto') 2
# ('later', 'protocol') 2
# ('adopt', 'kyoto') 2
# ('adopt', 'protocol') 2
# ('kyoto', 'legal') 2
# ('kyoto', 'bind') 2
# ('protocol', 'legal') 2
# ('protocol', 'bind') 2
# ('protocol', 'parti') 2
# ('parti', 'convent') 2
# ('treati', 'parti') 2
# ('emiss', 'parti') 2
# ('reduct', 'parti') 2
# ('target', 'parti') 2
# ('parti', 'aim') 2
# ('aim', 'strengthen') 2
# ('agreement', 'strengthen') 2
# ('therefor', 'decis') 2
# ('take', 'decis') 2
# ('decis', 'previous') 2
# ('dehradun', 'govern') 2
# ('total', 'toward') 2
# ('total', 'chang') 2
# ('budget', 'toward') 2
# ('offici', 'wing') 2
# ('wing', 'implement') 2
# ('manoj', 'pant') 2
# ('manoj', 'chief') 2
# ('manoj', 'coordin') 2
# ('manoj', 'offic') 2
# ('manoj', 'state') 2
# ('manoj', 'plan') 2
# ('manoj', 'depart') 2
# ('pant', 'chief') 2
# ('pant', 'coordin') 2
# ('pant', 'offic') 2
# ('pant', 'state') 2
# ('pant', 'plan') 2
# ('pant', 'depart') 2
# ('pant', 'told') 2
# ('chief', 'coordin') 2
# ('chief', 'told') 2
# ('chief', 'toi') 2
# ('coordin', 'state') 2
# ('coordin', 'plan') 2
# ('coordin', 'depart') 2
# ('coordin', 'told') 2
# ('coordin', 'toi') 2
# ('offic', 'plan') 2
# ('offic', 'told') 2
# ('offic', 'toi') 2
# ('offic', 'alloc') 2
# ('state', 'alloc') 2
# ('plan', 'alloc') 2
# ('plan', 'total') 2
# ('depart', 'alloc') 2
# ('depart', 'total') 2
# ('told', 'alloc') 2
# ('told', 'total') 2
# ('told', 'budget') 2
# ('told', 'depart') 2
# ('toi', 'alloc') 2
# ('toi', 'total') 2
# ('alloc', 'total') 2
# ('alloc', 'depart') 2
# ('budget', 'fund') 2
# ('climat', 'overal') 2
# ('chang', 'overal') 2
# ('fund', 'overal') 2
# ('fund', 'budget') 2
# ('fund', 'woven') 2
# ('overal', 'woven') 2
# ('overal', 'scheme') 2
# ('woven', 'scheme') 2
# ('woven', 'sustain') 2
# ('woven', 'develop') 2
# ('woven', 'goal') 2
# ('scheme', 'develop') 2
# ('scheme', 'goal') 2
# ('scheme', 'serv') 2
# ('scheme', 'environment') 2
# ('sustain', 'serv') 2
# ('sustain', 'howev') 2
# ('develop', 'serv') 2
# ('develop', 'howev') 2
# ('goal', 'serv') 2
# ('goal', 'environment') 2
# ('goal', 'howev') 2
# ('goal', 'princip') 2
# ('would', 'serv') 2
# ('serv', 'howev') 2
# ('serv', 'jairaj') 2
# ('serv', 'princip') 2
# ('serv', 'conserv') 2
# ('environment', 'howev') 2
# ('environment', 'jairaj') 2
# ('environment', 'princip') 2
# ('environment', 'forest') 2
# ('howev', 'jairaj') 2
# ('howev', 'princip') 2
# ('howev', 'chief') 2
# ('howev', 'conserv') 2
# ('howev', 'forest') 2
# ('howev', 'separ') 2
# ('jairaj', 'said') 2
# ('jairaj', 'separ') 2
# ('jairaj', 'fund') 2
# ('princip', 'said') 2
# ('princip', 'separ') 2
# ('princip', 'fund') 2
# ('chief', 'separ') 2
# ('chief', 'fund') 2
# ('conserv', 'separ') 2
# ('conserv', 'fund') 2
# ('forest', 'separ') 2
# ('forest', 'fund') 2
# ('said', 'capac') 2
# ('separ', 'fund') 2
# ('separ', 'would') 2
# ('separ', 'capac') 2
# ('fund', 'build') 2
# ('would', 'build') 2
# ('would', 'sensit') 2
# ('capac', 'depart') 2
# ('capac', 'field') 2
# ('build', 'depart') 2
# ('build', 'field') 2
# ('depart', 'field') 2
# ('depart', 'good') 2
# ('depart', 'begin') 2
# ('field', 'chang') 2
# ('field', 'good') 2
# ('field', 'begin') 2
# ('field', 'made') 2
# ('field', 'environ') 2
# ('field', 'wing') 2
# ('good', 'begin') 2
# ('good', 'made') 2
# ('good', 'wing') 2
# ('good', 'forest') 2
# ('good', 'depart') 2
# ('begin', 'environ') 2
# ('begin', 'wing') 2
# ('begin', 'state') 2
# ('begin', 'forest') 2
# ('begin', 'depart') 2
# ('begin', 'abl') 2
# ('made', 'environ') 2
# ('made', 'wing') 2
# ('made', 'abl') 2
# ('environ', 'abl') 2
# ('environ', 'togeth') 2
# ('wing', 'bring') 2
# ('wing', 'togeth') 2
# ('wing', 'senior') 2
# ('state', 'bring') 2
# ('state', 'senior') 2
# ('forest', 'abl') 2
# ('forest', 'bring') 2
# ('forest', 'togeth') 2
# ('forest', 'senior') 2
# ('forest', 'differ') 2
# ('depart', 'abl') 2
# ('depart', 'bring') 2
# ('depart', 'togeth') 2
# ('depart', 'senior') 2
# ('depart', 'offici') 2
# ('abl', 'togeth') 2
# ('abl', 'depart') 2
# ('bring', 'togeth') 2
# ('bring', 'senior') 2
# ('bring', 'differ') 2
# ('bring', 'depart') 2
# ('bring', 'one') 2
# ('bring', 'roof') 2
# ('togeth', 'senior') 2
# ('togeth', 'offici') 2
# ('togeth', 'differ') 2
# ('togeth', 'depart') 2
# ('togeth', 'roof') 2
# ('togeth', 'discuss') 2
# ('senior', 'depart') 2
# ('senior', 'one') 2
# ('senior', 'roof') 2
# ('senior', 'discuss') 2
# ('senior', 'mandat') 2
# ('offici', 'one') 2
# ('offici', 'roof') 2
# ('offici', 'discuss') 2
# ('offici', 'mandat') 2
# ('offici', 'strategi') 2
# ('differ', 'depart') 2
# ('differ', 'one') 2
# ('differ', 'roof') 2
# ('differ', 'discuss') 2
# ('differ', 'mandat') 2
# ('differ', 'strategi') 2
# ('differ', 'implement') 2
# ('depart', 'one') 2
# ('depart', 'roof') 2
# ('depart', 'discuss') 2
# ('depart', 'sapcc') 2
# ('one', 'roof') 2
# ('one', 'mandat') 2
# ('one', 'strategi') 2
# ('one', 'implement') 2
# ('one', 'sapcc') 2
# ('one', 'activ') 2
# ('roof', 'discuss') 2
# ('roof', 'mandat') 2
# ('roof', 'strategi') 2
# ('roof', 'implement') 2
# ('roof', 'sapcc') 2
# ('roof', 'activ') 2
# ('roof', 'mix') 2
# ('discuss', 'mandat') 2
# ('discuss', 'strategi') 2
# ('discuss', 'implement') 2
# ('discuss', 'sapcc') 2
# ('discuss', 'activ') 2
# ('discuss', 'mix') 2
# ('discuss', 'budget') 2
# ('mandat', 'strategi') 2
# ('mandat', 'implement') 2
# ('mandat', 'sapcc') 2
# ('mandat', 'activ') 2
# ('mandat', 'mix') 2
# ('mandat', 'budget') 2
# ('strategi', 'sapcc') 2
# ('strategi', 'activ') 2
# ('strategi', 'mix') 2
# ('strategi', 'budget') 2
# ('strategi', 'serv') 2
# ('implement', 'activ') 2
# ('implement', 'mix') 2
# ('implement', 'budget') 2
# ('implement', 'serv') 2
# ('implement', 'purpos') 2
# ('sapcc', 'activ') 2
# ('sapcc', 'mix') 2
# ('sapcc', 'serv') 2
# ('sapcc', 'purpos') 2
# ('sapcc', 'hope') 2
# ('activ', 'mix') 2
# ('activ', 'budget') 2
# ('activ', 'serv') 2
# ('activ', 'purpos') 2
# ('activ', 'hope') 2
# ('activ', 'new') 2
# ('mix', 'budget') 2
# ('mix', 'serv') 2
# ('mix', 'purpos') 2
# ('mix', 'hope') 2
# ('mix', 'new') 2
# ('mix', 'govern') 2
# ('budget', 'purpos') 2
# ('budget', 'hope') 2
# ('budget', 'new') 2
# ('budget', 'state') 2
# ('serv', 'purpos') 2
# ('serv', 'hope') 2
# ('serv', 'new') 2
# ('serv', 'govern') 2
# ('serv', 'state') 2
# ('serv', 'pay') 2
# ('purpos', 'hope') 2
# ('purpos', 'new') 2
# ('purpos', 'govern') 2
# ('purpos', 'state') 2
# ('purpos', 'pay') 2
# ('purpos', 'heed') 2
# ('hope', 'new') 2
# ('hope', 'govern') 2
# ('hope', 'state') 2
# ('hope', 'pay') 2
# ('hope', 'heed') 2
# ('new', 'pay') 2
# ('new', 'heed') 2
# ('new', 'major') 2
# ('govern', 'heed') 2
# ('state', 'heed') 2
# ('pay', 'heed') 2
# ('pay', 'major') 2
# ('pay', 'decis') 2
# ('pay', 'expand') 2
# ('pay', 'base') 2
# ('pay', 'prioriti') 2
# ('heed', 'said') 2
# ('heed', 'major') 2
# ('heed', 'decis') 2
# ('heed', 'expand') 2
# ('heed', 'base') 2
# ('heed', 'prioriti') 2
# ('heed', 'area') 2
# ('said', 'expand') 2
# ('major', 'decis') 2
# ('major', 'expand') 2
# ('major', 'base') 2
# ('major', 'also') 2
# ('major', 'taken') 2
# ('decis', 'base') 2
# ('decis', 'prioriti') 2
# ('decis', 'also') 2
# ('decis', 'meet') 2
# ('expand', 'base') 2
# ('expand', 'prioriti') 2
# ('expand', 'area') 2
# ('expand', 'also') 2
# ('expand', 'taken') 2
# ('expand', 'meet') 2
# ('expand', 'held') 2
# ('base', 'prioriti') 2
# ('base', 'area') 2
# ('base', 'taken') 2
# ('base', 'meet') 2
# ('base', 'held') 2
# ('base', 'environ') 2
# ('prioriti', 'also') 2
# ('prioriti', 'taken') 2
# ('prioriti', 'meet') 2
# ('prioriti', 'held') 2
# ('prioriti', 'environ') 2
# ('prioriti', 'wing') 2
# ('area', 'taken') 2
# ('area', 'meet') 2
# ('area', 'held') 2
# ('area', 'wing') 2
# ('area', 'offici') 2
# ('also', 'meet') 2
# ('also', 'held') 2
# ('also', 'wing') 2
# ('taken', 'meet') 2
# ('taken', 'held') 2
# ('taken', 'environ') 2
# ('taken', 'wing') 2
# ('taken', 'offici') 2
# ('meet', 'held') 2
# ('meet', 'environ') 2
# ('meet', 'wing') 2
# ('meet', 'offici') 2
# ('meet', 'depart') 2
# ('held', 'environ') 2
# ('held', 'wing') 2
# ('held', 'offici') 2
# ('held', 'state') 2
# ('held', 'govern') 2
# ('held', 'depart') 2
# ('held', 'unit') 2
# ('wing', 'govern') 2
# ('wing', 'unit') 2
# ('wing', 'nation') 2
# ('wing', 'develop') 2
# ('offici', 'govern') 2
# ('offici', 'develop') 2
# ('state', 'undp') 2
# ('govern', 'unit') 2
# ('govern', 'undp') 2
# ('depart', 'unit') 2
# ('depart', 'nation') 2
# ('depart', 'undp') 2
# ('unit', 'chief') 2
# ('nation', 'chief') 2
# ('nation', 'conserv') 2
# ('undp', 'chief') 2
# ('undp', 'conserv') 2
# ('undp', 'forest') 2
# ('undp', 'nodal') 2
# ('undp', 'offic') 2
# ('jha', 'forest') 2
# ('conserv', 'nodal') 2
# ('conserv', 'offic') 2
# ('forest', 'nodal') 2
# ('forest', 'offic') 2
# ('offic', 'select') 2
# ('climat', 'select') 2
# ('said', 'select') 2
# ('said', 'four') 2
# ('select', 'four') 2
# ('select', 'prioriti') 2
# ('select', 'area') 2
# ('select', 'forest') 2
# ('select', 'energi') 2
# ('select', 'disast') 2
# ('four', 'prioriti') 2
# ('four', 'area') 2
# ('four', 'forest') 2
# ('four', 'disast') 2
# ('four', 'manag') 2
# ('prioriti', 'energi') 2
# ('prioriti', 'disast') 2
# ('prioriti', 'manag') 2
# ('area', 'manag') 2
# ('area', 'adapt') 2
# ('area', 'implement') 2
# ('forest', 'adapt') 2
# ('energi', 'adapt') 2
# ('energi', 'implement') 2
# ('disast', 'implement') 2
# ('disast', 'action') 2
# ('manag', 'adapt') 2
# ('manag', 'implement') 2
# ('manag', 'action') 2
# ('manag', 'take') 2
# ('adapt', 'take') 2
# ('implement', 'take') 2
# ('implement', 'area') 2
# ('implement', 'main') 2
# ('action', 'area') 2
# ('take', 'main') 2
# ('take', 'earli') 2
# ('area', 'main') 2
# ('area', 'much') 2
# ('area', 'earli') 2
# ('area', 'stage') 2
# ('main', 'much') 2
# ('main', 'earli') 2
# ('main', 'stage') 2
# ('educ', 'would') 2
# ('habitat', 'would') 2
# ('educ', 'sensit') 2
# ('educ', 'understand') 2
# ('much', 'earli') 2
# ('much', 'stage') 2
# ('much', 'induc') 2
# ('much', 'sensit') 2
# ('much', 'understand') 2
# ('much', 'toward') 2
# ('earli', 'stage') 2
# ('earli', 'induc') 2
# ('earli', 'sensit') 2
# ('earli', 'understand') 2
# ('earli', 'toward') 2
# ('earli', 'extent') 2
# ('stage', 'induc') 2
# ('stage', 'sensit') 2
# ('stage', 'understand') 2
# ('stage', 'toward') 2
# ('stage', 'extent') 2
# ('stage', 'magnitud') 2
# ('induc', 'sensit') 2
# ('induc', 'understand') 2
# ('induc', 'toward') 2
# ('induc', 'extent') 2
# ('induc', 'magnitud') 2
# ('induc', 'way') 2
# ('induc', 'deal') 2
# ('sensit', 'understand') 2
# ('sensit', 'toward') 2
# ('sensit', 'extent') 2
# ('sensit', 'magnitud') 2
# ('sensit', 'way') 2
# ('sensit', 'deal') 2
# ('understand', 'toward') 2
# ('understand', 'extent') 2
# ('understand', 'magnitud') 2
# ('understand', 'way') 2
# ('understand', 'deal') 2
# ('toward', 'extent') 2
# ('toward', 'magnitud') 2
# ('toward', 'way') 2
# ('extent', 'magnitud') 2
# ('extent', 'way') 2
# ('extent', 'deal') 2
# ('extent', 'habitat') 2
# ('magnitud', 'way') 2
# ('magnitud', 'deal') 2
# ('magnitud', 'climat') 2
# ('magnitud', 'chang') 2
# ('magnitud', 'habitat') 2
# ('magnitud', 'area') 2
# ('way', 'deal') 2
# ('way', 'habitat') 2
# ('way', 'area') 2
# ('deal', 'habitat') 2
# ('deal', 'area') 2
# ('deal', 'amalgam') 2
# ('climat', 'amalgam') 2
# ('climat', 'complement') 2
# ('chang', 'amalgam') 2
# ('chang', 'complement') 2
# ('habitat', 'area') 2
# ('habitat', 'amalgam') 2
# ('habitat', 'depart') 2
# ('habitat', 'complement') 2
# ('habitat', 'mandat') 2
# ('habitat', 'tourism') 2
# ('area', 'amalgam') 2
# ('area', 'complement') 2
# ('area', 'mandat') 2
# ('area', 'tourism') 2
# ('area', 'transport') 2
# ('amalgam', 'depart') 2
# ('amalgam', 'complement') 2
# ('amalgam', 'mandat') 2
# ('amalgam', 'tourism') 2
# ('amalgam', 'transport') 2
# ('amalgam', 'agricultur') 2
# ('amalgam', 'horticultur') 2
# ('depart', 'complement') 2
# ('depart', 'tourism') 2
# ('depart', 'transport') 2
# ('depart', 'horticultur') 2
# ('depart', 'anim') 2
# ('complement', 'mandat') 2
# ('complement', 'tourism') 2
# ('complement', 'transport') 2
# ('complement', 'agricultur') 2
# ('complement', 'horticultur') 2
# ('complement', 'anim') 2
# ('complement', 'husbandri') 2
# ('mandat', 'tourism') 2
# ('mandat', 'transport') 2
# ('mandat', 'agricultur') 2
# ('mandat', 'horticultur') 2
# ('mandat', 'anim') 2
# ('mandat', 'husbandri') 2
# ('mandat', 'way') 2
# ('tourism', 'anim') 2
# ('tourism', 'husbandri') 2
# ('tourism', 'way') 2
# ('tourism', 'abl') 2
# ('transport', 'anim') 2
# ('transport', 'husbandri') 2
# ('transport', 'way') 2
# ('transport', 'abl') 2
# ('transport', 'bring') 2
# ('agricultur', 'anim') 2
# ('agricultur', 'husbandri') 2
# ('agricultur', 'way') 2
# ('agricultur', 'abl') 2
# ('agricultur', 'bring') 2
# ('horticultur', 'anim') 2
# ('horticultur', 'husbandri') 2
# ('horticultur', 'way') 2
# ('horticultur', 'abl') 2
# ('horticultur', 'bring') 2
# ('horticultur', 'import') 2
# ('horticultur', 'sector') 2
# ('anim', 'husbandri') 2
# ('anim', 'way') 2
# ('anim', 'abl') 2
# ('anim', 'bring') 2
# ('anim', 'import') 2
# ('husbandri', 'way') 2
# ('husbandri', 'abl') 2
# ('husbandri', 'bring') 2
# ('husbandri', 'import') 2
# ('husbandri', 'sector') 2
# ('husbandri', 'ambit') 2
# ('husbandri', 'sapcc') 2
# ('way', 'abl') 2
# ('way', 'bring') 2
# ('way', 'import') 2
# ('way', 'ambit') 2
# ('way', 'sapcc') 2
# ('abl', 'import') 2
# ('abl', 'ambit') 2
# ('abl', 'sapcc') 2
# ('bring', 'import') 2
# ('bring', 'sector') 2
# ('bring', 'ambit') 2
# ('bring', 'sapcc') 2
# ('import', 'ambit') 2
# ('import', 'sapcc') 2
# ('sector', 'ambit') 2
# ('sector', 'sapcc') 2
# ('rawat', 'govern') 2
# ('rawat', 'budget') 2
# ('overal', 'develop') 2
# ('overal', 'centr') 2
# ('budget', 'goal') 2
# ('mix', 'state') 2
# ('brought', 'budget') 2
# ('technolog', 'centr') 2
# ('technolog', 'excel') 2
# ('excel', 'research') 2
# ('research', 'scholar') 2
# ('scholar', 'look') 2
# ('look', 'river') 2
# ('look', 'ocean') 2
# ('river', 'ocean') 2
# ('climat', 'bengal') 2
# ('vulner', 'cyclon') 2
# ('predict', 'scenario') 2
# ('cyclon', 'chang') 2
# ('cyclon', 'past') 2
# ('cyclon', 'decad') 2
# ('averag', 'radius') 2
# ('averag', 'cyclon') 2
# ('radius', 'cyclon') 2
# ('oceanwav', 'activ') 2
# ('synopt', 'activ') 2
# ('scale', 'activ') 2
# ('activ', 'generat') 2
# ('activ', 'long') 2
# ('activ', 'wave') 2
# ('long', 'bangladesh') 2
# ('wave', 'bangladesh') 2
# ('bengal', 'odisha') 2
# ('coast', 'wave') 2
# ('well', 'wave') 2
# ('wave', 'generat') 2
# ('wave', 'wind') 2
# ('wave', 'affect') 2
# ('wave', 'pattern') 2
# ('wave', 'side') 2
# ('activ', 'side') 2
# ('increas', 'side') 2
# ('eastern', 'side') 2
# ('side', 'alter') 2
# ('side', 'sedimentari') 2
# ('side', 'dyman') 2
# ('side', 'caus') 2
# ('aspect', 'research') 2

# %% [markdown]
# # Distributional distances
#
# If we want to compare different corpora, we need a distance or divergence that compares the two distributions.
#
# We will use the:
#
# + Kullback-Leibler (KL) divergence
# + $\chi^2$ divergence
# + Kolmogorov-Smirnov (KS) distance
# + Wasserstein distance
#
# ### Kullback-Leibler and $x^2$ divergences ###
#
# KL and $\chi^2$ divergences are members of the broader <a "href=https://en.wikipedia.org/wiki/F-divergence" target="_blank">$f$-divergence</a> family, a function of $D_f (P || Q)$ that calculates the difference between two probability distributions P and Q. The KL $f(t)$ is $ t \text{ log } t $, while the $\chi^2$ is $t^2-1$. KL comes from information and $\chi^2$ from measure theory. As such, the KL divergence computes the relative entropy between two distributions--how they differ in bits, while the $\chi^2$ whether the same statistical inferences can be drawn from them both.
#
# Specifically, given two discrete probability distributions $P$ and $Q$, the Kullback-Leibler divergence from $Q$ to $P$ is defined as:
#
# $D_{\mathrm{KL}}(P\|Q) = \sum_i P(i) \, \log\frac{P(i)}{Q(i)}$.
#
# The [scipy.stats.entropy()](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.entropy.html) function does the calculation for you, which takes in two arrays of probabilities and computes the KL divergence. Note that the KL divergence is in general not commutative, i.e. $D_{\mathrm{KL}}(P\|Q) \neq D_{\mathrm{KL}}(Q\|P)$ .
#
# Also note that the KL divernce is the sum of elementwise divergences. Scipy provides [scipy.special.kl_div()](https://docs.scipy.org/doc/scipy/reference/generated/scipy.special.kl_div.html#scipy-special-kl-div) which calculates elementwise divergences for you.
#
# The $\chi^2$ Divergence is defined as:
#
# $D_{\mathrm{\chi^2}}(P\|Q) = \sum_i \left(\frac{P(i)}{Q(i)}-1\right)^2$.
#
# This is also noncommutative, and the code can be drawn directly from scipy.
#
# ### Kolmogorov-Smirnov ###
#
# The two-sample Kolmogovorov-Smirnov test statistic calculates the distance between the cumulative distribution function of the two distributions to be compared, and, along with the $x^2$ divergence, is among the most common approaches two calculating a distance in statistics. It can be interpreted as a test of whether two distributions are drawn from the same underlying distribution. As with the others, the code is readily available in scipy.
#
# ### Wasserstein Distance ###
#
# When this is computed on a Euclidian metric structure (e.g., numbers of words), this is also known as the earth mover’s distance, because it can be seen as the minimum amount of "work" required to transform $P$ into $Q$, where "work" is measured as the amount of distribution weight that must be moved, multiplied by the distance it has to be moved.
#
# ### Computing ###
#
# To do this we will need to create the arrays, lets compare the Whitehouse releases with the Kennedy releases. First we have to download them and load them into a DataFrame.

# %%
kenReleases = getGithubFiles('https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Kennedy', maxFiles = 10)
kenReleases[:5]
# Out:
#                                         download_url  \
# 0  https://raw.githubusercontent.com/lintool/Grim...
# 1  https://raw.githubusercontent.com/lintool/Grim...
# 2  https://raw.githubusercontent.com/lintool/Grim...
# 3  https://raw.githubusercontent.com/lintool/Grim...
# 4  https://raw.githubusercontent.com/lintool/Grim...
#
#                                             html_url                    name  \
# 0  https://github.com/lintool/GrimmerSenatePressR...  01Apr2005Kennedy14.txt
# 1  https://github.com/lintool/GrimmerSenatePressR...  01Aug2005Kennedy12.txt
# 2  https://github.com/lintool/GrimmerSenatePressR...  01Aug2006Kennedy10.txt
# 3  https://github.com/lintool/GrimmerSenatePressR...  01Aug2006Kennedy11.txt
# 4  https://github.com/lintool/GrimmerSenatePressR...  01Aug2006Kennedy12.txt
#
#                                  path  \
# 0  raw/Kennedy/01Apr2005Kennedy14.txt
# 1  raw/Kennedy/01Aug2005Kennedy12.txt
# 2  raw/Kennedy/01Aug2006Kennedy10.txt
# 3  raw/Kennedy/01Aug2006Kennedy11.txt
# 4  raw/Kennedy/01Aug2006Kennedy12.txt
#
#                                                 text
# 0           FOR IMMEDIATE RELEASE   FOR IMMEDIATE...
# 1           FOR IMMEDIATE RELEASE   FOR IMMEDIATE...
# 2           FOR IMMEDIATE RELEASE  FOR IMMEDIATE ...
# 3           FOR IMMEDIATE RELEASE  FOR IMMEDIATE ...
# 4           FOR IMMEDIATE RELEASE  FOR IMMEDIATE ...

# %% [markdown]
# Then we can tokenize, stem and remove stop words, like we did for the Whitehouse press releases

# %%
kenReleases['tokenized_text'] = kenReleases['text'].apply(lambda x: nltk.word_tokenize(x))
kenReleases['normalized_tokens'] = kenReleases['tokenized_text'].apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, stemmer = snowball))

# %% [markdown]
# Now we need to compare the two collection of words, remove those not found in both, and assign the remaining ones indices.

# %%
whWords = set(whReleases['normalized_tokens'].sum())
kenWords = set(kenReleases['normalized_tokens'].sum())

#Change & to | if you want to keep all words
overlapWords = whWords & kenWords

overlapWordsDict = {word: index for index, word in enumerate(overlapWords)}
overlapWordsDict['student']
# Out:
# 163

# %% [markdown]
# Now we can count the occurrences of each word in the corpora and create our arrays. Note that we don't have to use numpy arrays as we do here. We could just use a list, but the arrays are faster in numpy so we encourage you to get in the habit of using them.

# %%
def makeProbsArray(dfColumn, overlapDict):
    words = dfColumn.sum()
    countList = [0] * len(overlapDict)
    for word in words:
        try:
            countList[overlapDict[word]] += 1
        except KeyError:
            #The word is not common so we skip it
            pass
    countArray = np.array(countList)
    return countArray / countArray.sum()

whProbArray = makeProbsArray(whReleases['normalized_tokens'], overlapWordsDict)
kenProbArray = makeProbsArray(kenReleases['normalized_tokens'], overlapWordsDict)
kenProbArray.sum()
#There is a little bit of a floating point math error
#but it's too small to see with print and too small matter here
# Out:
# 1.0

# %% [markdown]
# We can now compute the KL divergence. Pay attention to the asymmetry. Use [the Jensen–Shannon divergence](https://en.wikipedia.org/wiki/Jensen%E2%80%93Shannon_divergence), which is the average KL divergence between each distribution and the average of both distributions (i.e., the midpoint), if you want symmetry.

# %%
wh_kenDivergence = scipy.stats.entropy(whProbArray, kenProbArray)
print (wh_kenDivergence)
ken_whDivergence = scipy.stats.entropy(kenProbArray, whProbArray)
print (ken_whDivergence)
# Out:
# 0.617641967748
# 0.587708565719

# %% [markdown]
# Then, we can do the elementwise calculation and see which words best distinguish the two corpora.

# %%
wh_kenDivergence_ew = scipy.special.kl_div(whProbArray, kenProbArray)
kl_df = pandas.DataFrame(list(overlapWordsDict.keys()), columns = ['word'], index = list(overlapWordsDict.values()))
kl_df = kl_df.sort_index()
kl_df['elementwise divergence'] = wh_kenDivergence_ew
kl_df[:10]
# Out:
#       word  elementwise divergence
# 0  instead                0.002023
# 1   effort                0.001568
# 2   intent                0.000063
# 3   second                0.000063
# 4      job                0.000672
# 5     vote                0.000048
# 6     said                0.003477
# 7   packag                0.000048
# 8     deni                0.001101
# 9  forward                0.000127

# %%
kl_df.sort_values(by='elementwise divergence', ascending=False)[:10]
# Out:
#          word  elementwise divergence
# 135      iraq                0.086929
# 215      bush                0.042354
# 299      stem                0.021884
# 324       law                0.020547
# 286   protect                0.019358
# 51   american                0.018154
# 145    depart                0.017650
# 118     bring                0.014128
# 291    member                0.012429
# 237       war                0.011739

# %% [markdown]
# Now we will apply what we learned today to the Guternberg texts in nltk and see if we can detect patterns between them.
#
# First, let's transform every text into normalized tokens. Note that in this first step, no stopword is removed.

# %%
fileids = nltk.corpus.gutenberg.fileids()
corpora = []
for fileid in fileids:
    words = nltk.corpus.gutenberg.words(fileid)
    normalized_tokens = normlizeTokens(words, stopwordLst = [], stemmer = snowball)
    corpora.append(normalized_tokens)

# %% [markdown]
# Then, let's separate the normalized tokens into stopwords and non-stopwords.

# %%
corpora_s = []
corpora_nons = []
for corpus in corpora:
    s = []
    nons = []
    for word in corpus:
        if word in stop_words_nltk:
            s.append(word)
        else:
            nons.append(word)
    corpora_s.append(s)
    corpora_nons.append(nons)

# %% [markdown]
# Define some covenient funtions for calculating divergence and distances.

# %%
def kl_divergence(X, Y):
    P = X.copy()
    Q = Y.copy()
    P.columns = ['P']
    Q.columns = ['Q']
    df = Q.join(P).fillna(0)
    p = df.iloc[:,1]
    q = df.iloc[:,0]
    D_kl = scipy.stats.entropy(p, q)
    return D_kl

def chi2_divergence(X,Y):
    P = X.copy()
    Q = Y.copy()
    P.columns = ['P']
    Q.columns = ['Q']
    df = Q.join(P).fillna(0)
    p = df.iloc[:,1]
    q = df.iloc[:,0]
    return scipy.stats.chisquare(p, q).statistic

def Divergence(corpus1, corpus2, difference="KL"):
    """Difference parameter can equal KL, Chi2, or Wass"""
    freqP = nltk.FreqDist(corpus1)
    P = pandas.DataFrame(list(freqP.values()), columns = ['frequency'], index = list(freqP.keys()))
    freqQ = nltk.FreqDist(corpus2)
    Q = pandas.DataFrame(list(freqQ.values()), columns = ['frequency'], index = list(freqQ.keys()))
    if difference == "KL":
        return kl_divergence(P, Q)
    elif difference == "Chi2":
        return chi2_divergence(P, Q)
    elif difference == "KS":
        try:
            return scipy.stats.ks_2samp(P['frequency'], Q['frequency']).statistic
        except:
            return scipy.stats.ks_2samp(P['frequency'], Q['frequency'])
    elif difference == "Wasserstein":
        try:
            return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None).statistic
        except:
            return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None)

# %% [markdown]
# Now we will calculate the KL divergence for each pair of corpora, turn the results into a matrix, and visualize the matrix as a heatmap. Recall that $D_{\mathrm{KL}}(P\|Q)$ measures the amount of information loss when $Q$ is used to approximate $P$. Here, the rows are the $P$s used for calculating KL divergences, and the columns are the $Q$s. So, each cell measures the amount of information loss when the word distribution of the column text is used to approximate the word distribution of the row text. Because the KL divergence is directional, such that the divergence of $P$ from $Q$ is different from the same of $Q$ from $P$, the matrix is assymetric and contains unique information above and below the diagonal. The same is true for the $\chi^2$ divergence.

# %%
L = []
for p in corpora:
    l = []
    for q in corpora:
        l.append(Divergence(p,q, difference = 'KL'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# Note that works by the same author have the lowest within-group KL divergences.
#
# To reveal more patterns, let's do a multidimensional scaling of the matrix.

# %%
mds = sklearn.manifold.MDS()
pos = mds.fit(M).embedding_
x = pos[:,0]
y = pos[:,1]
fig, ax = plt.subplots(figsize = (6,6))
plt.plot(x, y, ' ')
for i, txt in enumerate(fileids):
    ax.annotate(txt, (x[i],y[i]))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\mds.py:396: UserWarning: The MDS API has changed. ``fit`` now constructs an dissimilarity matrix from data. To use a custom dissimilarity matrix, set ``dissimilarity='precomputed'``.
#   warnings.warn("The MDS API has changed. ``fit`` now constructs an"

# %% [markdown]
# Do you see any patterns in the image shown above? Does it make sense?
#
# We may just want to focus on the distrbution of stopwords or non-stopwords. Let's do the analysis again first for stopwords and then for non-stopwords.

# %%
L = []
for p in corpora_s:
    l = []
    for q in corpora_s:
        l.append(Divergence(p,q, difference='KL'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %%
L = []
for p in corpora_nons:
    l = []
    for q in corpora_nons:
        l.append(Divergence(p,q, difference='KL'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# Now we compute the same for the assymmetric $\chi^2$ Divergence.

# %%
L = []
for p in corpora_nons:
    l = []
    for q in corpora_nons:
        l.append(Divergence(p,q, difference='Chi2'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# For the KS distance:

# %%
L = []
for p in corpora_nons:
    l = []
    for q in corpora_nons:
        l.append(Divergence(p,q, difference='KS'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# And finally for the Wasserstein or "earth mover's" Distance.

# %%
L = []
for p in corpora_nons:
    l = []
    for q in corpora_nons:
        l.append(Divergence(p,q, difference='Wasserstein'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-0904f2053c21> in Divergence(corpus1, corpus2, difference)
#      38         try:
# ---> 39             return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None).statistic
#      40         except:
#
# AttributeError: module 'scipy.stats' has no attribute 'wasserstein_distance'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-0c41bb942f22> in <module>()
#       3     l = []
#       4     for q in corpora_nons:
# ----> 5         l.append(Divergence(p,q, difference='Wasserstein'))
#       6     L.append(l)
#       7 M = np.array(L)
#
# <ipython-input-63-0904f2053c21> in Divergence(corpus1, corpus2, difference)
#      39             return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None).statistic
#      40         except:
# ---> 41             return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None)
#
# AttributeError: module 'scipy.stats' has no attribute 'wasserstein_distance'

# %% [markdown]
# You can see that the Bible is highly divergent and this makes reading the plot somewhat difficult. Let's fix this by taking the log of each cell, which will reduce the distance of the Bible from other texts as an outlier.

# %%
! pip install scipy -V 1.0.0
# Out:
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages
# Collecting 1.0.0
#   Could not find a version that satisfies the requirement 1.0.0 (from versions: )
# No matching distribution found for 1.0.0

# %%
! pip uninstall scipy

# %%
import scipy

# %%
print('blah')

# %%
ax = sns.heatmap(div.apply(np.log).replace([np.inf, -np.inf], np.nan))
plt.show()

# %% [markdown]
# This is more legible, as it continues to show that the Bible is divergent, but other structure is also visible, such as the divergence of Austen's *Emma* and *Sense and Sensibility*, and Edgeworth's *The Parent's Assistant*.
#
# If we want to rerun this on a new data set of our own composition, we can be a bit more efficient with our coding. Let's use the Shakespeare texts from last week as example:

# %%
shakespeare_df = lucem_illud.loadTextDirectory('../data/Shakespeare')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-58cda747dc72> in <module>()
# ----> 1 shakespeare_df = lucem_illud.loadTextDirectory('../data/Shakespeare')
#
# AttributeError: module 'lucem_illud' has no attribute 'loadTextDirectory'

# %% [markdown]
# Now we stem and remove stopwords

# %%
shakespeare_df['tokenized_text'] = shakespeare_df['text'].apply(lambda x: nltk.word_tokenize(x))
shakespeare_df['normalized_tokens'] = shakespeare_df['tokenized_text'].apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, stemmer = porter))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-52b90ddf06cf> in <module>()
# ----> 1 shakespeare_df['tokenized_text'] = shakespeare_df['text'].apply(lambda x: nltk.word_tokenize(x))
#       2 shakespeare_df['normalized_tokens'] = shakespeare_df['tokenized_text'].apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, stemmer = porter))
#
# NameError: name 'shakespeare_df' is not defined

# %% [markdown]
# Create the corpus file and generate the heatmap:

# %%
measure = 'KS' #"KL", "Chi2", "KS", "Wasserstein"
num_of_texts = 10 #The bigger this number the slower it will run, you can also try selecting your own plays
fileids_sp = list(shakespeare_df[:num_of_texts].index)
corpora_sp = list(shakespeare_df[:num_of_texts]['normalized_tokens'])
L = []
for p in corpora_sp:
    l = []
    for q in corpora_sp:
        l.append(Divergence(p,q, difference=measure))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids_sp, index = fileids_sp)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# What are "The Passionate Pilgrim" and "The Phoenix and the Turtle"? Little known poems by Shakespeare that are unsurprisingly hard to classify, as they are so different from everything else he wrote.

# %% [markdown]
# ## <span style="color:red">*Exercise 4*</span>
#
# <span style="color:red">Construct cells immediately below this that calculate the KL and $\chi^2$ divergences, and the KS and Wasserstein distances between four separate corpora, plot these with heatmaps, and then array them in two dimensions with multidimensional scaling as above. What does this reveal about relations between the corpora? Which analysis (and divergence or distribution) distinguishes the authors or documents better?
#
# <span style="color:red">**Stretch**: Calculate the <a "href=https://en.wikipedia.org/wiki/Jensen–Shannon_divergence" target="_blank">Jensen-Shannon Divergence</a> between your four corpora. What is the relationship between the KL and JS divergences?</span>
